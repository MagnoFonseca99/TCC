# %% [markdown]
# # O Problema de Atribuição de Enfermeiros
# -  [Descrever o problema de negócios](#Describe-the-business-problem)
# *  [Usar a otimização de decisões](#Use-decision-optimization)
#     *  [Passo 1: Importar a biblioteca](#Step-1:-Import-the-library)
#     -  [Passo 2: Modelar os dados](#Step-2:-Model-the-data)
#     *  [Passo 3: Preparar os dados](#Step-3:-Prepare-the-data)
#     -  [Passo 4: Configurar o modelo prescritivo](#Step-4:-Set-up-the-prescriptive-model)
#         * [Definir as variáveis de decisão](#Define-the-decision-variables)
#         * [Expressar as restrições de negócios](#Express-the-business-constraints)
#         * [Expressar o objetivo](#Express-the-objective)
#         * [Resolver com Otimização de Decisões](#Solve-with-Decision-Optimization)
#     *  [Passo 5: Investigar a solução e executar uma análise de exemplo](#Step-5:-Investigate-the-solution-and-then-run-an-example-analysis)
# *  [Resumo](#Summary)

# %% [markdown]
# ## Descrever o problema de negócios
#
# Este notebook descreve como usar o CPLEX Modeling para Python junto com *pandas* para gerenciar a atribuição de enfermeiros aos turnos em um hospital.
#
# Os enfermeiros devem ser atribuídos aos turnos do hospital de acordo com várias restrições de habilidades e de pessoal.
#
# O objetivo do modelo é encontrar um equilíbrio eficiente entre diferentes metas:
#
# * minimizar o custo total do plano e
# * atribuir os turnos de forma mais justa possível.

# %% [markdown]
# ## Verificando os requisitos mínimos
#
# Este notebook utiliza algumas funcionalidades do pandas que estão disponíveis na versão 0.17.1 ou superior.

# %%
import pip
REQUIRED_MINIMUM_PANDAS_VERSION = '0.17.1'
try:
    import pandas as pd
    assert pd.__version__ >= REQUIRED_MINIMUM_PANDAS_VERSION
except:
    raise Exception("Version %s or above of Pandas is required to run this notebook" % REQUIRED_MINIMUM_PANDAS_VERSION)

# %% [markdown]
# ## Use decision optimization

# %% [markdown]
# ### Passo 1: Importar a biblioteca
#
# Execute o seguinte código para importar a biblioteca de Modelagem de Otimização de Decisão CPLEX. A biblioteca *DOcplex* contém os dois pacotes de modelagem: Programação Matemática (*docplex.mp*) e Programação por Restrições (*docplex.cp*).

# %%
import sys
try:
    import docplex.mp
except:
    raise Exception('Please install docplex. See https://pypi.org/project/docplex/')

# %% [markdown]
# ### Passo 2: Modelar os dados
#
# Os dados de entrada consistem em várias tabelas:
#
# * **Departamentos**: lista todos os departamentos envolvidos na atribuição.
# * **Habilidades**: lista todas as habilidades necessárias.
# * **Turnos**: lista todos os turnos que precisam ser preenchidos, cada um contendo informações sobre o departamento, o dia da semana e os horários de início e término.
# * **Enfermeiros**: lista todos os enfermeiros, identificados por seus nomes.
# * **Habilidades dos Enfermeiros**: indica as habilidades de cada enfermeiro.
# * **Requisitos de Habilidades**: lista o número mínimo de pessoas necessárias para cada departamento e habilidade.
# * **Férias dos Enfermeiros**: lista os dias de folga de cada enfermeiro.
# * **Associações de Enfermeiros**: lista os pares de enfermeiros que desejam trabalhar juntos.
# * **Incompatibilidades de Enfermeiros**: lista os pares de enfermeiros que não desejam trabalhar juntos.

# %% [markdown]
# #### Carregando dados do Excel com pandas
#
# Carregamos os dados de um arquivo Excel usando *pandas*.
# Cada planilha é lida em um *DataFrame* separado do *pandas*.

# %%
CSS = """
body {
    margin: 0;
    font-family: Helvetica;
}
table.dataframe {
    border-collapse: collapse;
    border: none;
}
table.dataframe tr {
    border: none;
}
table.dataframe td, table.dataframe th {
    margin: 0;
    border: 1px solid white;
    padding-left: 0.25em;
    padding-right: 0.25em;
}
table.dataframe th:not(:empty) {
    background-color: #fec;
    text-align: left;
    font-weight: normal;
}
table.dataframe tr:nth-child(2) th:empty {
    border-left: none;
    border-right: 1px dashed #888;
}
table.dataframe td {
    border: 2px solid #ccf;
    background-color: #f4f4ff;
}
    table.dataframe thead th:first-child {
        display: none;
    }
    table.dataframe tbody th {
        display: none;
    }
"""

# %%
from IPython.core.display import HTML
HTML('<style>{}</style>'.format(CSS))

from IPython.display import display

# %%
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO

# %%
# This notebook requires pandas to work
import pandas as pd
from pandas import DataFrame

# Make sure that xlrd package, which is a pandas optional dependency, is installed
# This package is required for Excel I/O
try:
    import xlrd
except:
    if hasattr(sys, 'real_prefix'):
        #we are in a virtual env.
        # !pip install xlrd 
    else:
        # !pip install --user xlrd

# %%
# Use pandas to read the file, one tab for each table.
data_url = "https://github.com/IBMDecisionOptimization/docplex-examples/blob/master/examples/mp/jupyter/nurses_data.xls?raw=true"
nurse_xls_file = pd.ExcelFile(data_url)

df_skills = nurse_xls_file.parse('Skills')
df_depts = nurse_xls_file.parse('Departments')
df_shifts = nurse_xls_file.parse('Shifts')
# Rename df_shifts index
df_shifts.index.name = 'shiftId'

# Index is column 0: name
df_nurses = nurse_xls_file.parse('Nurses', header=0, index_col=0)
df_nurse_skills = nurse_xls_file.parse('NurseSkills')
df_vacations = nurse_xls_file.parse('NurseVacations')
df_associations = nurse_xls_file.parse('NurseAssociations')
df_incompatibilities = nurse_xls_file.parse('NurseIncompatibilities')

# Display the nurses dataframe
print("#nurses = {}".format(len(df_nurses)))
print("#shifts = {}".format(len(df_shifts)))
print("#vacations = {}".format(len(df_vacations)))
# Out:
# #nurses = 32
# #shifts = 42
# #vacations = 59

# %% [markdown]
# Além disso, introduzimos alguns dados globais adicionais:
#
# * O tempo máximo de trabalho para cada enfermeiro.
# * O número máximo e mínimo de turnos trabalhados por um enfermeiro em uma semana.

# %%
# maximum work time (in hours)
max_work_time = 40

# maximum number of shifts worked in a week.
max_nb_shifts = 5

# %% [markdown]
# Os turnos são armazenados em um *DataFrame* separado.

# %%
df_shifts
# Out:
#            department        day  start_time  end_time  min_req  max_req
# shiftId
# 0           Emergency     Monday           2         8        3        5
# 1           Emergency     Monday           8        12        4        7
# 2           Emergency     Monday          12        18        2        5
# 3           Emergency     Monday          18         2        3        7
# 4        Consultation     Monday           8        12       10       13
# 5        Consultation     Monday          12        18        8       12
# 6        Cardiac Care     Monday           8        12       10       13
# 7        Cardiac Care     Monday          12        18        8       12
# 8           Emergency    Tuesday           2         8        3        5
# 9           Emergency    Tuesday           8        12        4        7
# 10          Emergency    Tuesday          12        18        2        5
# 11          Emergency    Tuesday          18         2        3        7
# 12       Consultation    Tuesday           8        12       10       13
# 13       Consultation    Tuesday          12        18        8       12
# 14       Cardiac Care    Tuesday           8        12        4        7
# 15       Cardiac Care    Tuesday          12        18        2        5
# 16       Cardiac Care    Tuesday          18         2        3        7
# 17          Emergency  Wednesday           2         8        3        5
# 18          Emergency  Wednesday           8        12        4        7
# 19          Emergency  Wednesday          12        18        2        5
# 20          Emergency  Wednesday          18         2        3        7
# 21       Consultation  Wednesday           8        12       10       13
# 22       Consultation  Wednesday          12        18        8       12
# 23          Emergency   Thursday           2         8        3        5
# 24          Emergency   Thursday           8        12        4        7
# 25          Emergency   Thursday          12        18        2        5
# 26          Emergency   Thursday          18         2        3        7
# 27       Consultation   Thursday           8        12       10       13
# 28       Consultation   Thursday          12        18        8       12
# 29          Emergency     Friday           2         8        3        5
# 30          Emergency     Friday           8        12        4        7
# 31          Emergency     Friday          12        18        2        5
# 32          Emergency     Friday          18         2        3        7
# 33       Consultation     Friday           8        12       10       13
# 34       Consultation     Friday          12        18        8       12
# 35          Emergency   Saturday           2        12        5        7
# 36          Emergency   Saturday          12        20        7        9
# 37          Emergency   Saturday          20         2       12       12
# 38          Emergency     Sunday           2        12        5        7
# 39          Emergency     Sunday          12        20        7        9
# 40          Emergency     Sunday          20         2        8       12
# 41         Geriatrics     Sunday           8        10        2        5

# %% [markdown]
# ### Passo 3: Preparar os dados
#
# Precisamos pré-computar dados adicionais para os turnos.
# Para cada turno, precisamos do horário de início e de término expressos em horas, contando a partir do início da semana: segunda-feira às 8h é convertido para 8, terça-feira às 8h é convertido para 24 + 8 = 32, e assim por diante.
#
# #### Sub-passo #1
# Começamos adicionando uma coluna extra chamada `dow` (dia da semana), que converte a string "dia" em um inteiro de 0 a 6 (segunda-feira é 0, domingo é 6).

# %%
days = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]
day_of_weeks = dict(zip(days, range(7)))

# utility to convert a day string e.g. "Monday" to an integer in 0..6
def day_to_day_of_week(day):
    return day_of_weeks[day.strip().lower()]

# for each day name, we normalize it by stripping whitespace and converting it to lowercase
# " Monday" -> "monday"
df_shifts["dow"] = df_shifts.day.apply(day_to_day_of_week)
df_shifts
# Out:
#            department        day  start_time  end_time  min_req  max_req  dow
# shiftId
# 0           Emergency     Monday           2         8        3        5    0
# 1           Emergency     Monday           8        12        4        7    0
# 2           Emergency     Monday          12        18        2        5    0
# 3           Emergency     Monday          18         2        3        7    0
# 4        Consultation     Monday           8        12       10       13    0
# 5        Consultation     Monday          12        18        8       12    0
# 6        Cardiac Care     Monday           8        12       10       13    0
# 7        Cardiac Care     Monday          12        18        8       12    0
# 8           Emergency    Tuesday           2         8        3        5    1
# 9           Emergency    Tuesday           8        12        4        7    1
# 10          Emergency    Tuesday          12        18        2        5    1
# 11          Emergency    Tuesday          18         2        3        7    1
# 12       Consultation    Tuesday           8        12       10       13    1
# 13       Consultation    Tuesday          12        18        8       12    1
# 14       Cardiac Care    Tuesday           8        12        4        7    1
# 15       Cardiac Care    Tuesday          12        18        2        5    1
# 16       Cardiac Care    Tuesday          18         2        3        7    1
# 17          Emergency  Wednesday           2         8        3        5    2
# 18          Emergency  Wednesday           8        12        4        7    2
# 19          Emergency  Wednesday          12        18        2        5    2
# 20          Emergency  Wednesday          18         2        3        7    2
# 21       Consultation  Wednesday           8        12       10       13    2
# 22       Consultation  Wednesday          12        18        8       12    2
# 23          Emergency   Thursday           2         8        3        5    3
# 24          Emergency   Thursday           8        12        4        7    3
# 25          Emergency   Thursday          12        18        2        5    3
# 26          Emergency   Thursday          18         2        3        7    3
# 27       Consultation   Thursday           8        12       10       13    3
# 28       Consultation   Thursday          12        18        8       12    3
# 29          Emergency     Friday           2         8        3        5    4
# 30          Emergency     Friday           8        12        4        7    4
# 31          Emergency     Friday          12        18        2        5    4
# 32          Emergency     Friday          18         2        3        7    4
# 33       Consultation     Friday           8        12       10       13    4
# 34       Consultation     Friday          12        18        8       12    4
# 35          Emergency   Saturday           2        12        5        7    5
# 36          Emergency   Saturday          12        20        7        9    5
# 37          Emergency   Saturday          20         2       12       12    5
# 38          Emergency     Sunday           2        12        5        7    6
# 39          Emergency     Sunday          12        20        7        9    6
# 40          Emergency     Sunday          20         2        8       12    6
# 41         Geriatrics     Sunday           8        10        2        5    6

# %% [markdown]
# #### Sub-passo #2: Calcular o horário de início absoluto de cada turno.
#
# Calcular o horário de início na semana é simples: basta adicionar `24 * dow` à coluna `start_time`. O resultado é armazenado em uma nova coluna chamada `wstart`.

# %%
df_shifts["wstart"] = df_shifts.start_time + 24 * df_shifts.dow

# %% [markdown]
# #### Sub-passo #3: Calcular o horário de término absoluto de cada turno.
#
# Calcular o horário de término absoluto é um pouco mais complicado, pois alguns turnos se estendem até a meia-noite. Por exemplo, o Turno #3 começa na segunda-feira às 18:00 e termina na terça-feira às 2:00. O horário de término absoluto do Turno #3 é 26, não 2.
# A regra geral para calcular o horário de término absoluto é:
#
# `abs_end_time = end_time + 24 * dow + (start_time >= end_time ? 24 : 0)`
#
# Novamente, usamos *pandas* para adicionar uma nova coluna calculada chamada `wend`. Isso é feito usando o método `apply` do *pandas* com uma função anônima `lambda` aplicada às linhas. O parâmetro `raw=True` impede a criação de uma *Series* do *pandas* para cada linha, o que melhora significativamente o desempenho em conjuntos de dados grandes.

# %%
# an auxiliary function to calculate absolute end time of a shift
def calculate_absolute_endtime(start, end, dow):
    return 24*dow + end + (24 if start>=end else 0)

# store the results in a new column
df_shifts["wend"] = df_shifts.apply(lambda row: calculate_absolute_endtime(
        row.start_time, row.end_time, row.dow), axis=1)

# %% [markdown]
# #### Sub-passo #4: Calcular a duração de cada turno.
#
# Calcular a duração de cada turno agora é uma diferença direta entre colunas. O resultado é armazenado na coluna `duration`.

# %%
df_shifts["duration"] = df_shifts.wend - df_shifts.wstart

# %% [markdown]
# #### Sub-passo #5: Calcular a demanda mínima para cada turno.
#
# A demanda mínima é o produto da duração (em horas) pelo número mínimo de enfermeiros requeridos. Assim, em termos de horas de enfermeiro, essa demanda é armazenada em outra nova coluna chamada `min_demand`.
#
# Por fim, exibimos o *DataFrame* de turnos atualizado com todas as colunas calculadas.

# %%
# also compute minimum demand in nurse-hours
df_shifts["min_demand"] = df_shifts.min_req * df_shifts.duration
# finally check the modified shifts dataframe
df_shifts
# Out:
#            department        day  start_time  end_time  min_req  max_req  dow  \
# shiftId
# 0           Emergency     Monday           2         8        3        5    0
# 1           Emergency     Monday           8        12        4        7    0
# 2           Emergency     Monday          12        18        2        5    0
# 3           Emergency     Monday          18         2        3        7    0
# 4        Consultation     Monday           8        12       10       13    0
# 5        Consultation     Monday          12        18        8       12    0
# 6        Cardiac Care     Monday           8        12       10       13    0
# 7        Cardiac Care     Monday          12        18        8       12    0
# 8           Emergency    Tuesday           2         8        3        5    1
# 9           Emergency    Tuesday           8        12        4        7    1
# 10          Emergency    Tuesday          12        18        2        5    1
# 11          Emergency    Tuesday          18         2        3        7    1
# 12       Consultation    Tuesday           8        12       10       13    1
# 13       Consultation    Tuesday          12        18        8       12    1
# 14       Cardiac Care    Tuesday           8        12        4        7    1
# 15       Cardiac Care    Tuesday          12        18        2        5    1
# 16       Cardiac Care    Tuesday          18         2        3        7    1
# 17          Emergency  Wednesday           2         8        3        5    2
# 18          Emergency  Wednesday           8        12        4        7    2
# 19          Emergency  Wednesday          12        18        2        5    2
# 20          Emergency  Wednesday          18         2        3        7    2
# 21       Consultation  Wednesday           8        12       10       13    2
# 22       Consultation  Wednesday          12        18        8       12    2
# 23          Emergency   Thursday           2         8        3        5    3
# 24          Emergency   Thursday           8        12        4        7    3
# 25          Emergency   Thursday          12        18        2        5    3
# 26          Emergency   Thursday          18         2        3        7    3
# 27       Consultation   Thursday           8        12       10       13    3
# 28       Consultation   Thursday          12        18        8       12    3
# 29          Emergency     Friday           2         8        3        5    4
# 30          Emergency     Friday           8        12        4        7    4
# 31          Emergency     Friday          12        18        2        5    4
# 32          Emergency     Friday          18         2        3        7    4
# 33       Consultation     Friday           8        12       10       13    4
# 34       Consultation     Friday          12        18        8       12    4
# 35          Emergency   Saturday           2        12        5        7    5
# 36          Emergency   Saturday          12        20        7        9    5
# 37          Emergency   Saturday          20         2       12       12    5
# 38          Emergency     Sunday           2        12        5        7    6
# 39          Emergency     Sunday          12        20        7        9    6
# 40          Emergency     Sunday          20         2        8       12    6
# 41         Geriatrics     Sunday           8        10        2        5    6
#
#          wstart  wend  duration  min_demand
# shiftId
# 0             2     8         6          18
# 1             8    12         4          16
# 2            12    18         6          12
# 3            18    26         8          24
# 4             8    12         4          40
# 5            12    18         6          48
# 6             8    12         4          40
# 7            12    18         6          48
# 8            26    32         6          18
# 9            32    36         4          16
# 10           36    42         6          12
# 11           42    50         8          24
# 12           32    36         4          40
# 13           36    42         6          48
# 14           32    36         4          16
# 15           36    42         6          12
# 16           42    50         8          24
# 17           50    56         6          18
# 18           56    60         4          16
# 19           60    66         6          12
# 20           66    74         8          24
# 21           56    60         4          40
# 22           60    66         6          48
# 23           74    80         6          18
# 24           80    84         4          16
# 25           84    90         6          12
# 26           90    98         8          24
# 27           80    84         4          40
# 28           84    90         6          48
# 29           98   104         6          18
# 30          104   108         4          16
# 31          108   114         6          12
# 32          114   122         8          24
# 33          104   108         4          40
# 34          108   114         6          48
# 35          122   132        10          50
# 36          132   140         8          56
# 37          140   146         6          72
# 38          146   156        10          50
# 39          156   164         8          56
# 40          164   170         6          48
# 41          152   154         2           4

# %% [markdown]
# ### Passo 4: Configurar o modelo

# %%
from pulp import LpProblem, LpVariable, lpSum, LpStatus, LpStatusOptimal, value, PULP_CBC_CMD, GLPK, CPLEX
import pulp

# Criando o problema de otimização
prob = pulp.LpProblem("nurses", pulp.LpMinimize)

# Definindo as coleções de enfermeiros e turnos
all_nurses = df_nurses.index.values  # Lista de enfermeiros
all_shifts = df_shifts.index.values  # Lista de turnos

# Definindo as variáveis binárias de atribuição
assigned = pulp.LpVariable.dicts(
    "assign", 
    [(nurse, shift) for nurse in all_nurses for shift in all_shifts], 
    cat='Binary'
)

# %%
import pandasql as psql
import sqlite3

df = pd.DataFrame(df_shifts)

# Conectar ao banco de dados SQLite na memória
conn = sqlite3.connect(':memory:')

# Carregar o DataFrame em uma tabela SQL temporária
df.to_sql('shifts', conn, index=False, if_exists='replace')

# Consulta SQL para encontrar turnos que ocorrem no mesmo horário
query = """
SELECT group_concat(shiftId) as turnos_simultaneos
FROM df
GROUP BY wstart 
HAVING COUNT(*) > 1
"""

# Executar a consulta no DataFrame
turnos_simultaneos = psql.sqldf(query, locals())

# Exibir o resultado
print(turnos_simultaneos)
# Out:
#    turnos_simultaneos
# 0               1,4,6
# 1               2,5,7
# 2             9,12,14
# 3            10,13,15
# 4               11,16
# 5               18,21
# 6               19,22
# 7               24,27
# 8               25,28
# 9               30,33
# 10              31,34

# %%
for nurse in all_nurses:
    #Adicionar a restrição para cada enfermeiro e grupo de turnos simultâneos
    for _, row in turnos_simultaneos.iterrows():
        # Pegar os turnos simultâneos e transformá-los em uma lista de inteiros
        simultaneous_shifts = [int(shift_id) for shift_id in row['turnos_simultaneos'].split(',')]
        # Criar a restrição: a soma das variáveis de decisão desses turnos deve ser <= 1 para cada enfermeiro
        prob += lpSum([assigned[(nurse, shift)] for shift in simultaneous_shifts]) <= 1, f"RestrSimult_{nurse}_{simultaneous_shifts}"

# %%
for nurse in all_nurses:
    #Adicionar a restrição de 40 horas trabalhadas na semana
    prob += lpSum([assigned[(nurse, shift)]*df_shifts['duration'][shift] for shift in all_shifts]) <= 40, f"Worktime_{nurse}"

# %%
for shift in all_shifts:
    #Adicionar a restrição de quantidade mínima e maxima
    prob += lpSum([assigned[(nurse, shift)] for nurse in all_nurses]) >= df_shifts['min_req'][shift], f"Min_Req_{shift}"
    prob += lpSum([assigned[(nurse, shift)] for nurse in all_nurses]) <= df_shifts['max_req'][shift], f"Max_Req_{shift}"

# %%
# Lista de pares de turnos no mesmo dia para restrição
max_consecutive_pairs = []
min_rest_pairs = []

for shift1, shift2 in combinations(all_shifts, 2):
    day1 = df_shifts.loc[shift1, 'day']
    day2 = df_shifts.loc[shift2, 'day']
    start_time1 = df_shifts.loc[shift1, 'start_time']
    end_time1 = df_shifts.loc[shift1, 'end_time']
    start_time2 = df_shifts.loc[shift2, 'start_time']
    end_time2 = df_shifts.loc[shift2, 'end_time']

    # Verificar se os turnos são no mesmo dia
    if day1 == day2:
        # Turnos consecutivos (shift2 começa logo após shift1 terminar)
        if start_time2 >= end_time1:
            work_hours = end_time1 - start_time1 + (end_time2 - start_time2)
            if work_hours > 10:
                max_consecutive_pairs.append((shift1, shift2))
        # Turnos não consecutivos (verificar descanso mínimo diário)
        rest_time = start_time2 - end_time1
        if rest_time > 0 and rest_time < 12:  # Menos de 12h de descanso
            min_rest_pairs.append((shift1, shift2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       2 max_consecutive_pairs = []
#       3 min_rest_pairs = []
# ----> 5 for shift1, shift2 in combinations(all_shifts, 2):
#       6     day1 = df_shifts.loc[shift1, 'day']
#       7     day2 = df_shifts.loc[shift2, 'day']
#
# NameError: name 'combinations' is not defined

# %%
# Adicionar restrição para trabalho consecutivo máximo de 10h
for nurse in all_nurses:
    for shift1, shift2 in max_consecutive_pairs:
        prob += (
            assigned[(nurse, shift1)] + assigned[(nurse, shift2)]
        ) <= 1, f"MaxConsecutive_{nurse}_{shift1}_{shift2}"

# %%
# Adicionar restrição para descanso mínimo diário de 12h
for nurse in all_nurses:
    for shift1, shift2 in min_rest_pairs:
        prob += (
            assigned[(nurse, shift1)] + assigned[(nurse, shift2)]
        ) <= 1, f"MinRest_{nurse}_{shift1}_{shift2}"

# %%
df_shifts
# Out:
#            department        day  start_time  end_time  min_req  max_req  dow  \
# shiftId
# 0           Emergency     Monday           2         8        3        5    0
# 1           Emergency     Monday           8        12        4        7    0
# 2           Emergency     Monday          12        18        2        5    0
# 3           Emergency     Monday          18         2        3        7    0
# 4        Consultation     Monday           8        12       10       13    0
# 5        Consultation     Monday          12        18        8       12    0
# 6        Cardiac Care     Monday           8        12       10       13    0
# 7        Cardiac Care     Monday          12        18        8       12    0
# 8           Emergency    Tuesday           2         8        3        5    1
# 9           Emergency    Tuesday           8        12        4        7    1
# 10          Emergency    Tuesday          12        18        2        5    1
# 11          Emergency    Tuesday          18         2        3        7    1
# 12       Consultation    Tuesday           8        12       10       13    1
# 13       Consultation    Tuesday          12        18        8       12    1
# 14       Cardiac Care    Tuesday           8        12        4        7    1
# 15       Cardiac Care    Tuesday          12        18        2        5    1
# 16       Cardiac Care    Tuesday          18         2        3        7    1
# 17          Emergency  Wednesday           2         8        3        5    2
# 18          Emergency  Wednesday           8        12        4        7    2
# 19          Emergency  Wednesday          12        18        2        5    2
# 20          Emergency  Wednesday          18         2        3        7    2
# 21       Consultation  Wednesday           8        12       10       13    2
# 22       Consultation  Wednesday          12        18        8       12    2
# 23          Emergency   Thursday           2         8        3        5    3
# 24          Emergency   Thursday           8        12        4        7    3
# 25          Emergency   Thursday          12        18        2        5    3
# 26          Emergency   Thursday          18         2        3        7    3
# 27       Consultation   Thursday           8        12       10       13    3
# 28       Consultation   Thursday          12        18        8       12    3
# 29          Emergency     Friday           2         8        3        5    4
# 30          Emergency     Friday           8        12        4        7    4
# 31          Emergency     Friday          12        18        2        5    4
# 32          Emergency     Friday          18         2        3        7    4
# 33       Consultation     Friday           8        12       10       13    4
# 34       Consultation     Friday          12        18        8       12    4
# 35          Emergency   Saturday           2        12        5        7    5
# 36          Emergency   Saturday          12        20        7        9    5
# 37          Emergency   Saturday          20         2       12       12    5
# 38          Emergency     Sunday           2        12        5        7    6
# 39          Emergency     Sunday          12        20        7        9    6
# 40          Emergency     Sunday          20         2        8       12    6
# 41         Geriatrics     Sunday           8        10        2        5    6
#
#          wstart  wend  duration  min_demand
# shiftId
# 0             2     8         6          18
# 1             8    12         4          16
# 2            12    18         6          12
# 3            18    26         8          24
# 4             8    12         4          40
# 5            12    18         6          48
# 6             8    12         4          40
# 7            12    18         6          48
# 8            26    32         6          18
# 9            32    36         4          16
# 10           36    42         6          12
# 11           42    50         8          24
# 12           32    36         4          40
# 13           36    42         6          48
# 14           32    36         4          16
# 15           36    42         6          12
# 16           42    50         8          24
# 17           50    56         6          18
# 18           56    60         4          16
# 19           60    66         6          12
# 20           66    74         8          24
# 21           56    60         4          40
# 22           60    66         6          48
# 23           74    80         6          18
# 24           80    84         4          16
# 25           84    90         6          12
# 26           90    98         8          24
# 27           80    84         4          40
# 28           84    90         6          48
# 29           98   104         6          18
# 30          104   108         4          16
# 31          108   114         6          12
# 32          114   122         8          24
# 33          104   108         4          40
# 34          108   114         6          48
# 35          122   132        10          50
# 36          132   140         8          56
# 37          140   146         6          72
# 38          146   156        10          50
# 39          156   164         8          56
# 40          164   170         6          48
# 41          152   154         2           4

# %%
CustoTotal = 0
for nurse in all_nurses:
    CustoEnfermeira = 0
    for shift in all_shifts:
        CustoEnfermeira += assigned[(nurse, shift)] * df_shifts['duration'][shift] * df_nurses.loc[nurse, 'pay_rate']
    CustoTotal += CustoEnfermeira

prob += CustoTotal, f"CustoTotal"

# %%
print(prob)
# Out:
# nurses:
# MINIMIZE
# 150*assign_('Anne',_np.int64(0)) + 100*assign_('Anne',_np.int64(1)) + 150*assign_('Anne',_np.int64(10)) + 200*assign_('Anne',_np.int64(11)) + 100*assign_('Anne',_np.int64(12)) + 150*assign_('Anne',_np.int64(13)) + 100*assign_('Anne',_np.int64(14)) + 150*assign_('Anne',_np.int64(15)) + 200*assign_('Anne',_np.int64(16)) + 150*assign_('Anne',_np.int64(17)) + 100*assign_('Anne',_np.int64(18)) + 150*assign_('Anne',_np.int64(19)) + 150*assign_('Anne',_np.int64(2)) + 200*assign_('Anne',_np.int64(20)) + 100*assign_('Anne',_np.int64(21)) + 150*assign_('Anne',_np.int64(22)) + 150*assign_('Anne',_np.int64(23)) + 100*assign_('Anne',_np.int64(24)) + 150*assign_('Anne',_np.int64(25)) + 200*assign_('Anne',_np.int64(26)) + 100*assign_('Anne',_np.int64(27)) + 150*assign_('Anne',_np.int64(28)) + 150*assign_('Anne',_np.int64(29)) + 200*assign_('Anne',_np.int64(3)) + 100*assign_('Anne',_np.int64(30)) + 150*assign_('Anne',_np.int64(31)) + 200*assign_('Anne',_np.int64(32)) + 100*assign_('Anne',_np.int64(33)) + 150*assign_('Anne',_np.int64(34)) + 250*assign_('Anne',_np.int64(35)) + 200*assign_('Anne',_np.int64(36)) + 150*assign_('Anne',_np.int64(37)) + 250*assign_('Anne',_np.int64(38)) + 200*assign_('Anne',_np.int64(39)) + 100*assign_('Anne',_np.int64(4)) + 150*assign_('Anne',_np.int64(40)) + 50*assign_('Anne',_np.int64(41)) + 150*assign_('Anne',_np.int64(5)) + 100*assign_('Anne',_np.int64(6)) + 150*assign_('Anne',_np.int64(7)) + 150*assign_('Anne',_np.int64(8)) + 100*assign_('Anne',_np.int64(9)) + 168*assign_('Bethanie',_np.int64(0)) + 112*assign_('Bethanie',_np.int64(1)) + 168*assign_('Bethanie',_np.int64(10)) + 224*assign_('Bethanie',_np.int64(11)) + 112*assign_('Bethanie',_np.int64(12)) + 168*assign_('Bethanie',_np.int64(13)) + 112*assign_('Bethanie',_np.int64(14)) + 168*assign_('Bethanie',_np.int64(15)) + 224*assign_('Bethanie',_np.int64(16)) + 168*assign_('Bethanie',_np.int64(17)) + 112*assign_('Bethanie',_np.int64(18)) + 168*assign_('Bethanie',_np.int64(19)) + 168*assign_('Bethanie',_np.int64(2)) + 224*assign_('Bethanie',_np.int64(20)) + 112*assign_('Bethanie',_np.int64(21)) + 168*assign_('Bethanie',_np.int64(22)) + 168*assign_('Bethanie',_np.int64(23)) + 112*assign_('Bethanie',_np.int64(24)) + 168*assign_('Bethanie',_np.int64(25)) + 224*assign_('Bethanie',_np.int64(26)) + 112*assign_('Bethanie',_np.int64(27)) + 168*assign_('Bethanie',_np.int64(28)) + 168*assign_('Bethanie',_np.int64(29)) + 224*assign_('Bethanie',_np.int64(3)) + 112*assign_('Bethanie',_np.int64(30)) + 168*assign_('Bethanie',_np.int64(31)) + 224*assign_('Bethanie',_np.int64(32)) + 112*assign_('Bethanie',_np.int64(33)) + 168*assign_('Bethanie',_np.int64(34)) + 280*assign_('Bethanie',_np.int64(35)) + 224*assign_('Bethanie',_np.int64(36)) + 168*assign_('Bethanie',_np.int64(37)) + 280*assign_('Bethanie',_np.int64(38)) + 224*assign_('Bethanie',_np.int64(39)) + 112*assign_('Bethanie',_np.int64(4)) + 168*assign_('Bethanie',_np.int64(40)) + 56*assign_('Bethanie',_np.int64(41)) + 168*assign_('Bethanie',_np.int64(5)) + 112*assign_('Bethanie',_np.int64(6)) + 168*assign_('Bethanie',_np.int64(7)) + 168*assign_('Bethanie',_np.int64(8)) + 112*assign_('Bethanie',_np.int64(9)) + 102*assign_('Betsy',_np.int64(0)) + 68*assign_('Betsy',_np.int64(1)) + 102*assign_('Betsy',_np.int64(10)) + 136*assign_('Betsy',_np.int64(11)) + 68*assign_('Betsy',_np.int64(12)) + 102*assign_('Betsy',_np.int64(13)) + 68*assign_('Betsy',_np.int64(14)) + 102*assign_('Betsy',_np.int64(15)) + 136*assign_('Betsy',_np.int64(16)) + 102*assign_('Betsy',_np.int64(17)) + 68*assign_('Betsy',_np.int64(18)) + 102*assign_('Betsy',_np.int64(19)) + 102*assign_('Betsy',_np.int64(2)) + 136*assign_('Betsy',_np.int64(20)) + 68*assign_('Betsy',_np.int64(21)) + 102*assign_('Betsy',_np.int64(22)) + 102*assign_('Betsy',_np.int64(23)) + 68*assign_('Betsy',_np.int64(24)) + 102*assign_('Betsy',_np.int64(25)) + 136*assign_('Betsy',_np.int64(26)) + 68*assign_('Betsy',_np.int64(27)) + 102*assign_('Betsy',_np.int64(28)) + 102*assign_('Betsy',_np.in ...
# SUBJECT TO
# RestrSimult_Anne__1,_4,_6_: assign_('Anne',_np.int64(1))
#  + assign_('Anne',_np.int64(4)) + assign_('Anne',_np.int64(6)) <= 1
#
# RestrSimult_Anne__2,_5,_7_: assign_('Anne',_np.int64(2))
#  + assign_('Anne',_np.int64(5)) + assign_('Anne',_np.int64(7)) <= 1
#
# RestrSimult_Anne__9,_12,_14_: assign_('Anne',_np.int64(12))
#  + assign_('Anne',_np.int64(14)) + assign_('Anne',_np.int64(9)) <= 1
#
# RestrSimult_Anne__10,_13,_15_: assign_('Anne',_np.int64(10))
#  + assign_('Anne',_np.int64(13)) + assign_('Anne',_np.int64(15)) <= 1
#
# RestrSimult_Anne__11,_16_: assign_('Anne',_np.int64(11))
#  + assign_('Anne',_np.int64(16)) <= 1
#
# RestrSimult_Anne__18,_21_: assign_('Anne',_np.int64(18))
#  + assign_('Anne',_np.int64(21)) <= 1
#
# RestrSimult_Anne__19,_22_: assign_('Anne',_np.int64(19))
#  + assign_('Anne',_np.int64(22)) <= 1
#
# RestrSimult_Anne__24,_27_: assign_('Anne',_np.int64(24))
#  + assign_('Anne',_np.int64(27)) <= 1
#
# RestrSimult_Anne__25,_28_: assign_('Anne',_np.int64(25))
#  + assign_('Anne',_np.int64(28)) <= 1
#
# RestrSimult_Anne__30,_33_: assign_('Anne',_np.int64(30))
#  + assign_('Anne',_np.int64(33)) <= 1
#
# RestrSimult_Anne__31,_34_: assign_('Anne',_np.int64(31))
#  + assign_('Anne',_np.int64(34)) <= 1
#
# RestrSimult_Bethanie__1,_4,_6_: assign_('Bethanie',_np.int64(1))
#  + assign_('Bethanie',_np.int64(4)) + assign_('Bethanie',_np.int64(6)) <= 1
#
# RestrSimult_Bethanie__2,_5,_7_: assign_('Bethanie',_np.int64(2))
#  + assign_('Bethanie',_np.int64(5)) + assign_('Bethanie',_np.int64(7)) <= 1
#
# RestrSimult_Bethanie__9,_12,_14_: assign_('Bethanie',_np.int64(12))
#  + assign_('Bethanie',_np.int64(14)) + assign_('Bethanie',_np.int64(9)) <= 1
#
# RestrSimult_Bethanie__10,_13,_15_: assign_('Bethanie',_np.int64(10))
#  + assign_('Bethanie',_np.int64(13)) + assign_('Bethanie',_np.int64(15)) <= 1
#
# RestrSimult_Bethanie__11,_16_: assign_('Bethanie',_np.int64(11))
#  + assign_('Bethanie',_np.int64(16)) <= 1
#
# RestrSimult_Bethanie__18,_21_: assign_('Bethanie',_np.int64(18))
#  + assign_('Bethanie',_np.int64(21)) <= 1
#
# RestrSimult_Bethanie__19,_22_: assign_('Bethanie',_np.int64(19))
#  + assign_('Bethanie',_np.int64(22)) <= 1
#
# RestrSimult_Bethanie__24,_27_: assign_('Bethanie',_np.int64(24))
#  + assign_('Bethanie',_np.int64(27)) <= 1
#
# RestrSimult_Bethanie__25,_28_: assign_('Bethanie',_np.int64(25))
#  + assign_('Bethanie',_np.int64(28)) <= 1
#
# RestrSimult_Bethanie__30,_33_: assign_('Bethanie',_np.int64(30))
#  + assign_('Bethanie',_np.int64(33)) <= 1
#
# RestrSimult_Bethanie__31,_34_: assign_('Bethanie',_np.int64(31))
#  + assign_('Bethanie',_np.int64(34)) <= 1
#
# RestrSimult_Betsy__1,_4,_6_: assign_('Betsy',_np.int64(1))
#  + assign_('Betsy',_np.int64(4)) + assign_('Betsy',_np.int64(6)) <= 1
#
# RestrSimult_Betsy__2,_5,_7_: assign_('Betsy',_np.int64(2))
#  + assign_('Betsy',_np.int64(5)) + assign_('Betsy',_np.int64(7)) <= 1
#
# RestrSimult_Betsy__9,_12,_14_: assign_('Betsy',_np.int64(12))
#  + assign_('Betsy',_np.int64(14)) + assign_('Betsy',_np.int64(9)) <= 1
#
# RestrSimult_Betsy__10,_13,_15_: assign_('Betsy',_np.int64(10))
#  + assign_('Betsy',_np.int64(13)) + assign_('Betsy',_np.int64(15)) <= 1
#
# RestrSimult_Betsy__11,_16_: assign_('Betsy',_np.int64(11))
#  + assign_('Betsy',_np.int64(16)) <= 1
#
# RestrSimult_Betsy__18,_21_: assign_('Betsy',_np.int64(18))
#  + assign_('Betsy',_np.int64(21)) <= 1
#
# RestrSimult_Betsy__19,_22_: assign_('Betsy',_np.int64(19))
#  + assign_('Betsy',_np.int64(22)) <= 1
#
# RestrSimult_Betsy__24,_27_: assign_('Betsy',_np.int64(24))
#  + assign_('Betsy',_np.int64(27)) <= 1
#
# RestrSimult_Betsy__25,_28_: assign_('Betsy',_np.int64(25))
#  + assign_('Betsy',_np.int64(28)) <= 1
#
# RestrSimult_Betsy__30,_33_: assign_('Betsy',_np.int64(30))
#  + assign_('Betsy',_np.int64(33)) <= 1
#
# RestrSimult_Betsy__31,_34_: assign_('Betsy',_np.int64(31))
#  + assign_('Betsy',_np.int64(34)) <= 1
#
# RestrSimult_Cathy__1,_4,_6_: assign_('Cathy',_np.int64(1))
#  + assign_('Cathy',_np.int64(4)) + assign_('Cathy',_np.int64(6)) <= 1
#
# RestrSimult_Cathy__2,_5,_7_: assign_('Cathy',_np.int64(2))
#  + assign_('Cathy',_np.int64(5)) + assign_('Cathy',_np.int64(7)) <= 1
#
# RestrSimult_Cathy__9,_12,_14_: assign_('Cathy',_np.int64(12))
#  + assign_('Cathy',_np.int64(14)) + assign_('Cathy',_np.int64(9)) <= 1
#
# RestrSimult_Cathy__10,_13,_15_: assign_('Cathy',_np.int64(10))
#  + assign_('Cathy',_np.int64(13)) + assign_('Cathy',_np.int64(15)) <= 1
#
# RestrSimult_Cathy__11,_16_: assign_('Cathy',_np.int64(11))
#  + assign_('Cathy',_np.int64(16)) <= 1
#
# RestrSimult_Cathy__18,_21_: assign_('Cathy',_np.int64(18))
#  + assign_('Cathy',_np.int64(21)) <= 1
#
# RestrSimult_Cathy__19,_22_: assign_('Cathy',_np.int64(19))
#  + assign_('Cathy',_np.int64(22)) <= 1
#
# RestrSimult_Cathy__24,_27_: assign_('Cathy',_np.int64(24))
#  + assign_('Cathy',_np.int64(27)) <= 1
#
# RestrSimult_Cathy__25,_28_: assign_('Cathy',_np.int64(25))
#  + assign_('Cathy',_np.int64(28)) <= 1
#
# RestrSimult_Cathy__30,_33_: assign_('Cathy',_np.int64(30))
#  + assign_('Cathy',_np.int64(33)) <= 1
#
# RestrSimult_Cathy__31,_34_: assign_('Cathy',_np.int64(31))
#  + assign_('Cathy',_np.int64(34)) <= 1
#
# RestrSimult_Cecilia__1,_4,_6_: assign_('Cecilia',_np.int64(1))
#  + assign_('Cecilia',_np.int64(4)) + assign_('Cecilia',_np.int64(6)) <= 1
#
# RestrSimult_Cecilia__2,_5,_7_: assign_('Cecilia',_np.int64(2))
#  + assign_('Cecilia',_np.int64(5)) + assign_('Cecilia',_np.int64(7)) <= 1
#
# RestrSimult_Cecilia__9,_12,_14_: assign_('Cecilia',_np.int64(12))
#  + assign_('Cecilia',_np.int64(14)) + assign_('Cecilia',_np.int64(9)) <= 1
#
# RestrSimult_Cecilia__10,_13,_15_: assign_('Cecilia',_np.int64(10))
#  + assign_('Cecilia',_np.int64(13)) + assign_('Cecilia',_np.int64(15)) <= 1
#
# RestrSimult_Cecilia__11,_16_: assign_('Cecilia',_np.int64(11))
#  + assign_('Cecilia',_np.int64(16)) <= 1
#
# RestrSimult_Cecilia__18,_21_: assign_('Cecilia',_np.int64(18))
#  + assign_('Cecilia',_np.int64(21)) <= 1
#
# RestrSimult_Cecilia__19,_22_: assign_('Cecilia',_np.int64(19))
#  + assign_('Cecilia',_np.int64(22)) <= 1
#
# RestrSimult_Cecilia__24,_27_: assign_('Cecilia',_np.int64(24))
#  + assign_('Cecilia',_np.int64(27)) <= 1
#
# RestrSimult_Cecilia__25,_28_: assign_('Cecilia',_np.int64(25))
#  + assign_('Cecilia',_np.int64(28)) <= 1
#
# RestrSimult_Cecilia__30,_33_: assign_('Cecilia',_np.int64(30))
#  + assign_('Cecilia',_np.int64(33)) <= 1
#
# RestrSimult_Cecilia__31,_34_: assign_('Cecilia',_np.int64(31))
#  + assign_('Cecilia',_np.int64(34)) <= 1
#
# RestrSimult_Chris__1,_4,_6_: assign_('Chris',_np.int64(1))
#  + assign_('Chris',_np.int64(4)) + assign_('Chris',_np.int64(6)) <= 1
#
# RestrSimult_Chris__2,_5,_7_: assign_('Chris',_np.int64(2))
#  + assign_('Chris',_np.int64(5)) + assign_('Chris',_np.int64(7)) <= 1
#
# RestrSimult_Chris__9,_12,_14_: assign_('Chris',_np.int64(12))
#  + assign_('Chris',_np.int64(14)) + assign_('Chris',_np.int64(9)) <= 1
#
# RestrSimult_Chris__10,_13,_15_: assign_('Chris',_np.int64(10))
#  + assign_('Chris',_np.int64(13)) + assign_('Chris',_np.int64(15)) <= 1
#
# RestrSimult_Chris__11,_16_: assign_('Chris',_np.int64(11))
#  + assign_('Chris',_np.int64(16)) <= 1
#
# RestrSimult_Chris__18,_21_: assign_('Chris',_np.int64(18))
#  + assign_('Chris',_np.int64(21)) <= 1
#
# RestrSimult_Chris__19,_22_: assign_('Chris',_np.int64(19))
#  + assign_('Chris',_np.int64(22)) <= 1
#
# RestrSimult_Chris__24,_27_: assign_('Chris',_np.int64(24))
#  + assign_('Chris',_np.int64(27)) <= 1
#
# RestrSimult_Chris__25,_28_: assign_('Chris',_np.int64(25))
#  + assign_('Chris',_np.int64(28)) <= 1
#
# RestrSimult_Chris__30,_33_: assign_('Chris',_np.int64(30))
#  + assign_('Chris',_np.int64(33)) <= 1
#
# RestrSimult_Chris__31,_34_: assign_('Chris',_np.int64(31))
#  + assign_('Chris',_np.int64(34)) <= 1
#
# RestrSimult_Cindy__1,_4,_6_: assign_('Cindy',_np.int64(1))
#  + assign_('Cindy',_np.int64(4)) + assign_('Cindy',_np.int64(6)) <= 1
#
# RestrSimult_Cindy__2,_5,_7_: assign_('Cindy',_np.int64(2))
#  + assign_('Cindy',_np.int64(5)) + assign_('Cindy',_np.int64(7)) <= 1
#
# RestrSimult_Cindy__9,_12,_14_: assign_('Cindy',_np.int64(12))
#  + assign_('Cindy',_np.int64(14)) + assign_('Cindy',_np.int64(9)) <= 1
#
# RestrSimult_Cindy__10,_13,_15_: assign_('Cindy',_np.int64(10))
#  + assign_('Cindy',_np.int64(13)) + assign_('Cindy',_np.int64(15)) <= 1
#
# RestrSimult_Cindy__11,_16_: assign_('Cindy',_np.int64(11))
#  + assign_('Cindy',_np.int64(16)) <= 1
#
# RestrSimult_Cindy__18,_21_: assign_('Cindy',_np.int64(18))
#  + assign_('Cindy',_np.int64(21)) <= 1
#
# RestrSimult_Cindy__19,_22_: assign_('Cindy',_np.int64(19))
#  + assign_('Cindy',_np.int64(22)) <= 1
#
# RestrSimult_Cindy__24,_27_: assign_('Cindy',_np.int64(24))
#  + assign_('Cindy',_np.int64(27)) <= 1
#
# RestrSimult_Cindy__25,_28_: assign_('Cindy',_np.int64(25))
#  + assign_('Cindy',_np.int64(28)) <= 1
#
# RestrSimult_Cindy__30,_33_: assign_('Cindy',_np.int64(30))
#  + assign_('Cindy',_np.int64(33)) <= 1
#
# RestrSimult_Cindy__31,_34_: assign_('Cindy',_np.int64(31))
#  + assign_('Cindy',_np.int64(34)) <= 1
#
# RestrSimult_David__1,_4,_6_: assign_('David',_np.int64(1))
#  + assign_('David',_np.int64(4)) + assign_('David',_np.int64(6)) <= 1
#
# RestrSimult_David__2,_5,_7_: assign_('David',_np.int64(2))
#  + assign_('David',_np.int64(5)) + assign_('David',_np.int64(7)) <= 1
#
# RestrSimult_David__9,_12,_14_: assign_('David',_np.int64(12))
#  + assign_('David',_np.int64(14)) + assign_('David',_np.int64(9)) <= 1
#
# RestrSimult_David__10,_13,_15_: assign_('David',_np.int64(10))
#  + assign_('David',_np.int64(13)) + assign_('David',_np.int64(15)) <= 1
#
# RestrSimult_David__11,_16_: assign_('David',_np.int64(11))
#  + assign_('David',_np.int64(16)) <= 1
#
# RestrSimult_David__18,_21_: assign_('David',_np.int64(18))
#  + assign_('David',_np.int64(21)) <= 1
#
# RestrSimult_David__19,_22_: assign_('David',_np.int64(19))
#  + assign_('David',_np.int64(22)) <= 1
#
# RestrSimult_David__24,_27_: assign_('David',_np.int64(24))
#  + assign_('David',_np.int64(27)) <= 1
#
# RestrSimult_David__25,_28_: assign_('David',_np.int64(25))
#  + assign_('David',_np.int64(28)) <= 1
#
# RestrSimult_David__30,_33_: assign_('David',_np.int64(30))
#  + assign_('David',_np.int64(33)) <= 1
#
# RestrSimult_David__31,_34_: assign_('David',_np.int64(31))
#  + assign_('David',_np.int64(34)) <= 1
#
# RestrSimult_Debbie__1,_4,_6_: assign_('Debbie',_np.int64(1))
#  + assign_('Debbie',_np.int64(4)) + assign_('Debbie',_np.int64(6)) <= 1
#
# RestrSimult_Debbie__2,_5,_7_: assign_('Debbie',_np.int64(2))
#  + assign_('Debbie',_np.int64(5)) + assign_('Debbie',_np.int64(7)) <= 1
#
# RestrSimult_Debbie__9,_12,_14_: assign_('Debbie',_np.int64(12))
#  + assign_('Debbie',_np.int64(14)) + assign_('Debbie',_np.int64(9)) <= 1
#
# RestrSimult_Debbie__10,_13,_15_: assign_('Debbie',_np.int64(10))
#  + assign_('Debbie',_np.int64(13)) + assign_('Debbie',_np.int64(15)) <= 1
#
# RestrSimult_Debbie__11,_16_: assign_('Debbie',_np.int64(11))
#  + assign_('Debbie',_np.int64(16)) <= 1
#
# RestrSimult_Debbie__18,_21_: assign_('Debbie',_np.int64(18))
#  + assign_('Debbie',_np.int64(21)) <= 1
#
# RestrSimult_Debbie__19,_22_: assign_('Debbie',_np.int64(19))
#  + assign_('Debbie',_np.int64(22)) <= 1
#
# RestrSimult_Debbie__24,_27_: assign_('Debbie',_np.int64(24))
#  + assign_('Debbie',_np.int64(27)) <= 1
#
# RestrSimult_Debbie__25,_28_: assign_('Debbie',_np.int64(25))
#  + assign_('Debbie',_np.int64(28)) <= 1
#
# RestrSimult_Debbie__30,_33_: assign_('Debbie',_np.int64(30))
#  + assign_('Debbie',_np.int64(33)) <= 1
#
# RestrSimult_Debbie__31,_34_: assign_('Debbie',_np.int64(31))
#  + assign_('Debbie',_np.int64(34)) <= 1
#
# RestrSimult_Dee__1,_4,_6_: assign_('Dee',_np.int64(1))
#  + assign_('Dee',_np.int64(4)) + assign_('Dee',_np.int64(6)) <= 1
#
# RestrSimult_Dee__2,_5,_7_: assign_('Dee',_np.int64(2))
#  + assign_('Dee',_np.int64(5)) + assign_('Dee',_np.int64(7)) <= 1
#
# RestrSimult_Dee__9,_12,_14_: assign_('Dee',_np.int64(12))
#  + assign_('Dee',_np.int64(14)) + assign_('Dee',_np.int64(9)) <= 1
#
# RestrSimult_Dee__10,_13,_15_: assign_('Dee',_np.int64(10))
#  + assign_('Dee',_np.int64(13)) + assign_('Dee',_np.int64(15)) <= 1
#
# RestrSimult_Dee__11,_16_: assign_('Dee',_np.int64(11))
#  + assign_('Dee',_np.int64(16)) <= 1
#
# RestrSimult_Dee__18,_21_: assign_('Dee',_np.int64(18))
#  + assign_('Dee',_np.int64(21)) <= 1
#
# RestrSimult_Dee__19,_22_: assign_('Dee',_np.int64(19))
#  + assign_('Dee',_np.int64(22)) <= 1
#
# RestrSimult_Dee__24,_27_: assign_('Dee',_np.int64(24))
#  + assign_('Dee',_np.int64(27)) <= 1
#
# RestrSimult_Dee__25,_28_: assign_('Dee',_np.int64(25))
#  + assign_('Dee',_np.int64(28)) <= 1
#
# RestrSimult_Dee__30,_33_: assign_('Dee',_np.int64(30))
#  + assign_('Dee',_np.int64(33)) <= 1
#
# RestrSimult_Dee__31,_34_: assign_('Dee',_np.int64(31))
#  + assign_('Dee',_np.int64(34)) <= 1
#
# RestrSimult_Gloria__1,_4,_6_: assign_('Gloria',_np.int64(1))
#  + assign_('Gloria',_np.int64(4)) + assign_('Gloria',_np.int64(6)) <= 1
#
# RestrSimult_Gloria__2,_5,_7_: assign_('Gloria',_np.int64(2))
#  + assign_('Gloria',_np.int64(5)) + assign_('Gloria',_np.int64(7)) <= 1
#
# RestrSimult_Gloria__9,_12,_14_: assign_('Gloria',_np.int64(12))
#  + assign_('Gloria',_np.int64(14)) + assign_('Gloria',_np.int64(9)) <= 1
#
# RestrSimult_Gloria__10,_13,_15_: assign_('Gloria',_np.int64(10))
#  + assign_('Gloria',_np.int64(13)) + assign_('Gloria',_np.int64(15)) <= 1
#
# RestrSimult_Gloria__11,_16_: assign_('Gloria',_np.int64(11))
#  + assign_('Gloria',_np.int64(16)) <= 1
#
# RestrSimult_Gloria__18,_21_: assign_('Gloria',_np.int64(18))
#  + assign_('Gloria',_np.int64(21)) <= 1
#
# RestrSimult_Gloria__19,_22_: assign_('Gloria',_np.int64(19))
#  + assign_('Gloria',_np.int64(22)) <= 1
#
# RestrSimult_Gloria__24,_27_: assign_('Gloria',_np.int64(24))
#  + assign_('Gloria',_np.int64(27)) <= 1
#
# RestrSimult_Gloria__25,_28_: assign_('Gloria',_np.int64(25))
#  + assign_('Gloria',_np.int64(28)) <= 1
#
# RestrSimult_Gloria__30,_33_: assign_('Gloria',_np.int64(30))
#  + assign_('Gloria',_np.int64(33)) <= 1
#
# RestrSimult_Gloria__31,_34_: assign_('Gloria',_np.int64(31))
#  + assign_('Gloria',_np.int64(34)) <= 1
#
# RestrSimult_Isabelle__1,_4,_6_: assign_('Isabelle',_np.int64(1))
#  + assign_('Isabelle',_np.int64(4)) + assign_('Isabelle',_np.int64(6)) <= 1
#
# RestrSimult_Isabelle__2,_5,_7_: assign_('Isabelle',_np.int64(2))
#  + assign_('Isabelle',_np.int64(5)) + assign_('Isabelle',_np.int64(7)) <= 1
#
# RestrSimult_Isabelle__9,_12,_14_: assign_('Isabelle',_np.int64(12))
#  + assign_('Isabelle',_np.int64(14)) + assign_('Isabelle',_np.int64(9)) <= 1
#
# RestrSimult_Isabelle__10,_13,_15_: assign_('Isabelle',_np.int64(10))
#  + assign_('Isabelle',_np.int64(13)) + assign_('Isabelle',_np.int64(15)) <= 1
#
# RestrSimult_Isabelle__11,_16_: assign_('Isabelle',_np.int64(11))
#  + assign_('Isabelle',_np.int64(16)) <= 1
#
# RestrSimult_Isabelle__18,_21_: assign_('Isabelle',_np.int64(18))
#  + assign_('Isabelle',_np.int64(21)) <= 1
#
# RestrSimult_Isabelle__19,_22_: assign_('Isabelle',_np.int64(19))
#  + assign_('Isabelle',_np.int64(22)) <= 1
#
# RestrSimult_Isabelle__24,_27_: assign_('Isabelle',_np.int64(24))
#  + assign_('Isabelle',_np.int64(27)) <= 1
#
# RestrSimult_Isabelle__25,_28_: assign_('Isabelle',_np.int64(25))
#  + assign_('Isabelle',_np.int64(28)) <= 1
#
# RestrSimult_Isabelle__30,_33_: assign_('Isabelle',_np.int64(30))
#  + assign_('Isabelle',_np.int64(33)) <= 1
#
# RestrSimult_Isabelle__31,_34_: assign_('Isabelle',_np.int64(31))
#  + assign_('Isabelle',_np.int64(34)) <= 1
#
# RestrSimult_Jane__1,_4,_6_: assign_('Jane',_np.int64(1))
#  + assign_('Jane',_np.int64(4)) + assign_('Jane',_np.int64(6)) <= 1
#
# RestrSimult_Jane__2,_5,_7_: assign_('Jane',_np.int64(2))
#  + assign_('Jane',_np.int64(5)) + assign_('Jane',_np.int64(7)) <= 1
#
# RestrSimult_Jane__9,_12,_14_: assign_('Jane',_np.int64(12))
#  + assign_('Jane',_np.int64(14)) + assign_('Jane',_np.int64(9)) <= 1
#
# RestrSimult_Jane__10,_13,_15_: assign_('Jane',_np.int64(10))
#  + assign_('Jane',_np.int64(13)) + assign_('Jane',_np.int64(15)) <= 1
#
# RestrSimult_Jane__11,_16_: assign_('Jane',_np.int64(11))
#  + assign_('Jane',_np.int64(16)) <= 1
#
# RestrSimult_Jane__18,_21_: assign_('Jane',_np.int64(18))
#  + assign_('Jane',_np.int64(21)) <= 1
#
# RestrSimult_Jane__19,_22_: assign_('Jane',_np.int64(19))
#  + assign_('Jane',_np.int64(22)) <= 1
#
# RestrSimult_Jane__24,_27_: assign_('Jane',_np.int64(24))
#  + assign_('Jane',_np.int64(27)) <= 1
#
# RestrSimult_Jane__25,_28_: assign_('Jane',_np.int64(25))
#  + assign_('Jane',_np.int64(28)) <= 1
#
# RestrSimult_Jane__30,_33_: assign_('Jane',_np.int64(30))
#  + assign_('Jane',_np.int64(33)) <= 1
#
# RestrSimult_Jane__31,_34_: assign_('Jane',_np.int64(31))
#  + assign_('Jane',_np.int64(34)) <= 1
#
# RestrSimult_Janelle__1,_4,_6_: assign_('Janelle',_np.int64(1))
#  + assign_('Janelle',_np.int64(4)) + assign_('Janelle',_np.int64(6)) <= 1
#
# RestrSimult_Janelle__2,_5,_7_: assign_('Janelle',_np.int64(2))
#  + assign_('Janelle',_np.int64(5)) + assign_('Janelle',_np.int64(7)) <= 1
#
# RestrSimult_Janelle__9,_12,_14_: assign_('Janelle',_np.int64(12))
#  + assign_('Janelle',_np.int64(14)) + assign_('Janelle',_np.int64(9)) <= 1
#
# RestrSimult_Janelle__10,_13,_15_: assign_('Janelle',_np.int64(10))
#  + assign_('Janelle',_np.int64(13)) + assign_('Janelle',_np.int64(15)) <= 1
#
# RestrSimult_Janelle__11,_16_: assign_('Janelle',_np.int64(11))
#  + assign_('Janelle',_np.int64(16)) <= 1
#
# RestrSimult_Janelle__18,_21_: assign_('Janelle',_np.int64(18))
#  + assign_('Janelle',_np.int64(21)) <= 1
#
# RestrSimult_Janelle__19,_22_: assign_('Janelle',_np.int64(19))
#  + assign_('Janelle',_np.int64(22)) <= 1
#
# RestrSimult_Janelle__24,_27_: assign_('Janelle',_np.int64(24))
#  + assign_('Janelle',_np.int64(27)) <= 1
#
# RestrSimult_Janelle__25,_28_: assign_('Janelle',_np.int64(25))
#  + assign_('Janelle',_np.int64(28)) <= 1
#
# RestrSimult_Janelle__30,_33_: assign_('Janelle',_np.int64(30))
#  + assign_('Janelle',_np.int64(33)) <= 1
#
# RestrSimult_Janelle__31,_34_: assign_('Janelle',_np.int64(31))
#  + assign_('Janelle',_np.int64(34)) <= 1
#
# RestrSimult_Janice__1,_4,_6_: assign_('Janice',_np.int64(1))
#  + assign_('Janice',_np.int64(4)) + assign_('Janice',_np.int64(6)) <= 1
#
# RestrSimult_Janice__2,_5,_7_: assign_('Janice',_np.int64(2))
#  + assign_('Janice',_np.int64(5)) + assign_('Janice',_np.int64(7)) <= 1
#
# RestrSimult_Janice__9,_12,_14_: assign_('Janice',_np.int64(12))
#  + assign_('Janice',_np.int64(14)) + assign_('Janice',_np.int64(9)) <= 1
#
# RestrSimult_Janice__10,_13,_15_: assign_('Janice',_np.int64(10))
#  + assign_('Janice',_np.int64(13)) + assign_('Janice',_np.int64(15)) <= 1
#
# RestrSimult_Janice__11,_16_: assign_('Janice',_np.int64(11))
#  + assign_('Janice',_np.int64(16)) <= 1
#
# RestrSimult_Janice__18,_21_: assign_('Janice',_np.int64(18))
#  + assign_('Janice',_np.int64(21)) <= 1
#
# RestrSimult_Janice__19,_22_: assign_('Janice',_np.int64(19))
#  + assign_('Janice',_np.int64(22)) <= 1
#
# RestrSimult_Janice__24,_27_: assign_('Janice',_np.int64(24))
#  + assign_('Janice',_np.int64(27)) <= 1
#
# RestrSimult_Janice__25,_28_: assign_('Janice',_np.int64(25))
#  + assign_('Janice',_np.int64(28)) <= 1
#
# RestrSimult_Janice__30,_33_: assign_('Janice',_np.int64(30))
#  + assign_('Janice',_np.int64(33)) <= 1
#
# RestrSimult_Janice__31,_34_: assign_('Janice',_np.int64(31))
#  + assign_('Janice',_np.int64(34)) <= 1
#
# RestrSimult_Jemma__1,_4,_6_: assign_('Jemma',_np.int64(1))
#  + assign_('Jemma',_np.int64(4)) + assign_('Jemma',_np.int64(6)) <= 1
#
# RestrSimult_Jemma__2,_5,_7_: assign_('Jemma',_np.int64(2))
#  + assign_('Jemma',_np.int64(5)) + assign_('Jemma',_np.int64(7)) <= 1
#
# RestrSimult_Jemma__9,_12,_14_: assign_('Jemma',_np.int64(12))
#  + assign_('Jemma',_np.int64(14)) + assign_('Jemma',_np.int64(9)) <= 1
#
# RestrSimult_Jemma__10,_13,_15_: assign_('Jemma',_np.int64(10))
#  + assign_('Jemma',_np.int64(13)) + assign_('Jemma',_np.int64(15)) <= 1
#
# RestrSimult_Jemma__11,_16_: assign_('Jemma',_np.int64(11))
#  + assign_('Jemma',_np.int64(16)) <= 1
#
# RestrSimult_Jemma__18,_21_: assign_('Jemma',_np.int64(18))
#  + assign_('Jemma',_np.int64(21)) <= 1
#
# RestrSimult_Jemma__19,_22_: assign_('Jemma',_np.int64(19))
#  + assign_('Jemma',_np.int64(22)) <= 1
#
# RestrSimult_Jemma__24,_27_: assign_('Jemma',_np.int64(24))
#  + assign_('Jemma',_np.int64(27)) <= 1
#
# RestrSimult_Jemma__25,_28_: assign_('Jemma',_np.int64(25))
#  + assign_('Jemma',_np.int64(28)) <= 1
#
# RestrSimult_Jemma__30,_33_: assign_('Jemma',_np.int64(30))
#  + assign_('Jemma',_np.int64(33)) <= 1
#
# RestrSimult_Jemma__31,_34_: assign_('Jemma',_np.int64(31))
#  + assign_('Jemma',_np.int64(34)) <= 1
#
# RestrSimult_Joan__1,_4,_6_: assign_('Joan',_np.int64(1))
#  + assign_('Joan',_np.int64(4)) + assign_('Joan',_np.int64(6)) <= 1
#
# RestrSimult_Joan__2,_5,_7_: assign_('Joan',_np.int64(2))
#  + assign_('Joan',_np.int64(5)) + assign_('Joan',_np.int64(7)) <= 1
#
# RestrSimult_Joan__9,_12,_14_: assign_('Joan',_np.int64(12))
#  + assign_('Joan',_np.int64(14)) + assign_('Joan',_np.int64(9)) <= 1
#
# RestrSimult_Joan__10,_13,_15_: assign_('Joan',_np.int64(10))
#  + assign_('Joan',_np.int64(13)) + assign_('Joan',_np.int64(15)) <= 1
#
# RestrSimult_Joan__11,_16_: assign_('Joan',_np.int64(11))
#  + assign_('Joan',_np.int64(16)) <= 1
#
# RestrSimult_Joan__18,_21_: assign_('Joan',_np.int64(18))
#  + assign_('Joan',_np.int64(21)) <= 1
#
# RestrSimult_Joan__19,_22_: assign_('Joan',_np.int64(19))
#  + assign_('Joan',_np.int64(22)) <= 1
#
# RestrSimult_Joan__24,_27_: assign_('Joan',_np.int64(24))
#  + assign_('Joan',_np.int64(27)) <= 1
#
# RestrSimult_Joan__25,_28_: assign_('Joan',_np.int64(25))
#  + assign_('Joan',_np.int64(28)) <= 1
#
# RestrSimult_Joan__30,_33_: assign_('Joan',_np.int64(30))
#  + assign_('Joan',_np.int64(33)) <= 1
#
# RestrSimult_Joan__31,_34_: assign_('Joan',_np.int64(31))
#  + assign_('Joan',_np.int64(34)) <= 1
#
# RestrSimult_Joyce__1,_4,_6_: assign_('Joyce',_np.int64(1))
#  + assign_('Joyce',_np.int64(4)) + assign_('Joyce',_np.int64(6)) <= 1
#
# RestrSimult_Joyce__2,_5,_7_: assign_('Joyce',_np.int64(2))
#  + assign_('Joyce',_np.int64(5)) + assign_('Joyce',_np.int64(7)) <= 1
#
# RestrSimult_Joyce__9,_12,_14_: assign_('Joyce',_np.int64(12))
#  + assign_('Joyce',_np.int64(14)) + assign_('Joyce',_np.int64(9)) <= 1
#
# RestrSimult_Joyce__10,_13,_15_: assign_('Joyce',_np.int64(10))
#  + assign_('Joyce',_np.int64(13)) + assign_('Joyce',_np.int64(15)) <= 1
#
# RestrSimult_Joyce__11,_16_: assign_('Joyce',_np.int64(11))
#  + assign_('Joyce',_np.int64(16)) <= 1
#
# RestrSimult_Joyce__18,_21_: assign_('Joyce',_np.int64(18))
#  + assign_('Joyce',_np.int64(21)) <= 1
#
# RestrSimult_Joyce__19,_22_: assign_('Joyce',_np.int64(19))
#  + assign_('Joyce',_np.int64(22)) <= 1
#
# RestrSimult_Joyce__24,_27_: assign_('Joyce',_np.int64(24))
#  + assign_('Joyce',_np.int64(27)) <= 1
#
# RestrSimult_Joyce__25,_28_: assign_('Joyce',_np.int64(25))
#  + assign_('Joyce',_np.int64(28)) <= 1
#
# RestrSimult_Joyce__30,_33_: assign_('Joyce',_np.int64(30))
#  + assign_('Joyce',_np.int64(33)) <= 1
#
# RestrSimult_Joyce__31,_34_: assign_('Joyce',_np.int64(31))
#  + assign_('Joyce',_np.int64(34)) <= 1
#
# RestrSimult_Jude__1,_4,_6_: assign_('Jude',_np.int64(1))
#  + assign_('Jude',_np.int64(4)) + assign_('Jude',_np.int64(6)) <= 1
#
# RestrSimult_Jude__2,_5,_7_: assign_('Jude',_np.int64(2))
#  + assign_('Jude',_np.int64(5)) + assign_('Jude',_np.int64(7)) <= 1
#
# RestrSimult_Jude__9,_12,_14_: assign_('Jude',_np.int64(12))
#  + assign_('Jude',_np.int64(14)) + assign_('Jude',_np.int64(9)) <= 1
#
# RestrSimult_Jude__10,_13,_15_: assign_('Jude',_np.int64(10))
#  + assign_('Jude',_np.int64(13)) + assign_('Jude',_np.int64(15)) <= 1
#
# RestrSimult_Jude__11,_16_: assign_('Jude',_np.int64(11))
#  + assign_('Jude',_np.int64(16)) <= 1
#
# RestrSimult_Jude__18,_21_: assign_('Jude',_np.int64(18))
#  + assign_('Jude',_np.int64(21)) <= 1
#
# RestrSimult_Jude__19,_22_: assign_('Jude',_np.int64(19))
#  + assign_('Jude',_np.int64(22)) <= 1
#
# RestrSimult_Jude__24,_27_: assign_('Jude',_np.int64(24))
#  + assign_('Jude',_np.int64(27)) <= 1
#
# RestrSimult_Jude__25,_28_: assign_('Jude',_np.int64(25))
#  + assign_('Jude',_np.int64(28)) <= 1
#
# RestrSimult_Jude__30,_33_: assign_('Jude',_np.int64(30))
#  + assign_('Jude',_np.int64(33)) <= 1
#
# RestrSimult_Jude__31,_34_: assign_('Jude',_np.int64(31))
#  + assign_('Jude',_np.int64(34)) <= 1
#
# RestrSimult_Julie__1,_4,_6_: assign_('Julie',_np.int64(1))
#  + assign_('Julie',_np.int64(4)) + assign_('Julie',_np.int64(6)) <= 1
#
# RestrSimult_Julie__2,_5,_7_: assign_('Julie',_np.int64(2))
#  + assign_('Julie',_np.int64(5)) + assign_('Julie',_np.int64(7)) <= 1
#
# RestrSimult_Julie__9,_12,_14_: assign_('Julie',_np.int64(12))
#  + assign_('Julie',_np.int64(14)) + assign_('Julie',_np.int64(9)) <= 1
#
# RestrSimult_Julie__10,_13,_15_: assign_('Julie',_np.int64(10))
#  + assign_('Julie',_np.int64(13)) + assign_('Julie',_np.int64(15)) <= 1
#
# RestrSimult_Julie__11,_16_: assign_('Julie',_np.int64(11))
#  + assign_('Julie',_np.int64(16)) <= 1
#
# RestrSimult_Julie__18,_21_: assign_('Julie',_np.int64(18))
#  + assign_('Julie',_np.int64(21)) <= 1
#
# RestrSimult_Julie__19,_22_: assign_('Julie',_np.int64(19))
#  + assign_('Julie',_np.int64(22)) <= 1
#
# RestrSimult_Julie__24,_27_: assign_('Julie',_np.int64(24))
#  + assign_('Julie',_np.int64(27)) <= 1
#
# RestrSimult_Julie__25,_28_: assign_('Julie',_np.int64(25))
#  + assign_('Julie',_np.int64(28)) <= 1
#
# RestrSimult_Julie__30,_33_: assign_('Julie',_np.int64(30))
#  + assign_('Julie',_np.int64(33)) <= 1
#
# RestrSimult_Julie__31,_34_: assign_('Julie',_np.int64(31))
#  + assign_('Julie',_np.int64(34)) <= 1
#
# RestrSimult_Juliet__1,_4,_6_: assign_('Juliet',_np.int64(1))
#  + assign_('Juliet',_np.int64(4)) + assign_('Juliet',_np.int64(6)) <= 1
#
# RestrSimult_Juliet__2,_5,_7_: assign_('Juliet',_np.int64(2))
#  + assign_('Juliet',_np.int64(5)) + assign_('Juliet',_np.int64(7)) <= 1
#
# RestrSimult_Juliet__9,_12,_14_: assign_('Juliet',_np.int64(12))
#  + assign_('Juliet',_np.int64(14)) + assign_('Juliet',_np.int64(9)) <= 1
#
# RestrSimult_Juliet__10,_13,_15_: assign_('Juliet',_np.int64(10))
#  + assign_('Juliet',_np.int64(13)) + assign_('Juliet',_np.int64(15)) <= 1
#
# RestrSimult_Juliet__11,_16_: assign_('Juliet',_np.int64(11))
#  + assign_('Juliet',_np.int64(16)) <= 1
#
# RestrSimult_Juliet__18,_21_: assign_('Juliet',_np.int64(18))
#  + assign_('Juliet',_np.int64(21)) <= 1
#
# RestrSimult_Juliet__19,_22_: assign_('Juliet',_np.int64(19))
#  + assign_('Juliet',_np.int64(22)) <= 1
#
# RestrSimult_Juliet__24,_27_: assign_('Juliet',_np.int64(24))
#  + assign_('Juliet',_np.int64(27)) <= 1
#
# RestrSimult_Juliet__25,_28_: assign_('Juliet',_np.int64(25))
#  + assign_('Juliet',_np.int64(28)) <= 1
#
# RestrSimult_Juliet__30,_33_: assign_('Juliet',_np.int64(30))
#  + assign_('Juliet',_np.int64(33)) <= 1
#
# RestrSimult_Juliet__31,_34_: assign_('Juliet',_np.int64(31))
#  + assign_('Juliet',_np.int64(34)) <= 1
#
# RestrSimult_Kate__1,_4,_6_: assign_('Kate',_np.int64(1))
#  + assign_('Kate',_np.int64(4)) + assign_('Kate',_np.int64(6)) <= 1
#
# RestrSimult_Kate__2,_5,_7_: assign_('Kate',_np.int64(2))
#  + assign_('Kate',_np.int64(5)) + assign_('Kate',_np.int64(7)) <= 1
#
# RestrSimult_Kate__9,_12,_14_: assign_('Kate',_np.int64(12))
#  + assign_('Kate',_np.int64(14)) + assign_('Kate',_np.int64(9)) <= 1
#
# RestrSimult_Kate__10,_13,_15_: assign_('Kate',_np.int64(10))
#  + assign_('Kate',_np.int64(13)) + assign_('Kate',_np.int64(15)) <= 1
#
# RestrSimult_Kate__11,_16_: assign_('Kate',_np.int64(11))
#  + assign_('Kate',_np.int64(16)) <= 1
#
# RestrSimult_Kate__18,_21_: assign_('Kate',_np.int64(18))
#  + assign_('Kate',_np.int64(21)) <= 1
#
# RestrSimult_Kate__19,_22_: assign_('Kate',_np.int64(19))
#  + assign_('Kate',_np.int64(22)) <= 1
#
# RestrSimult_Kate__24,_27_: assign_('Kate',_np.int64(24))
#  + assign_('Kate',_np.int64(27)) <= 1
#
# RestrSimult_Kate__25,_28_: assign_('Kate',_np.int64(25))
#  + assign_('Kate',_np.int64(28)) <= 1
#
# RestrSimult_Kate__30,_33_: assign_('Kate',_np.int64(30))
#  + assign_('Kate',_np.int64(33)) <= 1
#
# RestrSimult_Kate__31,_34_: assign_('Kate',_np.int64(31))
#  + assign_('Kate',_np.int64(34)) <= 1
#
# RestrSimult_Nancy__1,_4,_6_: assign_('Nancy',_np.int64(1))
#  + assign_('Nancy',_np.int64(4)) + assign_('Nancy',_np.int64(6)) <= 1
#
# RestrSimult_Nancy__2,_5,_7_: assign_('Nancy',_np.int64(2))
#  + assign_('Nancy',_np.int64(5)) + assign_('Nancy',_np.int64(7)) <= 1
#
# RestrSimult_Nancy__9,_12,_14_: assign_('Nancy',_np.int64(12))
#  + assign_('Nancy',_np.int64(14)) + assign_('Nancy',_np.int64(9)) <= 1
#
# RestrSimult_Nancy__10,_13,_15_: assign_('Nancy',_np.int64(10))
#  + assign_('Nancy',_np.int64(13)) + assign_('Nancy',_np.int64(15)) <= 1
#
# RestrSimult_Nancy__11,_16_: assign_('Nancy',_np.int64(11))
#  + assign_('Nancy',_np.int64(16)) <= 1
#
# RestrSimult_Nancy__18,_21_: assign_('Nancy',_np.int64(18))
#  + assign_('Nancy',_np.int64(21)) <= 1
#
# RestrSimult_Nancy__19,_22_: assign_('Nancy',_np.int64(19))
#  + assign_('Nancy',_np.int64(22)) <= 1
#
# RestrSimult_Nancy__24,_27_: assign_('Nancy',_np.int64(24))
#  + assign_('Nancy',_np.int64(27)) <= 1
#
# RestrSimult_Nancy__25,_28_: assign_('Nancy',_np.int64(25))
#  + assign_('Nancy',_np.int64(28)) <= 1
#
# RestrSimult_Nancy__30,_33_: assign_('Nancy',_np.int64(30))
#  + assign_('Nancy',_np.int64(33)) <= 1
#
# RestrSimult_Nancy__31,_34_: assign_('Nancy',_np.int64(31))
#  + assign_('Nancy',_np.int64(34)) <= 1
#
# RestrSimult_Nathalie__1,_4,_6_: assign_('Nathalie',_np.int64(1))
#  + assign_('Nathalie',_np.int64(4)) + assign_('Nathalie',_np.int64(6)) <= 1
#
# RestrSimult_Nathalie__2,_5,_7_: assign_('Nathalie',_np.int64(2))
#  + assign_('Nathalie',_np.int64(5)) + assign_('Nathalie',_np.int64(7)) <= 1
#
# RestrSimult_Nathalie__9,_12,_14_: assign_('Nathalie',_np.int64(12))
#  + assign_('Nathalie',_np.int64(14)) + assign_('Nathalie',_np.int64(9)) <= 1
#
# RestrSimult_Nathalie__10,_13,_15_: assign_('Nathalie',_np.int64(10))
#  + assign_('Nathalie',_np.int64(13)) + assign_('Nathalie',_np.int64(15)) <= 1
#
# RestrSimult_Nathalie__11,_16_: assign_('Nathalie',_np.int64(11))
#  + assign_('Nathalie',_np.int64(16)) <= 1
#
# RestrSimult_Nathalie__18,_21_: assign_('Nathalie',_np.int64(18))
#  + assign_('Nathalie',_np.int64(21)) <= 1
#
# RestrSimult_Nathalie__19,_22_: assign_('Nathalie',_np.int64(19))
#  + assign_('Nathalie',_np.int64(22)) <= 1
#
# RestrSimult_Nathalie__24,_27_: assign_('Nathalie',_np.int64(24))
#  + assign_('Nathalie',_np.int64(27)) <= 1
#
# RestrSimult_Nathalie__25,_28_: assign_('Nathalie',_np.int64(25))
#  + assign_('Nathalie',_np.int64(28)) <= 1
#
# RestrSimult_Nathalie__30,_33_: assign_('Nathalie',_np.int64(30))
#  + assign_('Nathalie',_np.int64(33)) <= 1
#
# RestrSimult_Nathalie__31,_34_: assign_('Nathalie',_np.int64(31))
#  + assign_('Nathalie',_np.int64(34)) <= 1
#
# RestrSimult_Nicole__1,_4,_6_: assign_('Nicole',_np.int64(1))
#  + assign_('Nicole',_np.int64(4)) + assign_('Nicole',_np.int64(6)) <= 1
#
# RestrSimult_Nicole__2,_5,_7_: assign_('Nicole',_np.int64(2))
#  + assign_('Nicole',_np.int64(5)) + assign_('Nicole',_np.int64(7)) <= 1
#
# RestrSimult_Nicole__9,_12,_14_: assign_('Nicole',_np.int64(12))
#  + assign_('Nicole',_np.int64(14)) + assign_('Nicole',_np.int64(9)) <= 1
#
# RestrSimult_Nicole__10,_13,_15_: assign_('Nicole',_np.int64(10))
#  + assign_('Nicole',_np.int64(13)) + assign_('Nicole',_np.int64(15)) <= 1
#
# RestrSimult_Nicole__11,_16_: assign_('Nicole',_np.int64(11))
#  + assign_('Nicole',_np.int64(16)) <= 1
#
# RestrSimult_Nicole__18,_21_: assign_('Nicole',_np.int64(18))
#  + assign_('Nicole',_np.int64(21)) <= 1
#
# RestrSimult_Nicole__19,_22_: assign_('Nicole',_np.int64(19))
#  + assign_('Nicole',_np.int64(22)) <= 1
#
# RestrSimult_Nicole__24,_27_: assign_('Nicole',_np.int64(24))
#  + assign_('Nicole',_np.int64(27)) <= 1
#
# RestrSimult_Nicole__25,_28_: assign_('Nicole',_np.int64(25))
#  + assign_('Nicole',_np.int64(28)) <= 1
#
# RestrSimult_Nicole__30,_33_: assign_('Nicole',_np.int64(30))
#  + assign_('Nicole',_np.int64(33)) <= 1
#
# RestrSimult_Nicole__31,_34_: assign_('Nicole',_np.int64(31))
#  + assign_('Nicole',_np.int64(34)) <= 1
#
# RestrSimult_Patricia__1,_4,_6_: assign_('Patricia',_np.int64(1))
#  + assign_('Patricia',_np.int64(4)) + assign_('Patricia',_np.int64(6)) <= 1
#
# RestrSimult_Patricia__2,_5,_7_: assign_('Patricia',_np.int64(2))
#  + assign_('Patricia',_np.int64(5)) + assign_('Patricia',_np.int64(7)) <= 1
#
# RestrSimult_Patricia__9,_12,_14_: assign_('Patricia',_np.int64(12))
#  + assign_('Patricia',_np.int64(14)) + assign_('Patricia',_np.int64(9)) <= 1
#
# RestrSimult_Patricia__10,_13,_15_: assign_('Patricia',_np.int64(10))
#  + assign_('Patricia',_np.int64(13)) + assign_('Patricia',_np.int64(15)) <= 1
#
# RestrSimult_Patricia__11,_16_: assign_('Patricia',_np.int64(11))
#  + assign_('Patricia',_np.int64(16)) <= 1
#
# RestrSimult_Patricia__18,_21_: assign_('Patricia',_np.int64(18))
#  + assign_('Patricia',_np.int64(21)) <= 1
#
# RestrSimult_Patricia__19,_22_: assign_('Patricia',_np.int64(19))
#  + assign_('Patricia',_np.int64(22)) <= 1
#
# RestrSimult_Patricia__24,_27_: assign_('Patricia',_np.int64(24))
#  + assign_('Patricia',_np.int64(27)) <= 1
#
# RestrSimult_Patricia__25,_28_: assign_('Patricia',_np.int64(25))
#  + assign_('Patricia',_np.int64(28)) <= 1
#
# RestrSimult_Patricia__30,_33_: assign_('Patricia',_np.int64(30))
#  + assign_('Patricia',_np.int64(33)) <= 1
#
# RestrSimult_Patricia__31,_34_: assign_('Patricia',_np.int64(31))
#  + assign_('Patricia',_np.int64(34)) <= 1
#
# RestrSimult_Patrick__1,_4,_6_: assign_('Patrick',_np.int64(1))
#  + assign_('Patrick',_np.int64(4)) + assign_('Patrick',_np.int64(6)) <= 1
#
# RestrSimult_Patrick__2,_5,_7_: assign_('Patrick',_np.int64(2))
#  + assign_('Patrick',_np.int64(5)) + assign_('Patrick',_np.int64(7)) <= 1
#
# RestrSimult_Patrick__9,_12,_14_: assign_('Patrick',_np.int64(12))
#  + assign_('Patrick',_np.int64(14)) + assign_('Patrick',_np.int64(9)) <= 1
#
# RestrSimult_Patrick__10,_13,_15_: assign_('Patrick',_np.int64(10))
#  + assign_('Patrick',_np.int64(13)) + assign_('Patrick',_np.int64(15)) <= 1
#
# RestrSimult_Patrick__11,_16_: assign_('Patrick',_np.int64(11))
#  + assign_('Patrick',_np.int64(16)) <= 1
#
# RestrSimult_Patrick__18,_21_: assign_('Patrick',_np.int64(18))
#  + assign_('Patrick',_np.int64(21)) <= 1
#
# RestrSimult_Patrick__19,_22_: assign_('Patrick',_np.int64(19))
#  + assign_('Patrick',_np.int64(22)) <= 1
#
# RestrSimult_Patrick__24,_27_: assign_('Patrick',_np.int64(24))
#  + assign_('Patrick',_np.int64(27)) <= 1
#
# RestrSimult_Patrick__25,_28_: assign_('Patrick',_np.int64(25))
#  + assign_('Patrick',_np.int64(28)) <= 1
#
# RestrSimult_Patrick__30,_33_: assign_('Patrick',_np.int64(30))
#  + assign_('Patrick',_np.int64(33)) <= 1
#
# RestrSimult_Patrick__31,_34_: assign_('Patrick',_np.int64(31))
#  + assign_('Patrick',_np.int64(34)) <= 1
#
# RestrSimult_Roberta__1,_4,_6_: assign_('Roberta',_np.int64(1))
#  + assign_('Roberta',_np.int64(4)) + assign_('Roberta',_np.int64(6)) <= 1
#
# RestrSimult_Roberta__2,_5,_7_: assign_('Roberta',_np.int64(2))
#  + assign_('Roberta',_np.int64(5)) + assign_('Roberta',_np.int64(7)) <= 1
#
# RestrSimult_Roberta__9,_12,_14_: assign_('Roberta',_np.int64(12))
#  + assign_('Roberta',_np.int64(14)) + assign_('Roberta',_np.int64(9)) <= 1
#
# RestrSimult_Roberta__10,_13,_15_: assign_('Roberta',_np.int64(10))
#  + assign_('Roberta',_np.int64(13)) + assign_('Roberta',_np.int64(15)) <= 1
#
# RestrSimult_Roberta__11,_16_: assign_('Roberta',_np.int64(11))
#  + assign_('Roberta',_np.int64(16)) <= 1
#
# RestrSimult_Roberta__18,_21_: assign_('Roberta',_np.int64(18))
#  + assign_('Roberta',_np.int64(21)) <= 1
#
# RestrSimult_Roberta__19,_22_: assign_('Roberta',_np.int64(19))
#  + assign_('Roberta',_np.int64(22)) <= 1
#
# RestrSimult_Roberta__24,_27_: assign_('Roberta',_np.int64(24))
#  + assign_('Roberta',_np.int64(27)) <= 1
#
# RestrSimult_Roberta__25,_28_: assign_('Roberta',_np.int64(25))
#  + assign_('Roberta',_np.int64(28)) <= 1
#
# RestrSimult_Roberta__30,_33_: assign_('Roberta',_np.int64(30))
#  + assign_('Roberta',_np.int64(33)) <= 1
#
# RestrSimult_Roberta__31,_34_: assign_('Roberta',_np.int64(31))
#  + assign_('Roberta',_np.int64(34)) <= 1
#
# RestrSimult_Suzanne__1,_4,_6_: assign_('Suzanne',_np.int64(1))
#  + assign_('Suzanne',_np.int64(4)) + assign_('Suzanne',_np.int64(6)) <= 1
#
# RestrSimult_Suzanne__2,_5,_7_: assign_('Suzanne',_np.int64(2))
#  + assign_('Suzanne',_np.int64(5)) + assign_('Suzanne',_np.int64(7)) <= 1
#
# RestrSimult_Suzanne__9,_12,_14_: assign_('Suzanne',_np.int64(12))
#  + assign_('Suzanne',_np.int64(14)) + assign_('Suzanne',_np.int64(9)) <= 1
#
# RestrSimult_Suzanne__10,_13,_15_: assign_('Suzanne',_np.int64(10))
#  + assign_('Suzanne',_np.int64(13)) + assign_('Suzanne',_np.int64(15)) <= 1
#
# RestrSimult_Suzanne__11,_16_: assign_('Suzanne',_np.int64(11))
#  + assign_('Suzanne',_np.int64(16)) <= 1
#
# RestrSimult_Suzanne__18,_21_: assign_('Suzanne',_np.int64(18))
#  + assign_('Suzanne',_np.int64(21)) <= 1
#
# RestrSimult_Suzanne__19,_22_: assign_('Suzanne',_np.int64(19))
#  + assign_('Suzanne',_np.int64(22)) <= 1
#
# RestrSimult_Suzanne__24,_27_: assign_('Suzanne',_np.int64(24))
#  + assign_('Suzanne',_np.int64(27)) <= 1
#
# RestrSimult_Suzanne__25,_28_: assign_('Suzanne',_np.int64(25))
#  + assign_('Suzanne',_np.int64(28)) <= 1
#
# RestrSimult_Suzanne__30,_33_: assign_('Suzanne',_np.int64(30))
#  + assign_('Suzanne',_np.int64(33)) <= 1
#
# RestrSimult_Suzanne__31,_34_: assign_('Suzanne',_np.int64(31))
#  + assign_('Suzanne',_np.int64(34)) <= 1
#
# RestrSimult_Vickie__1,_4,_6_: assign_('Vickie',_np.int64(1))
#  + assign_('Vickie',_np.int64(4)) + assign_('Vickie',_np.int64(6)) <= 1
#
# RestrSimult_Vickie__2,_5,_7_: assign_('Vickie',_np.int64(2))
#  + assign_('Vickie',_np.int64(5)) + assign_('Vickie',_np.int64(7)) <= 1
#
# RestrSimult_Vickie__9,_12,_14_: assign_('Vickie',_np.int64(12))
#  + assign_('Vickie',_np.int64(14)) + assign_('Vickie',_np.int64(9)) <= 1
#
# RestrSimult_Vickie__10,_13,_15_: assign_('Vickie',_np.int64(10))
#  + assign_('Vickie',_np.int64(13)) + assign_('Vickie',_np.int64(15)) <= 1
#
# RestrSimult_Vickie__11,_16_: assign_('Vickie',_np.int64(11))
#  + assign_('Vickie',_np.int64(16)) <= 1
#
# RestrSimult_Vickie__18,_21_: assign_('Vickie',_np.int64(18))
#  + assign_('Vickie',_np.int64(21)) <= 1
#
# RestrSimult_Vickie__19,_22_: assign_('Vickie',_np.int64(19))
#  + assign_('Vickie',_np.int64(22)) <= 1
#
# RestrSimult_Vickie__24,_27_: assign_('Vickie',_np.int64(24))
#  + assign_('Vickie',_np.int64(27)) <= 1
#
# RestrSimult_Vickie__25,_28_: assign_('Vickie',_np.int64(25))
#  + assign_('Vickie',_np.int64(28)) <= 1
#
# RestrSimult_Vickie__30,_33_: assign_('Vickie',_np.int64(30))
#  + assign_('Vickie',_np.int64(33)) <= 1
#
# RestrSimult_Vickie__31,_34_: assign_('Vickie',_np.int64(31))
#  + assign_('Vickie',_np.int64(34)) <= 1
#
# RestrSimult_Wendie__1,_4,_6_: assign_('Wendie',_np.int64(1))
#  + assign_('Wendie',_np.int64(4)) + assign_('Wendie',_np.int64(6)) <= 1
#
# RestrSimult_Wendie__2,_5,_7_: assign_('Wendie',_np.int64(2))
#  + assign_('Wendie',_np.int64(5)) + assign_('Wendie',_np.int64(7)) <= 1
#
# RestrSimult_Wendie__9,_12,_14_: assign_('Wendie',_np.int64(12))
#  + assign_('Wendie',_np.int64(14)) + assign_('Wendie',_np.int64(9)) <= 1
#
# RestrSimult_Wendie__10,_13,_15_: assign_('Wendie',_np.int64(10))
#  + assign_('Wendie',_np.int64(13)) + assign_('Wendie',_np.int64(15)) <= 1
#
# RestrSimult_Wendie__11,_16_: assign_('Wendie',_np.int64(11))
#  + assign_('Wendie',_np.int64(16)) <= 1
#
# RestrSimult_Wendie__18,_21_: assign_('Wendie',_np.int64(18))
#  + assign_('Wendie',_np.int64(21)) <= 1
#
# RestrSimult_Wendie__19,_22_: assign_('Wendie',_np.int64(19))
#  + assign_('Wendie',_np.int64(22)) <= 1
#
# RestrSimult_Wendie__24,_27_: assign_('Wendie',_np.int64(24))
#  + assign_('Wendie',_np.int64(27)) <= 1
#
# RestrSimult_Wendie__25,_28_: assign_('Wendie',_np.int64(25))
#  + assign_('Wendie',_np.int64(28)) <= 1
#
# RestrSimult_Wendie__30,_33_: assign_('Wendie',_np.int64(30))
#  + assign_('Wendie',_np.int64(33)) <= 1
#
# RestrSimult_Wendie__31,_34_: assign_('Wendie',_np.int64(31))
#  + assign_('Wendie',_np.int64(34)) <= 1
#
# RestrSimult_Zoe__1,_4,_6_: assign_('Zoe',_np.int64(1))
#  + assign_('Zoe',_np.int64(4)) + assign_('Zoe',_np.int64(6)) <= 1
#
# RestrSimult_Zoe__2,_5,_7_: assign_('Zoe',_np.int64(2))
#  + assign_('Zoe',_np.int64(5)) + assign_('Zoe',_np.int64(7)) <= 1
#
# RestrSimult_Zoe__9,_12,_14_: assign_('Zoe',_np.int64(12))
#  + assign_('Zoe',_np.int64(14)) + assign_('Zoe',_np.int64(9)) <= 1
#
# RestrSimult_Zoe__10,_13,_15_: assign_('Zoe',_np.int64(10))
#  + assign_('Zoe',_np.int64(13)) + assign_('Zoe',_np.int64(15)) <= 1
#
# RestrSimult_Zoe__11,_16_: assign_('Zoe',_np.int64(11))
#  + assign_('Zoe',_np.int64(16)) <= 1
#
# RestrSimult_Zoe__18,_21_: assign_('Zoe',_np.int64(18))
#  + assign_('Zoe',_np.int64(21)) <= 1
#
# RestrSimult_Zoe__19,_22_: assign_('Zoe',_np.int64(19))
#  + assign_('Zoe',_np.int64(22)) <= 1
#
# RestrSimult_Zoe__24,_27_: assign_('Zoe',_np.int64(24))
#  + assign_('Zoe',_np.int64(27)) <= 1
#
# RestrSimult_Zoe__25,_28_: assign_('Zoe',_np.int64(25))
#  + assign_('Zoe',_np.int64(28)) <= 1
#
# RestrSimult_Zoe__30,_33_: assign_('Zoe',_np.int64(30))
#  + assign_('Zoe',_np.int64(33)) <= 1
#
# RestrSimult_Zoe__31,_34_: assign_('Zoe',_np.int64(31))
#  + assign_('Zoe',_np.int64(34)) <= 1
#
# Worktime_Anne: 6 assign_('Anne',_np.int64(0)) + 4 assign_('Anne',_np.int64(1))
#  + 6 assign_('Anne',_np.int64(10)) + 8 assign_('Anne',_np.int64(11))
#  + 4 assign_('Anne',_np.int64(12)) + 6 assign_('Anne',_np.int64(13))
#  + 4 assign_('Anne',_np.int64(14)) + 6 assign_('Anne',_np.int64(15))
#  + 8 assign_('Anne',_np.int64(16)) + 6 assign_('Anne',_np.int64(17))
#  + 4 assign_('Anne',_np.int64(18)) + 6 assign_('Anne',_np.int64(19))
#  + 6 assign_('Anne',_np.int64(2)) + 8 assign_('Anne',_np.int64(20))
#  + 4 assign_('Anne',_np.int64(21)) + 6 assign_('Anne',_np.int64(22))
#  + 6 assign_('Anne',_np.int64(23)) + 4 assign_('Anne',_np.int64(24))
#  + 6 assign_('Anne',_np.int64(25)) + 8 assign_('Anne',_np.int64(26))
#  + 4 assign_('Anne',_np.int64(27)) + 6 assign_('Anne',_np.int64(28))
#  + 6 assign_('Anne',_np.int64(29)) + 8 assign_('Anne',_np.int64(3))
#  + 4 assign_('Anne',_np.int64(30)) + 6 assign_('Anne',_np.int64(31))
#  + 8 assign_('Anne',_np.int64(32)) + 4 assign_('Anne',_np.int64(33))
#  + 6 assign_('Anne',_np.int64(34)) + 10 assign_('Anne',_np.int64(35))
#  + 8 assign_('Anne',_np.int64(36)) + 6 assign_('Anne',_np.int64(37))
#  + 10 assign_('Anne',_np.int64(38)) + 8 assign_('Anne',_np.int64(39))
#  + 4 assign_('Anne',_np.int64(4)) + 6 assign_('Anne',_np.int64(40))
#  + 2 assign_('Anne',_np.int64(41)) + 6 assign_('Anne',_np.int64(5))
#  + 4 assign_('Anne',_np.int64(6)) + 6 assign_('Anne',_np.int64(7))
#  + 6 assign_('Anne',_np.int64(8)) + 4 assign_('Anne',_np.int64(9)) <= 40
#
# Worktime_Bethanie: 6 assign_('Bethanie',_np.int64(0))
#  + 4 assign_('Bethanie',_np.int64(1)) + 6 assign_('Bethanie',_np.int64(10))
#  + 8 assign_('Bethanie',_np.int64(11)) + 4 assign_('Bethanie',_np.int64(12))
#  + 6 assign_('Bethanie',_np.int64(13)) + 4 assign_('Bethanie',_np.int64(14))
#  + 6 assign_('Bethanie',_np.int64(15)) + 8 assign_('Bethanie',_np.int64(16))
#  + 6 assign_('Bethanie',_np.int64(17)) + 4 assign_('Bethanie',_np.int64(18))
#  + 6 assign_('Bethanie',_np.int64(19)) + 6 assign_('Bethanie',_np.int64(2))
#  + 8 assign_('Bethanie',_np.int64(20)) + 4 assign_('Bethanie',_np.int64(21))
#  + 6 assign_('Bethanie',_np.int64(22)) + 6 assign_('Bethanie',_np.int64(23))
#  + 4 assign_('Bethanie',_np.int64(24)) + 6 assign_('Bethanie',_np.int64(25))
#  + 8 assign_('Bethanie',_np.int64(26)) + 4 assign_('Bethanie',_np.int64(27))
#  + 6 assign_('Bethanie',_np.int64(28)) + 6 assign_('Bethanie',_np.int64(29))
#  + 8 assign_('Bethanie',_np.int64(3)) + 4 assign_('Bethanie',_np.int64(30))
#  + 6 assign_('Bethanie',_np.int64(31)) + 8 assign_('Bethanie',_np.int64(32))
#  + 4 assign_('Bethanie',_np.int64(33)) + 6 assign_('Bethanie',_np.int64(34))
#  + 10 assign_('Bethanie',_np.int64(35)) + 8 assign_('Bethanie',_np.int64(36))
#  + 6 assign_('Bethanie',_np.int64(37)) + 10 assign_('Bethanie',_np.int64(38))
#  + 8 assign_('Bethanie',_np.int64(39)) + 4 assign_('Bethanie',_np.int64(4))
#  + 6 assign_('Bethanie',_np.int64(40)) + 2 assign_('Bethanie',_np.int64(41))
#  + 6 assign_('Bethanie',_np.int64(5)) + 4 assign_('Bethanie',_np.int64(6))
#  + 6 assign_('Bethanie',_np.int64(7)) + 6 assign_('Bethanie',_np.int64(8))
#  + 4 assign_('Bethanie',_np.int64(9)) <= 40
#
# Worktime_Betsy: 6 assign_('Betsy',_np.int64(0))
#  + 4 assign_('Betsy',_np.int64(1)) + 6 assign_('Betsy',_np.int64(10))
#  + 8 assign_('Betsy',_np.int64(11)) + 4 assign_('Betsy',_np.int64(12))
#  + 6 assign_('Betsy',_np.int64(13)) + 4 assign_('Betsy',_np.int64(14))
#  + 6 assign_('Betsy',_np.int64(15)) + 8 assign_('Betsy',_np.int64(16))
#  + 6 assign_('Betsy',_np.int64(17)) + 4 assign_('Betsy',_np.int64(18))
#  + 6 assign_('Betsy',_np.int64(19)) + 6 assign_('Betsy',_np.int64(2))
#  + 8 assign_('Betsy',_np.int64(20)) + 4 assign_('Betsy',_np.int64(21))
#  + 6 assign_('Betsy',_np.int64(22)) + 6 assign_('Betsy',_np.int64(23))
#  + 4 assign_('Betsy',_np.int64(24)) + 6 assign_('Betsy',_np.int64(25))
#  + 8 assign_('Betsy',_np.int64(26)) + 4 assign_('Betsy',_np.int64(27))
#  + 6 assign_('Betsy',_np.int64(28)) + 6 assign_('Betsy',_np.int64(29))
#  + 8 assign_('Betsy',_np.int64(3)) + 4 assign_('Betsy',_np.int64(30))
#  + 6 assign_('Betsy',_np.int64(31)) + 8 assign_('Betsy',_np.int64(32))
# ...
# 0 <= assign_('Nicole',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(9)) <= 1 Integer

# %%
import time;

resultado = []

inicio = time.time()
prob.solve()
fim = time.time()
tempo_execucao = fim - inicio
resultado_objetivo = prob.objective.value()

resultado.append({
"Solver": "PULP_CBC_CMD",
"Tempo de Execução (s)": tempo_execucao,
"Valor da Função Objetivo": resultado_objetivo,
"Status": prob.status
})
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/magnofonseca/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/a15e2624176d4a65a33daef890fd3f2f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /tmp/a15e2624176d4a65a33daef890fd3f2f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 2297 COLUMNS
# At line 14842 RHS
# At line 17135 BOUNDS
# At line 18480 ENDATA
# Problem MODEL has 2292 rows, 1344 columns and 8512 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 29508 - 0.03 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 890 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 787 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 532 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 155 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 42 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 32 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 23 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0004I processed model has 746 rows, 1344 columns (1344 integer (1344 of which binary)) and 4768 elements
# Cutoff increment increased from 1e-05 to 1.9999
# Cbc0038I Initial state - 38 integers unsatisfied sum - 13.9667
# Cbc0038I Pass   1: suminf.    6.46667 (22) obj. 29724 iterations 148
# Cbc0038I Pass   2: suminf.    5.96667 (21) obj. 29724 iterations 38
# Cbc0038I Pass   3: suminf.    5.60000 (21) obj. 29744 iterations 92
# Cbc0038I Pass   4: suminf.    5.10000 (19) obj. 29698 iterations 62
# Cbc0038I Pass   5: suminf.    5.10000 (19) obj. 29638 iterations 9
# Cbc0038I Pass   6: suminf.    5.10000 (19) obj. 29678 iterations 70
# Cbc0038I Pass   7: suminf.    4.60000 (18) obj. 29678 iterations 63
# Cbc0038I Pass   8: suminf.    4.60000 (18) obj. 29678 iterations 1
# Cbc0038I Pass   9: suminf.    5.80000 (20) obj. 29734 iterations 100
# Cbc0038I Pass  10: suminf.    5.60000 (20) obj. 29706 iterations 33
# Cbc0038I Pass  11: suminf.    5.20000 (19) obj. 29706 iterations 5
# Cbc0038I Pass  12: suminf.    5.80000 (21) obj. 29739.6 iterations 77
# Cbc0038I Pass  13: suminf.    3.90000 (16) obj. 29688 iterations 71
# Cbc0038I Pass  14: suminf.    3.90000 (16) obj. 29688 iterations 3
# Cbc0038I Pass  15: suminf.    3.90000 (16) obj. 29688 iterations 81
# Cbc0038I Pass  16: suminf.   17.57917 (60) obj. 30040 iterations 458
# Cbc0038I Pass  17: suminf.    7.00000 (24) obj. 30040 iterations 186
# Cbc0038I Pass  18: suminf.    7.00000 (24) obj. 30040 iterations 11
# Cbc0038I Pass  19: suminf.    8.46667 (26) obj. 29874 iterations 178
# Cbc0038I Pass  20: suminf.    7.10000 (22) obj. 29860 iterations 63
# Cbc0038I Pass  21: suminf.    7.10000 (22) obj. 29860 iterations 21
# Cbc0038I Pass  22: suminf.    5.40000 (18) obj. 29874 iterations 97
# Cbc0038I Pass  23: suminf.    5.40000 (18) obj. 29874 iterations 92
# Cbc0038I Pass  24: suminf.    5.80000 (19) obj. 29852 iterations 128
# Cbc0038I Pass  25: suminf.    5.40000 (19) obj. 29844 iterations 73
# Cbc0038I Pass  26: suminf.    5.90000 (19) obj. 29844 iterations 86
# Cbc0038I Pass  27: suminf.    5.90000 (19) obj. 29844 iterations 41
# Cbc0038I Pass  28: suminf.    5.40000 (19) obj. 29844 iterations 68
# Cbc0038I Pass  29: suminf.   16.38531 (59) obj. 30040 iterations 408
# Cbc0038I Pass  30: suminf.    6.60000 (20) obj. 30040 iterations 192
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 921 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 746 rows 1344 columns, reduced to 231 rows 423 columns
# Cbc0038I Mini branch and bound did not improve solution (0.75 seconds)
# Cbc0038I Full problem 747 rows 1344 columns, reduced to 747 rows 1344 columns - too large
# Cbc0038I After 0.78 seconds - Feasibility pump exiting - took 0.48 seconds
# Cbc0031I 11 added rows had average density of 147.36364
# Cbc0013I At root node, 11 cuts changed objective from 29508 to 29508 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.028 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 142 row cuts average 528.4 elements, 0 column cuts (0 active)  in 0.085 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 60 row cuts average 25.6 elements, 0 column cuts (0 active)  in 0.019 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 76 row cuts average 114.8 elements, 0 column cuts (0 active)  in 0.019 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 56 row cuts average 47.1 elements, 0 column cuts (0 active)  in 0.032 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 29508 (1.23 seconds)
# Cbc0012I Integer solution of 29558 found by DiveCoefficient after 964 iterations and 1 nodes (1.24 seconds)
# Cbc0038I Full problem 746 rows 1344 columns, reduced to 39 rows 49 columns
# Cbc0016I Integer solution of 29508 found by strong branching after 2191 iterations and 76 nodes (2.05 seconds)
# Cbc0001I Search completed - best objective 29508, took 2191 iterations and 76 nodes (2.05 seconds)
# Cbc0032I Strong branching done 350 times (2829 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 33, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 29508 to 29508
# Probing was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.028 seconds)
# Gomory was tried 10 times and created 142 cuts of which 0 were active after adding rounds of cuts (0.085 seconds)
# Knapsack was tried 10 times and created 60 cuts of which 0 were active after adding rounds of cuts (0.019 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# FlowCover was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 10 times and created 76 cuts of which 0 were active after adding rounds of cuts (0.019 seconds)
# ZeroHalf was tried 10 times and created 56 cuts of which 0 were active after adding rounds of cuts (0.032 seconds)
#
# Result - Optimal solution found
#
# Objective value:                29508.00000000
# Enumerated nodes:               76
# Total iterations:               2191
# Time (CPU seconds):             1.84
# Time (Wallclock seconds):       2.09
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.86   (Wallclock seconds):       2.11

# %%
prob
# Out:
# nurses:
# MINIMIZE
# 150*assign_('Anne',_np.int64(0)) + 100*assign_('Anne',_np.int64(1)) + 150*assign_('Anne',_np.int64(10)) + 200*assign_('Anne',_np.int64(11)) + 100*assign_('Anne',_np.int64(12)) + 150*assign_('Anne',_np.int64(13)) + 100*assign_('Anne',_np.int64(14)) + 150*assign_('Anne',_np.int64(15)) + 200*assign_('Anne',_np.int64(16)) + 150*assign_('Anne',_np.int64(17)) + 100*assign_('Anne',_np.int64(18)) + 150*assign_('Anne',_np.int64(19)) + 150*assign_('Anne',_np.int64(2)) + 200*assign_('Anne',_np.int64(20)) + 100*assign_('Anne',_np.int64(21)) + 150*assign_('Anne',_np.int64(22)) + 150*assign_('Anne',_np.int64(23)) + 100*assign_('Anne',_np.int64(24)) + 150*assign_('Anne',_np.int64(25)) + 200*assign_('Anne',_np.int64(26)) + 100*assign_('Anne',_np.int64(27)) + 150*assign_('Anne',_np.int64(28)) + 150*assign_('Anne',_np.int64(29)) + 200*assign_('Anne',_np.int64(3)) + 100*assign_('Anne',_np.int64(30)) + 150*assign_('Anne',_np.int64(31)) + 200*assign_('Anne',_np.int64(32)) + 100*assign_('Anne',_np.int64(33)) + 150*assign_('Anne',_np.int64(34)) + 250*assign_('Anne',_np.int64(35)) + 200*assign_('Anne',_np.int64(36)) + 150*assign_('Anne',_np.int64(37)) + 250*assign_('Anne',_np.int64(38)) + 200*assign_('Anne',_np.int64(39)) + 100*assign_('Anne',_np.int64(4)) + 150*assign_('Anne',_np.int64(40)) + 50*assign_('Anne',_np.int64(41)) + 150*assign_('Anne',_np.int64(5)) + 100*assign_('Anne',_np.int64(6)) + 150*assign_('Anne',_np.int64(7)) + 150*assign_('Anne',_np.int64(8)) + 100*assign_('Anne',_np.int64(9)) + 168*assign_('Bethanie',_np.int64(0)) + 112*assign_('Bethanie',_np.int64(1)) + 168*assign_('Bethanie',_np.int64(10)) + 224*assign_('Bethanie',_np.int64(11)) + 112*assign_('Bethanie',_np.int64(12)) + 168*assign_('Bethanie',_np.int64(13)) + 112*assign_('Bethanie',_np.int64(14)) + 168*assign_('Bethanie',_np.int64(15)) + 224*assign_('Bethanie',_np.int64(16)) + 168*assign_('Bethanie',_np.int64(17)) + 112*assign_('Bethanie',_np.int64(18)) + 168*assign_('Bethanie',_np.int64(19)) + 168*assign_('Bethanie',_np.int64(2)) + 224*assign_('Bethanie',_np.int64(20)) + 112*assign_('Bethanie',_np.int64(21)) + 168*assign_('Bethanie',_np.int64(22)) + 168*assign_('Bethanie',_np.int64(23)) + 112*assign_('Bethanie',_np.int64(24)) + 168*assign_('Bethanie',_np.int64(25)) + 224*assign_('Bethanie',_np.int64(26)) + 112*assign_('Bethanie',_np.int64(27)) + 168*assign_('Bethanie',_np.int64(28)) + 168*assign_('Bethanie',_np.int64(29)) + 224*assign_('Bethanie',_np.int64(3)) + 112*assign_('Bethanie',_np.int64(30)) + 168*assign_('Bethanie',_np.int64(31)) + 224*assign_('Bethanie',_np.int64(32)) + 112*assign_('Bethanie',_np.int64(33)) + 168*assign_('Bethanie',_np.int64(34)) + 280*assign_('Bethanie',_np.int64(35)) + 224*assign_('Bethanie',_np.int64(36)) + 168*assign_('Bethanie',_np.int64(37)) + 280*assign_('Bethanie',_np.int64(38)) + 224*assign_('Bethanie',_np.int64(39)) + 112*assign_('Bethanie',_np.int64(4)) + 168*assign_('Bethanie',_np.int64(40)) + 56*assign_('Bethanie',_np.int64(41)) + 168*assign_('Bethanie',_np.int64(5)) + 112*assign_('Bethanie',_np.int64(6)) + 168*assign_('Bethanie',_np.int64(7)) + 168*assign_('Bethanie',_np.int64(8)) + 112*assign_('Bethanie',_np.int64(9)) + 102*assign_('Betsy',_np.int64(0)) + 68*assign_('Betsy',_np.int64(1)) + 102*assign_('Betsy',_np.int64(10)) + 136*assign_('Betsy',_np.int64(11)) + 68*assign_('Betsy',_np.int64(12)) + 102*assign_('Betsy',_np.int64(13)) + 68*assign_('Betsy',_np.int64(14)) + 102*assign_('Betsy',_np.int64(15)) + 136*assign_('Betsy',_np.int64(16)) + 102*assign_('Betsy',_np.int64(17)) + 68*assign_('Betsy',_np.int64(18)) + 102*assign_('Betsy',_np.int64(19)) + 102*assign_('Betsy',_np.int64(2)) + 136*assign_('Betsy',_np.int64(20)) + 68*assign_('Betsy',_np.int64(21)) + 102*assign_('Betsy',_np.int64(22)) + 102*assign_('Betsy',_np.int64(23)) + 68*assign_('Betsy',_np.int64(24)) + 102*assign_('Betsy',_np.int64(25)) + 136*assign_('Betsy',_np.int64(26)) + 68*assign_('Betsy',_np.int64(27)) + 102*assign_('Betsy',_np.int64(28)) + 102*assign_('Betsy',_np.in ...
# SUBJECT TO
# RestrSimult_Anne__1,_4,_6_: assign_('Anne',_np.int64(1))
#  + assign_('Anne',_np.int64(4)) + assign_('Anne',_np.int64(6)) <= 1
#
# RestrSimult_Anne__2,_5,_7_: assign_('Anne',_np.int64(2))
#  + assign_('Anne',_np.int64(5)) + assign_('Anne',_np.int64(7)) <= 1
#
# RestrSimult_Anne__9,_12,_14_: assign_('Anne',_np.int64(12))
#  + assign_('Anne',_np.int64(14)) + assign_('Anne',_np.int64(9)) <= 1
#
# RestrSimult_Anne__10,_13,_15_: assign_('Anne',_np.int64(10))
#  + assign_('Anne',_np.int64(13)) + assign_('Anne',_np.int64(15)) <= 1
#
# RestrSimult_Anne__11,_16_: assign_('Anne',_np.int64(11))
#  + assign_('Anne',_np.int64(16)) <= 1
#
# RestrSimult_Anne__18,_21_: assign_('Anne',_np.int64(18))
#  + assign_('Anne',_np.int64(21)) <= 1
#
# RestrSimult_Anne__19,_22_: assign_('Anne',_np.int64(19))
#  + assign_('Anne',_np.int64(22)) <= 1
#
# RestrSimult_Anne__24,_27_: assign_('Anne',_np.int64(24))
#  + assign_('Anne',_np.int64(27)) <= 1
#
# RestrSimult_Anne__25,_28_: assign_('Anne',_np.int64(25))
#  + assign_('Anne',_np.int64(28)) <= 1
#
# RestrSimult_Anne__30,_33_: assign_('Anne',_np.int64(30))
#  + assign_('Anne',_np.int64(33)) <= 1
#
# RestrSimult_Anne__31,_34_: assign_('Anne',_np.int64(31))
#  + assign_('Anne',_np.int64(34)) <= 1
#
# RestrSimult_Bethanie__1,_4,_6_: assign_('Bethanie',_np.int64(1))
#  + assign_('Bethanie',_np.int64(4)) + assign_('Bethanie',_np.int64(6)) <= 1
#
# RestrSimult_Bethanie__2,_5,_7_: assign_('Bethanie',_np.int64(2))
#  + assign_('Bethanie',_np.int64(5)) + assign_('Bethanie',_np.int64(7)) <= 1
#
# RestrSimult_Bethanie__9,_12,_14_: assign_('Bethanie',_np.int64(12))
#  + assign_('Bethanie',_np.int64(14)) + assign_('Bethanie',_np.int64(9)) <= 1
#
# RestrSimult_Bethanie__10,_13,_15_: assign_('Bethanie',_np.int64(10))
#  + assign_('Bethanie',_np.int64(13)) + assign_('Bethanie',_np.int64(15)) <= 1
#
# RestrSimult_Bethanie__11,_16_: assign_('Bethanie',_np.int64(11))
#  + assign_('Bethanie',_np.int64(16)) <= 1
#
# RestrSimult_Bethanie__18,_21_: assign_('Bethanie',_np.int64(18))
#  + assign_('Bethanie',_np.int64(21)) <= 1
#
# RestrSimult_Bethanie__19,_22_: assign_('Bethanie',_np.int64(19))
#  + assign_('Bethanie',_np.int64(22)) <= 1
#
# RestrSimult_Bethanie__24,_27_: assign_('Bethanie',_np.int64(24))
#  + assign_('Bethanie',_np.int64(27)) <= 1
#
# RestrSimult_Bethanie__25,_28_: assign_('Bethanie',_np.int64(25))
#  + assign_('Bethanie',_np.int64(28)) <= 1
#
# RestrSimult_Bethanie__30,_33_: assign_('Bethanie',_np.int64(30))
#  + assign_('Bethanie',_np.int64(33)) <= 1
#
# RestrSimult_Bethanie__31,_34_: assign_('Bethanie',_np.int64(31))
#  + assign_('Bethanie',_np.int64(34)) <= 1
#
# RestrSimult_Betsy__1,_4,_6_: assign_('Betsy',_np.int64(1))
#  + assign_('Betsy',_np.int64(4)) + assign_('Betsy',_np.int64(6)) <= 1
#
# RestrSimult_Betsy__2,_5,_7_: assign_('Betsy',_np.int64(2))
#  + assign_('Betsy',_np.int64(5)) + assign_('Betsy',_np.int64(7)) <= 1
#
# RestrSimult_Betsy__9,_12,_14_: assign_('Betsy',_np.int64(12))
#  + assign_('Betsy',_np.int64(14)) + assign_('Betsy',_np.int64(9)) <= 1
#
# RestrSimult_Betsy__10,_13,_15_: assign_('Betsy',_np.int64(10))
#  + assign_('Betsy',_np.int64(13)) + assign_('Betsy',_np.int64(15)) <= 1
#
# RestrSimult_Betsy__11,_16_: assign_('Betsy',_np.int64(11))
#  + assign_('Betsy',_np.int64(16)) <= 1
#
# RestrSimult_Betsy__18,_21_: assign_('Betsy',_np.int64(18))
#  + assign_('Betsy',_np.int64(21)) <= 1
#
# RestrSimult_Betsy__19,_22_: assign_('Betsy',_np.int64(19))
#  + assign_('Betsy',_np.int64(22)) <= 1
#
# RestrSimult_Betsy__24,_27_: assign_('Betsy',_np.int64(24))
#  + assign_('Betsy',_np.int64(27)) <= 1
#
# RestrSimult_Betsy__25,_28_: assign_('Betsy',_np.int64(25))
#  + assign_('Betsy',_np.int64(28)) <= 1
#
# RestrSimult_Betsy__30,_33_: assign_('Betsy',_np.int64(30))
#  + assign_('Betsy',_np.int64(33)) <= 1
#
# RestrSimult_Betsy__31,_34_: assign_('Betsy',_np.int64(31))
#  + assign_('Betsy',_np.int64(34)) <= 1
#
# RestrSimult_Cathy__1,_4,_6_: assign_('Cathy',_np.int64(1))
#  + assign_('Cathy',_np.int64(4)) + assign_('Cathy',_np.int64(6)) <= 1
#
# RestrSimult_Cathy__2,_5,_7_: assign_('Cathy',_np.int64(2))
#  + assign_('Cathy',_np.int64(5)) + assign_('Cathy',_np.int64(7)) <= 1
#
# RestrSimult_Cathy__9,_12,_14_: assign_('Cathy',_np.int64(12))
#  + assign_('Cathy',_np.int64(14)) + assign_('Cathy',_np.int64(9)) <= 1
#
# RestrSimult_Cathy__10,_13,_15_: assign_('Cathy',_np.int64(10))
#  + assign_('Cathy',_np.int64(13)) + assign_('Cathy',_np.int64(15)) <= 1
#
# RestrSimult_Cathy__11,_16_: assign_('Cathy',_np.int64(11))
#  + assign_('Cathy',_np.int64(16)) <= 1
#
# RestrSimult_Cathy__18,_21_: assign_('Cathy',_np.int64(18))
#  + assign_('Cathy',_np.int64(21)) <= 1
#
# RestrSimult_Cathy__19,_22_: assign_('Cathy',_np.int64(19))
#  + assign_('Cathy',_np.int64(22)) <= 1
#
# RestrSimult_Cathy__24,_27_: assign_('Cathy',_np.int64(24))
#  + assign_('Cathy',_np.int64(27)) <= 1
#
# RestrSimult_Cathy__25,_28_: assign_('Cathy',_np.int64(25))
#  + assign_('Cathy',_np.int64(28)) <= 1
#
# RestrSimult_Cathy__30,_33_: assign_('Cathy',_np.int64(30))
#  + assign_('Cathy',_np.int64(33)) <= 1
#
# RestrSimult_Cathy__31,_34_: assign_('Cathy',_np.int64(31))
#  + assign_('Cathy',_np.int64(34)) <= 1
#
# RestrSimult_Cecilia__1,_4,_6_: assign_('Cecilia',_np.int64(1))
#  + assign_('Cecilia',_np.int64(4)) + assign_('Cecilia',_np.int64(6)) <= 1
#
# RestrSimult_Cecilia__2,_5,_7_: assign_('Cecilia',_np.int64(2))
#  + assign_('Cecilia',_np.int64(5)) + assign_('Cecilia',_np.int64(7)) <= 1
#
# RestrSimult_Cecilia__9,_12,_14_: assign_('Cecilia',_np.int64(12))
#  + assign_('Cecilia',_np.int64(14)) + assign_('Cecilia',_np.int64(9)) <= 1
#
# RestrSimult_Cecilia__10,_13,_15_: assign_('Cecilia',_np.int64(10))
#  + assign_('Cecilia',_np.int64(13)) + assign_('Cecilia',_np.int64(15)) <= 1
#
# RestrSimult_Cecilia__11,_16_: assign_('Cecilia',_np.int64(11))
#  + assign_('Cecilia',_np.int64(16)) <= 1
#
# RestrSimult_Cecilia__18,_21_: assign_('Cecilia',_np.int64(18))
#  + assign_('Cecilia',_np.int64(21)) <= 1
#
# RestrSimult_Cecilia__19,_22_: assign_('Cecilia',_np.int64(19))
#  + assign_('Cecilia',_np.int64(22)) <= 1
#
# RestrSimult_Cecilia__24,_27_: assign_('Cecilia',_np.int64(24))
#  + assign_('Cecilia',_np.int64(27)) <= 1
#
# RestrSimult_Cecilia__25,_28_: assign_('Cecilia',_np.int64(25))
#  + assign_('Cecilia',_np.int64(28)) <= 1
#
# RestrSimult_Cecilia__30,_33_: assign_('Cecilia',_np.int64(30))
#  + assign_('Cecilia',_np.int64(33)) <= 1
#
# RestrSimult_Cecilia__31,_34_: assign_('Cecilia',_np.int64(31))
#  + assign_('Cecilia',_np.int64(34)) <= 1
#
# RestrSimult_Chris__1,_4,_6_: assign_('Chris',_np.int64(1))
#  + assign_('Chris',_np.int64(4)) + assign_('Chris',_np.int64(6)) <= 1
#
# RestrSimult_Chris__2,_5,_7_: assign_('Chris',_np.int64(2))
#  + assign_('Chris',_np.int64(5)) + assign_('Chris',_np.int64(7)) <= 1
#
# RestrSimult_Chris__9,_12,_14_: assign_('Chris',_np.int64(12))
#  + assign_('Chris',_np.int64(14)) + assign_('Chris',_np.int64(9)) <= 1
#
# RestrSimult_Chris__10,_13,_15_: assign_('Chris',_np.int64(10))
#  + assign_('Chris',_np.int64(13)) + assign_('Chris',_np.int64(15)) <= 1
#
# RestrSimult_Chris__11,_16_: assign_('Chris',_np.int64(11))
#  + assign_('Chris',_np.int64(16)) <= 1
#
# RestrSimult_Chris__18,_21_: assign_('Chris',_np.int64(18))
#  + assign_('Chris',_np.int64(21)) <= 1
#
# RestrSimult_Chris__19,_22_: assign_('Chris',_np.int64(19))
#  + assign_('Chris',_np.int64(22)) <= 1
#
# RestrSimult_Chris__24,_27_: assign_('Chris',_np.int64(24))
#  + assign_('Chris',_np.int64(27)) <= 1
#
# RestrSimult_Chris__25,_28_: assign_('Chris',_np.int64(25))
#  + assign_('Chris',_np.int64(28)) <= 1
#
# RestrSimult_Chris__30,_33_: assign_('Chris',_np.int64(30))
#  + assign_('Chris',_np.int64(33)) <= 1
#
# RestrSimult_Chris__31,_34_: assign_('Chris',_np.int64(31))
#  + assign_('Chris',_np.int64(34)) <= 1
#
# RestrSimult_Cindy__1,_4,_6_: assign_('Cindy',_np.int64(1))
#  + assign_('Cindy',_np.int64(4)) + assign_('Cindy',_np.int64(6)) <= 1
#
# RestrSimult_Cindy__2,_5,_7_: assign_('Cindy',_np.int64(2))
#  + assign_('Cindy',_np.int64(5)) + assign_('Cindy',_np.int64(7)) <= 1
#
# RestrSimult_Cindy__9,_12,_14_: assign_('Cindy',_np.int64(12))
#  + assign_('Cindy',_np.int64(14)) + assign_('Cindy',_np.int64(9)) <= 1
#
# RestrSimult_Cindy__10,_13,_15_: assign_('Cindy',_np.int64(10))
#  + assign_('Cindy',_np.int64(13)) + assign_('Cindy',_np.int64(15)) <= 1
#
# RestrSimult_Cindy__11,_16_: assign_('Cindy',_np.int64(11))
#  + assign_('Cindy',_np.int64(16)) <= 1
#
# RestrSimult_Cindy__18,_21_: assign_('Cindy',_np.int64(18))
#  + assign_('Cindy',_np.int64(21)) <= 1
#
# RestrSimult_Cindy__19,_22_: assign_('Cindy',_np.int64(19))
#  + assign_('Cindy',_np.int64(22)) <= 1
#
# RestrSimult_Cindy__24,_27_: assign_('Cindy',_np.int64(24))
#  + assign_('Cindy',_np.int64(27)) <= 1
#
# RestrSimult_Cindy__25,_28_: assign_('Cindy',_np.int64(25))
#  + assign_('Cindy',_np.int64(28)) <= 1
#
# RestrSimult_Cindy__30,_33_: assign_('Cindy',_np.int64(30))
#  + assign_('Cindy',_np.int64(33)) <= 1
#
# RestrSimult_Cindy__31,_34_: assign_('Cindy',_np.int64(31))
#  + assign_('Cindy',_np.int64(34)) <= 1
#
# RestrSimult_David__1,_4,_6_: assign_('David',_np.int64(1))
#  + assign_('David',_np.int64(4)) + assign_('David',_np.int64(6)) <= 1
#
# RestrSimult_David__2,_5,_7_: assign_('David',_np.int64(2))
#  + assign_('David',_np.int64(5)) + assign_('David',_np.int64(7)) <= 1
#
# RestrSimult_David__9,_12,_14_: assign_('David',_np.int64(12))
#  + assign_('David',_np.int64(14)) + assign_('David',_np.int64(9)) <= 1
#
# RestrSimult_David__10,_13,_15_: assign_('David',_np.int64(10))
#  + assign_('David',_np.int64(13)) + assign_('David',_np.int64(15)) <= 1
#
# RestrSimult_David__11,_16_: assign_('David',_np.int64(11))
#  + assign_('David',_np.int64(16)) <= 1
#
# RestrSimult_David__18,_21_: assign_('David',_np.int64(18))
#  + assign_('David',_np.int64(21)) <= 1
#
# RestrSimult_David__19,_22_: assign_('David',_np.int64(19))
#  + assign_('David',_np.int64(22)) <= 1
#
# RestrSimult_David__24,_27_: assign_('David',_np.int64(24))
#  + assign_('David',_np.int64(27)) <= 1
#
# RestrSimult_David__25,_28_: assign_('David',_np.int64(25))
#  + assign_('David',_np.int64(28)) <= 1
#
# RestrSimult_David__30,_33_: assign_('David',_np.int64(30))
#  + assign_('David',_np.int64(33)) <= 1
#
# RestrSimult_David__31,_34_: assign_('David',_np.int64(31))
#  + assign_('David',_np.int64(34)) <= 1
#
# RestrSimult_Debbie__1,_4,_6_: assign_('Debbie',_np.int64(1))
#  + assign_('Debbie',_np.int64(4)) + assign_('Debbie',_np.int64(6)) <= 1
#
# RestrSimult_Debbie__2,_5,_7_: assign_('Debbie',_np.int64(2))
#  + assign_('Debbie',_np.int64(5)) + assign_('Debbie',_np.int64(7)) <= 1
#
# RestrSimult_Debbie__9,_12,_14_: assign_('Debbie',_np.int64(12))
#  + assign_('Debbie',_np.int64(14)) + assign_('Debbie',_np.int64(9)) <= 1
#
# RestrSimult_Debbie__10,_13,_15_: assign_('Debbie',_np.int64(10))
#  + assign_('Debbie',_np.int64(13)) + assign_('Debbie',_np.int64(15)) <= 1
#
# RestrSimult_Debbie__11,_16_: assign_('Debbie',_np.int64(11))
#  + assign_('Debbie',_np.int64(16)) <= 1
#
# RestrSimult_Debbie__18,_21_: assign_('Debbie',_np.int64(18))
#  + assign_('Debbie',_np.int64(21)) <= 1
#
# RestrSimult_Debbie__19,_22_: assign_('Debbie',_np.int64(19))
#  + assign_('Debbie',_np.int64(22)) <= 1
#
# RestrSimult_Debbie__24,_27_: assign_('Debbie',_np.int64(24))
#  + assign_('Debbie',_np.int64(27)) <= 1
#
# RestrSimult_Debbie__25,_28_: assign_('Debbie',_np.int64(25))
#  + assign_('Debbie',_np.int64(28)) <= 1
#
# RestrSimult_Debbie__30,_33_: assign_('Debbie',_np.int64(30))
#  + assign_('Debbie',_np.int64(33)) <= 1
#
# RestrSimult_Debbie__31,_34_: assign_('Debbie',_np.int64(31))
#  + assign_('Debbie',_np.int64(34)) <= 1
#
# RestrSimult_Dee__1,_4,_6_: assign_('Dee',_np.int64(1))
#  + assign_('Dee',_np.int64(4)) + assign_('Dee',_np.int64(6)) <= 1
#
# RestrSimult_Dee__2,_5,_7_: assign_('Dee',_np.int64(2))
#  + assign_('Dee',_np.int64(5)) + assign_('Dee',_np.int64(7)) <= 1
#
# RestrSimult_Dee__9,_12,_14_: assign_('Dee',_np.int64(12))
#  + assign_('Dee',_np.int64(14)) + assign_('Dee',_np.int64(9)) <= 1
#
# RestrSimult_Dee__10,_13,_15_: assign_('Dee',_np.int64(10))
#  + assign_('Dee',_np.int64(13)) + assign_('Dee',_np.int64(15)) <= 1
#
# RestrSimult_Dee__11,_16_: assign_('Dee',_np.int64(11))
#  + assign_('Dee',_np.int64(16)) <= 1
#
# RestrSimult_Dee__18,_21_: assign_('Dee',_np.int64(18))
#  + assign_('Dee',_np.int64(21)) <= 1
#
# RestrSimult_Dee__19,_22_: assign_('Dee',_np.int64(19))
#  + assign_('Dee',_np.int64(22)) <= 1
#
# RestrSimult_Dee__24,_27_: assign_('Dee',_np.int64(24))
#  + assign_('Dee',_np.int64(27)) <= 1
#
# RestrSimult_Dee__25,_28_: assign_('Dee',_np.int64(25))
#  + assign_('Dee',_np.int64(28)) <= 1
#
# RestrSimult_Dee__30,_33_: assign_('Dee',_np.int64(30))
#  + assign_('Dee',_np.int64(33)) <= 1
#
# RestrSimult_Dee__31,_34_: assign_('Dee',_np.int64(31))
#  + assign_('Dee',_np.int64(34)) <= 1
#
# RestrSimult_Gloria__1,_4,_6_: assign_('Gloria',_np.int64(1))
#  + assign_('Gloria',_np.int64(4)) + assign_('Gloria',_np.int64(6)) <= 1
#
# RestrSimult_Gloria__2,_5,_7_: assign_('Gloria',_np.int64(2))
#  + assign_('Gloria',_np.int64(5)) + assign_('Gloria',_np.int64(7)) <= 1
#
# RestrSimult_Gloria__9,_12,_14_: assign_('Gloria',_np.int64(12))
#  + assign_('Gloria',_np.int64(14)) + assign_('Gloria',_np.int64(9)) <= 1
#
# RestrSimult_Gloria__10,_13,_15_: assign_('Gloria',_np.int64(10))
#  + assign_('Gloria',_np.int64(13)) + assign_('Gloria',_np.int64(15)) <= 1
#
# RestrSimult_Gloria__11,_16_: assign_('Gloria',_np.int64(11))
#  + assign_('Gloria',_np.int64(16)) <= 1
#
# RestrSimult_Gloria__18,_21_: assign_('Gloria',_np.int64(18))
#  + assign_('Gloria',_np.int64(21)) <= 1
#
# RestrSimult_Gloria__19,_22_: assign_('Gloria',_np.int64(19))
#  + assign_('Gloria',_np.int64(22)) <= 1
#
# RestrSimult_Gloria__24,_27_: assign_('Gloria',_np.int64(24))
#  + assign_('Gloria',_np.int64(27)) <= 1
#
# RestrSimult_Gloria__25,_28_: assign_('Gloria',_np.int64(25))
#  + assign_('Gloria',_np.int64(28)) <= 1
#
# RestrSimult_Gloria__30,_33_: assign_('Gloria',_np.int64(30))
#  + assign_('Gloria',_np.int64(33)) <= 1
#
# RestrSimult_Gloria__31,_34_: assign_('Gloria',_np.int64(31))
#  + assign_('Gloria',_np.int64(34)) <= 1
#
# RestrSimult_Isabelle__1,_4,_6_: assign_('Isabelle',_np.int64(1))
#  + assign_('Isabelle',_np.int64(4)) + assign_('Isabelle',_np.int64(6)) <= 1
#
# RestrSimult_Isabelle__2,_5,_7_: assign_('Isabelle',_np.int64(2))
#  + assign_('Isabelle',_np.int64(5)) + assign_('Isabelle',_np.int64(7)) <= 1
#
# RestrSimult_Isabelle__9,_12,_14_: assign_('Isabelle',_np.int64(12))
#  + assign_('Isabelle',_np.int64(14)) + assign_('Isabelle',_np.int64(9)) <= 1
#
# RestrSimult_Isabelle__10,_13,_15_: assign_('Isabelle',_np.int64(10))
#  + assign_('Isabelle',_np.int64(13)) + assign_('Isabelle',_np.int64(15)) <= 1
#
# RestrSimult_Isabelle__11,_16_: assign_('Isabelle',_np.int64(11))
#  + assign_('Isabelle',_np.int64(16)) <= 1
#
# RestrSimult_Isabelle__18,_21_: assign_('Isabelle',_np.int64(18))
#  + assign_('Isabelle',_np.int64(21)) <= 1
#
# RestrSimult_Isabelle__19,_22_: assign_('Isabelle',_np.int64(19))
#  + assign_('Isabelle',_np.int64(22)) <= 1
#
# RestrSimult_Isabelle__24,_27_: assign_('Isabelle',_np.int64(24))
#  + assign_('Isabelle',_np.int64(27)) <= 1
#
# RestrSimult_Isabelle__25,_28_: assign_('Isabelle',_np.int64(25))
#  + assign_('Isabelle',_np.int64(28)) <= 1
#
# RestrSimult_Isabelle__30,_33_: assign_('Isabelle',_np.int64(30))
#  + assign_('Isabelle',_np.int64(33)) <= 1
#
# RestrSimult_Isabelle__31,_34_: assign_('Isabelle',_np.int64(31))
#  + assign_('Isabelle',_np.int64(34)) <= 1
#
# RestrSimult_Jane__1,_4,_6_: assign_('Jane',_np.int64(1))
#  + assign_('Jane',_np.int64(4)) + assign_('Jane',_np.int64(6)) <= 1
#
# RestrSimult_Jane__2,_5,_7_: assign_('Jane',_np.int64(2))
#  + assign_('Jane',_np.int64(5)) + assign_('Jane',_np.int64(7)) <= 1
#
# RestrSimult_Jane__9,_12,_14_: assign_('Jane',_np.int64(12))
#  + assign_('Jane',_np.int64(14)) + assign_('Jane',_np.int64(9)) <= 1
#
# RestrSimult_Jane__10,_13,_15_: assign_('Jane',_np.int64(10))
#  + assign_('Jane',_np.int64(13)) + assign_('Jane',_np.int64(15)) <= 1
#
# RestrSimult_Jane__11,_16_: assign_('Jane',_np.int64(11))
#  + assign_('Jane',_np.int64(16)) <= 1
#
# RestrSimult_Jane__18,_21_: assign_('Jane',_np.int64(18))
#  + assign_('Jane',_np.int64(21)) <= 1
#
# RestrSimult_Jane__19,_22_: assign_('Jane',_np.int64(19))
#  + assign_('Jane',_np.int64(22)) <= 1
#
# RestrSimult_Jane__24,_27_: assign_('Jane',_np.int64(24))
#  + assign_('Jane',_np.int64(27)) <= 1
#
# RestrSimult_Jane__25,_28_: assign_('Jane',_np.int64(25))
#  + assign_('Jane',_np.int64(28)) <= 1
#
# RestrSimult_Jane__30,_33_: assign_('Jane',_np.int64(30))
#  + assign_('Jane',_np.int64(33)) <= 1
#
# RestrSimult_Jane__31,_34_: assign_('Jane',_np.int64(31))
#  + assign_('Jane',_np.int64(34)) <= 1
#
# RestrSimult_Janelle__1,_4,_6_: assign_('Janelle',_np.int64(1))
#  + assign_('Janelle',_np.int64(4)) + assign_('Janelle',_np.int64(6)) <= 1
#
# RestrSimult_Janelle__2,_5,_7_: assign_('Janelle',_np.int64(2))
#  + assign_('Janelle',_np.int64(5)) + assign_('Janelle',_np.int64(7)) <= 1
#
# RestrSimult_Janelle__9,_12,_14_: assign_('Janelle',_np.int64(12))
#  + assign_('Janelle',_np.int64(14)) + assign_('Janelle',_np.int64(9)) <= 1
#
# RestrSimult_Janelle__10,_13,_15_: assign_('Janelle',_np.int64(10))
#  + assign_('Janelle',_np.int64(13)) + assign_('Janelle',_np.int64(15)) <= 1
#
# RestrSimult_Janelle__11,_16_: assign_('Janelle',_np.int64(11))
#  + assign_('Janelle',_np.int64(16)) <= 1
#
# RestrSimult_Janelle__18,_21_: assign_('Janelle',_np.int64(18))
#  + assign_('Janelle',_np.int64(21)) <= 1
#
# RestrSimult_Janelle__19,_22_: assign_('Janelle',_np.int64(19))
#  + assign_('Janelle',_np.int64(22)) <= 1
#
# RestrSimult_Janelle__24,_27_: assign_('Janelle',_np.int64(24))
#  + assign_('Janelle',_np.int64(27)) <= 1
#
# RestrSimult_Janelle__25,_28_: assign_('Janelle',_np.int64(25))
#  + assign_('Janelle',_np.int64(28)) <= 1
#
# RestrSimult_Janelle__30,_33_: assign_('Janelle',_np.int64(30))
#  + assign_('Janelle',_np.int64(33)) <= 1
#
# RestrSimult_Janelle__31,_34_: assign_('Janelle',_np.int64(31))
#  + assign_('Janelle',_np.int64(34)) <= 1
#
# RestrSimult_Janice__1,_4,_6_: assign_('Janice',_np.int64(1))
#  + assign_('Janice',_np.int64(4)) + assign_('Janice',_np.int64(6)) <= 1
#
# RestrSimult_Janice__2,_5,_7_: assign_('Janice',_np.int64(2))
#  + assign_('Janice',_np.int64(5)) + assign_('Janice',_np.int64(7)) <= 1
#
# RestrSimult_Janice__9,_12,_14_: assign_('Janice',_np.int64(12))
#  + assign_('Janice',_np.int64(14)) + assign_('Janice',_np.int64(9)) <= 1
#
# RestrSimult_Janice__10,_13,_15_: assign_('Janice',_np.int64(10))
#  + assign_('Janice',_np.int64(13)) + assign_('Janice',_np.int64(15)) <= 1
#
# RestrSimult_Janice__11,_16_: assign_('Janice',_np.int64(11))
#  + assign_('Janice',_np.int64(16)) <= 1
#
# RestrSimult_Janice__18,_21_: assign_('Janice',_np.int64(18))
#  + assign_('Janice',_np.int64(21)) <= 1
#
# RestrSimult_Janice__19,_22_: assign_('Janice',_np.int64(19))
#  + assign_('Janice',_np.int64(22)) <= 1
#
# RestrSimult_Janice__24,_27_: assign_('Janice',_np.int64(24))
#  + assign_('Janice',_np.int64(27)) <= 1
#
# RestrSimult_Janice__25,_28_: assign_('Janice',_np.int64(25))
#  + assign_('Janice',_np.int64(28)) <= 1
#
# RestrSimult_Janice__30,_33_: assign_('Janice',_np.int64(30))
#  + assign_('Janice',_np.int64(33)) <= 1
#
# RestrSimult_Janice__31,_34_: assign_('Janice',_np.int64(31))
#  + assign_('Janice',_np.int64(34)) <= 1
#
# RestrSimult_Jemma__1,_4,_6_: assign_('Jemma',_np.int64(1))
#  + assign_('Jemma',_np.int64(4)) + assign_('Jemma',_np.int64(6)) <= 1
#
# RestrSimult_Jemma__2,_5,_7_: assign_('Jemma',_np.int64(2))
#  + assign_('Jemma',_np.int64(5)) + assign_('Jemma',_np.int64(7)) <= 1
#
# RestrSimult_Jemma__9,_12,_14_: assign_('Jemma',_np.int64(12))
#  + assign_('Jemma',_np.int64(14)) + assign_('Jemma',_np.int64(9)) <= 1
#
# RestrSimult_Jemma__10,_13,_15_: assign_('Jemma',_np.int64(10))
#  + assign_('Jemma',_np.int64(13)) + assign_('Jemma',_np.int64(15)) <= 1
#
# RestrSimult_Jemma__11,_16_: assign_('Jemma',_np.int64(11))
#  + assign_('Jemma',_np.int64(16)) <= 1
#
# RestrSimult_Jemma__18,_21_: assign_('Jemma',_np.int64(18))
#  + assign_('Jemma',_np.int64(21)) <= 1
#
# RestrSimult_Jemma__19,_22_: assign_('Jemma',_np.int64(19))
#  + assign_('Jemma',_np.int64(22)) <= 1
#
# RestrSimult_Jemma__24,_27_: assign_('Jemma',_np.int64(24))
#  + assign_('Jemma',_np.int64(27)) <= 1
#
# RestrSimult_Jemma__25,_28_: assign_('Jemma',_np.int64(25))
#  + assign_('Jemma',_np.int64(28)) <= 1
#
# RestrSimult_Jemma__30,_33_: assign_('Jemma',_np.int64(30))
#  + assign_('Jemma',_np.int64(33)) <= 1
#
# RestrSimult_Jemma__31,_34_: assign_('Jemma',_np.int64(31))
#  + assign_('Jemma',_np.int64(34)) <= 1
#
# RestrSimult_Joan__1,_4,_6_: assign_('Joan',_np.int64(1))
#  + assign_('Joan',_np.int64(4)) + assign_('Joan',_np.int64(6)) <= 1
#
# RestrSimult_Joan__2,_5,_7_: assign_('Joan',_np.int64(2))
#  + assign_('Joan',_np.int64(5)) + assign_('Joan',_np.int64(7)) <= 1
#
# RestrSimult_Joan__9,_12,_14_: assign_('Joan',_np.int64(12))
#  + assign_('Joan',_np.int64(14)) + assign_('Joan',_np.int64(9)) <= 1
#
# RestrSimult_Joan__10,_13,_15_: assign_('Joan',_np.int64(10))
#  + assign_('Joan',_np.int64(13)) + assign_('Joan',_np.int64(15)) <= 1
#
# RestrSimult_Joan__11,_16_: assign_('Joan',_np.int64(11))
#  + assign_('Joan',_np.int64(16)) <= 1
#
# RestrSimult_Joan__18,_21_: assign_('Joan',_np.int64(18))
#  + assign_('Joan',_np.int64(21)) <= 1
#
# RestrSimult_Joan__19,_22_: assign_('Joan',_np.int64(19))
#  + assign_('Joan',_np.int64(22)) <= 1
#
# RestrSimult_Joan__24,_27_: assign_('Joan',_np.int64(24))
#  + assign_('Joan',_np.int64(27)) <= 1
#
# RestrSimult_Joan__25,_28_: assign_('Joan',_np.int64(25))
#  + assign_('Joan',_np.int64(28)) <= 1
#
# RestrSimult_Joan__30,_33_: assign_('Joan',_np.int64(30))
#  + assign_('Joan',_np.int64(33)) <= 1
#
# RestrSimult_Joan__31,_34_: assign_('Joan',_np.int64(31))
#  + assign_('Joan',_np.int64(34)) <= 1
#
# RestrSimult_Joyce__1,_4,_6_: assign_('Joyce',_np.int64(1))
#  + assign_('Joyce',_np.int64(4)) + assign_('Joyce',_np.int64(6)) <= 1
#
# RestrSimult_Joyce__2,_5,_7_: assign_('Joyce',_np.int64(2))
#  + assign_('Joyce',_np.int64(5)) + assign_('Joyce',_np.int64(7)) <= 1
#
# RestrSimult_Joyce__9,_12,_14_: assign_('Joyce',_np.int64(12))
#  + assign_('Joyce',_np.int64(14)) + assign_('Joyce',_np.int64(9)) <= 1
#
# RestrSimult_Joyce__10,_13,_15_: assign_('Joyce',_np.int64(10))
#  + assign_('Joyce',_np.int64(13)) + assign_('Joyce',_np.int64(15)) <= 1
#
# RestrSimult_Joyce__11,_16_: assign_('Joyce',_np.int64(11))
#  + assign_('Joyce',_np.int64(16)) <= 1
#
# RestrSimult_Joyce__18,_21_: assign_('Joyce',_np.int64(18))
#  + assign_('Joyce',_np.int64(21)) <= 1
#
# RestrSimult_Joyce__19,_22_: assign_('Joyce',_np.int64(19))
#  + assign_('Joyce',_np.int64(22)) <= 1
#
# RestrSimult_Joyce__24,_27_: assign_('Joyce',_np.int64(24))
#  + assign_('Joyce',_np.int64(27)) <= 1
#
# RestrSimult_Joyce__25,_28_: assign_('Joyce',_np.int64(25))
#  + assign_('Joyce',_np.int64(28)) <= 1
#
# RestrSimult_Joyce__30,_33_: assign_('Joyce',_np.int64(30))
#  + assign_('Joyce',_np.int64(33)) <= 1
#
# RestrSimult_Joyce__31,_34_: assign_('Joyce',_np.int64(31))
#  + assign_('Joyce',_np.int64(34)) <= 1
#
# RestrSimult_Jude__1,_4,_6_: assign_('Jude',_np.int64(1))
#  + assign_('Jude',_np.int64(4)) + assign_('Jude',_np.int64(6)) <= 1
#
# RestrSimult_Jude__2,_5,_7_: assign_('Jude',_np.int64(2))
#  + assign_('Jude',_np.int64(5)) + assign_('Jude',_np.int64(7)) <= 1
#
# RestrSimult_Jude__9,_12,_14_: assign_('Jude',_np.int64(12))
#  + assign_('Jude',_np.int64(14)) + assign_('Jude',_np.int64(9)) <= 1
#
# RestrSimult_Jude__10,_13,_15_: assign_('Jude',_np.int64(10))
#  + assign_('Jude',_np.int64(13)) + assign_('Jude',_np.int64(15)) <= 1
#
# RestrSimult_Jude__11,_16_: assign_('Jude',_np.int64(11))
#  + assign_('Jude',_np.int64(16)) <= 1
#
# RestrSimult_Jude__18,_21_: assign_('Jude',_np.int64(18))
#  + assign_('Jude',_np.int64(21)) <= 1
#
# RestrSimult_Jude__19,_22_: assign_('Jude',_np.int64(19))
#  + assign_('Jude',_np.int64(22)) <= 1
#
# RestrSimult_Jude__24,_27_: assign_('Jude',_np.int64(24))
#  + assign_('Jude',_np.int64(27)) <= 1
#
# RestrSimult_Jude__25,_28_: assign_('Jude',_np.int64(25))
#  + assign_('Jude',_np.int64(28)) <= 1
#
# RestrSimult_Jude__30,_33_: assign_('Jude',_np.int64(30))
#  + assign_('Jude',_np.int64(33)) <= 1
#
# RestrSimult_Jude__31,_34_: assign_('Jude',_np.int64(31))
#  + assign_('Jude',_np.int64(34)) <= 1
#
# RestrSimult_Julie__1,_4,_6_: assign_('Julie',_np.int64(1))
#  + assign_('Julie',_np.int64(4)) + assign_('Julie',_np.int64(6)) <= 1
#
# RestrSimult_Julie__2,_5,_7_: assign_('Julie',_np.int64(2))
#  + assign_('Julie',_np.int64(5)) + assign_('Julie',_np.int64(7)) <= 1
#
# RestrSimult_Julie__9,_12,_14_: assign_('Julie',_np.int64(12))
#  + assign_('Julie',_np.int64(14)) + assign_('Julie',_np.int64(9)) <= 1
#
# RestrSimult_Julie__10,_13,_15_: assign_('Julie',_np.int64(10))
#  + assign_('Julie',_np.int64(13)) + assign_('Julie',_np.int64(15)) <= 1
#
# RestrSimult_Julie__11,_16_: assign_('Julie',_np.int64(11))
#  + assign_('Julie',_np.int64(16)) <= 1
#
# RestrSimult_Julie__18,_21_: assign_('Julie',_np.int64(18))
#  + assign_('Julie',_np.int64(21)) <= 1
#
# RestrSimult_Julie__19,_22_: assign_('Julie',_np.int64(19))
#  + assign_('Julie',_np.int64(22)) <= 1
#
# RestrSimult_Julie__24,_27_: assign_('Julie',_np.int64(24))
#  + assign_('Julie',_np.int64(27)) <= 1
#
# RestrSimult_Julie__25,_28_: assign_('Julie',_np.int64(25))
#  + assign_('Julie',_np.int64(28)) <= 1
#
# RestrSimult_Julie__30,_33_: assign_('Julie',_np.int64(30))
#  + assign_('Julie',_np.int64(33)) <= 1
#
# RestrSimult_Julie__31,_34_: assign_('Julie',_np.int64(31))
#  + assign_('Julie',_np.int64(34)) <= 1
#
# RestrSimult_Juliet__1,_4,_6_: assign_('Juliet',_np.int64(1))
#  + assign_('Juliet',_np.int64(4)) + assign_('Juliet',_np.int64(6)) <= 1
#
# RestrSimult_Juliet__2,_5,_7_: assign_('Juliet',_np.int64(2))
#  + assign_('Juliet',_np.int64(5)) + assign_('Juliet',_np.int64(7)) <= 1
#
# RestrSimult_Juliet__9,_12,_14_: assign_('Juliet',_np.int64(12))
#  + assign_('Juliet',_np.int64(14)) + assign_('Juliet',_np.int64(9)) <= 1
#
# RestrSimult_Juliet__10,_13,_15_: assign_('Juliet',_np.int64(10))
#  + assign_('Juliet',_np.int64(13)) + assign_('Juliet',_np.int64(15)) <= 1
#
# RestrSimult_Juliet__11,_16_: assign_('Juliet',_np.int64(11))
#  + assign_('Juliet',_np.int64(16)) <= 1
#
# RestrSimult_Juliet__18,_21_: assign_('Juliet',_np.int64(18))
#  + assign_('Juliet',_np.int64(21)) <= 1
#
# RestrSimult_Juliet__19,_22_: assign_('Juliet',_np.int64(19))
#  + assign_('Juliet',_np.int64(22)) <= 1
#
# RestrSimult_Juliet__24,_27_: assign_('Juliet',_np.int64(24))
#  + assign_('Juliet',_np.int64(27)) <= 1
#
# RestrSimult_Juliet__25,_28_: assign_('Juliet',_np.int64(25))
#  + assign_('Juliet',_np.int64(28)) <= 1
#
# RestrSimult_Juliet__30,_33_: assign_('Juliet',_np.int64(30))
#  + assign_('Juliet',_np.int64(33)) <= 1
#
# RestrSimult_Juliet__31,_34_: assign_('Juliet',_np.int64(31))
#  + assign_('Juliet',_np.int64(34)) <= 1
#
# RestrSimult_Kate__1,_4,_6_: assign_('Kate',_np.int64(1))
#  + assign_('Kate',_np.int64(4)) + assign_('Kate',_np.int64(6)) <= 1
#
# RestrSimult_Kate__2,_5,_7_: assign_('Kate',_np.int64(2))
#  + assign_('Kate',_np.int64(5)) + assign_('Kate',_np.int64(7)) <= 1
#
# RestrSimult_Kate__9,_12,_14_: assign_('Kate',_np.int64(12))
#  + assign_('Kate',_np.int64(14)) + assign_('Kate',_np.int64(9)) <= 1
#
# RestrSimult_Kate__10,_13,_15_: assign_('Kate',_np.int64(10))
#  + assign_('Kate',_np.int64(13)) + assign_('Kate',_np.int64(15)) <= 1
#
# RestrSimult_Kate__11,_16_: assign_('Kate',_np.int64(11))
#  + assign_('Kate',_np.int64(16)) <= 1
#
# RestrSimult_Kate__18,_21_: assign_('Kate',_np.int64(18))
#  + assign_('Kate',_np.int64(21)) <= 1
#
# RestrSimult_Kate__19,_22_: assign_('Kate',_np.int64(19))
#  + assign_('Kate',_np.int64(22)) <= 1
#
# RestrSimult_Kate__24,_27_: assign_('Kate',_np.int64(24))
#  + assign_('Kate',_np.int64(27)) <= 1
#
# RestrSimult_Kate__25,_28_: assign_('Kate',_np.int64(25))
#  + assign_('Kate',_np.int64(28)) <= 1
#
# RestrSimult_Kate__30,_33_: assign_('Kate',_np.int64(30))
#  + assign_('Kate',_np.int64(33)) <= 1
#
# RestrSimult_Kate__31,_34_: assign_('Kate',_np.int64(31))
#  + assign_('Kate',_np.int64(34)) <= 1
#
# RestrSimult_Nancy__1,_4,_6_: assign_('Nancy',_np.int64(1))
#  + assign_('Nancy',_np.int64(4)) + assign_('Nancy',_np.int64(6)) <= 1
#
# RestrSimult_Nancy__2,_5,_7_: assign_('Nancy',_np.int64(2))
#  + assign_('Nancy',_np.int64(5)) + assign_('Nancy',_np.int64(7)) <= 1
#
# RestrSimult_Nancy__9,_12,_14_: assign_('Nancy',_np.int64(12))
#  + assign_('Nancy',_np.int64(14)) + assign_('Nancy',_np.int64(9)) <= 1
#
# RestrSimult_Nancy__10,_13,_15_: assign_('Nancy',_np.int64(10))
#  + assign_('Nancy',_np.int64(13)) + assign_('Nancy',_np.int64(15)) <= 1
#
# RestrSimult_Nancy__11,_16_: assign_('Nancy',_np.int64(11))
#  + assign_('Nancy',_np.int64(16)) <= 1
#
# RestrSimult_Nancy__18,_21_: assign_('Nancy',_np.int64(18))
#  + assign_('Nancy',_np.int64(21)) <= 1
#
# RestrSimult_Nancy__19,_22_: assign_('Nancy',_np.int64(19))
#  + assign_('Nancy',_np.int64(22)) <= 1
#
# RestrSimult_Nancy__24,_27_: assign_('Nancy',_np.int64(24))
#  + assign_('Nancy',_np.int64(27)) <= 1
#
# RestrSimult_Nancy__25,_28_: assign_('Nancy',_np.int64(25))
#  + assign_('Nancy',_np.int64(28)) <= 1
#
# RestrSimult_Nancy__30,_33_: assign_('Nancy',_np.int64(30))
#  + assign_('Nancy',_np.int64(33)) <= 1
#
# RestrSimult_Nancy__31,_34_: assign_('Nancy',_np.int64(31))
#  + assign_('Nancy',_np.int64(34)) <= 1
#
# RestrSimult_Nathalie__1,_4,_6_: assign_('Nathalie',_np.int64(1))
#  + assign_('Nathalie',_np.int64(4)) + assign_('Nathalie',_np.int64(6)) <= 1
#
# RestrSimult_Nathalie__2,_5,_7_: assign_('Nathalie',_np.int64(2))
#  + assign_('Nathalie',_np.int64(5)) + assign_('Nathalie',_np.int64(7)) <= 1
#
# RestrSimult_Nathalie__9,_12,_14_: assign_('Nathalie',_np.int64(12))
#  + assign_('Nathalie',_np.int64(14)) + assign_('Nathalie',_np.int64(9)) <= 1
#
# RestrSimult_Nathalie__10,_13,_15_: assign_('Nathalie',_np.int64(10))
#  + assign_('Nathalie',_np.int64(13)) + assign_('Nathalie',_np.int64(15)) <= 1
#
# RestrSimult_Nathalie__11,_16_: assign_('Nathalie',_np.int64(11))
#  + assign_('Nathalie',_np.int64(16)) <= 1
#
# RestrSimult_Nathalie__18,_21_: assign_('Nathalie',_np.int64(18))
#  + assign_('Nathalie',_np.int64(21)) <= 1
#
# RestrSimult_Nathalie__19,_22_: assign_('Nathalie',_np.int64(19))
#  + assign_('Nathalie',_np.int64(22)) <= 1
#
# RestrSimult_Nathalie__24,_27_: assign_('Nathalie',_np.int64(24))
#  + assign_('Nathalie',_np.int64(27)) <= 1
#
# RestrSimult_Nathalie__25,_28_: assign_('Nathalie',_np.int64(25))
#  + assign_('Nathalie',_np.int64(28)) <= 1
#
# RestrSimult_Nathalie__30,_33_: assign_('Nathalie',_np.int64(30))
#  + assign_('Nathalie',_np.int64(33)) <= 1
#
# RestrSimult_Nathalie__31,_34_: assign_('Nathalie',_np.int64(31))
#  + assign_('Nathalie',_np.int64(34)) <= 1
#
# RestrSimult_Nicole__1,_4,_6_: assign_('Nicole',_np.int64(1))
#  + assign_('Nicole',_np.int64(4)) + assign_('Nicole',_np.int64(6)) <= 1
#
# RestrSimult_Nicole__2,_5,_7_: assign_('Nicole',_np.int64(2))
#  + assign_('Nicole',_np.int64(5)) + assign_('Nicole',_np.int64(7)) <= 1
#
# RestrSimult_Nicole__9,_12,_14_: assign_('Nicole',_np.int64(12))
#  + assign_('Nicole',_np.int64(14)) + assign_('Nicole',_np.int64(9)) <= 1
#
# RestrSimult_Nicole__10,_13,_15_: assign_('Nicole',_np.int64(10))
#  + assign_('Nicole',_np.int64(13)) + assign_('Nicole',_np.int64(15)) <= 1
#
# RestrSimult_Nicole__11,_16_: assign_('Nicole',_np.int64(11))
#  + assign_('Nicole',_np.int64(16)) <= 1
#
# RestrSimult_Nicole__18,_21_: assign_('Nicole',_np.int64(18))
#  + assign_('Nicole',_np.int64(21)) <= 1
#
# RestrSimult_Nicole__19,_22_: assign_('Nicole',_np.int64(19))
#  + assign_('Nicole',_np.int64(22)) <= 1
#
# RestrSimult_Nicole__24,_27_: assign_('Nicole',_np.int64(24))
#  + assign_('Nicole',_np.int64(27)) <= 1
#
# RestrSimult_Nicole__25,_28_: assign_('Nicole',_np.int64(25))
#  + assign_('Nicole',_np.int64(28)) <= 1
#
# RestrSimult_Nicole__30,_33_: assign_('Nicole',_np.int64(30))
#  + assign_('Nicole',_np.int64(33)) <= 1
#
# RestrSimult_Nicole__31,_34_: assign_('Nicole',_np.int64(31))
#  + assign_('Nicole',_np.int64(34)) <= 1
#
# RestrSimult_Patricia__1,_4,_6_: assign_('Patricia',_np.int64(1))
#  + assign_('Patricia',_np.int64(4)) + assign_('Patricia',_np.int64(6)) <= 1
#
# RestrSimult_Patricia__2,_5,_7_: assign_('Patricia',_np.int64(2))
#  + assign_('Patricia',_np.int64(5)) + assign_('Patricia',_np.int64(7)) <= 1
#
# RestrSimult_Patricia__9,_12,_14_: assign_('Patricia',_np.int64(12))
#  + assign_('Patricia',_np.int64(14)) + assign_('Patricia',_np.int64(9)) <= 1
#
# RestrSimult_Patricia__10,_13,_15_: assign_('Patricia',_np.int64(10))
#  + assign_('Patricia',_np.int64(13)) + assign_('Patricia',_np.int64(15)) <= 1
#
# RestrSimult_Patricia__11,_16_: assign_('Patricia',_np.int64(11))
#  + assign_('Patricia',_np.int64(16)) <= 1
#
# RestrSimult_Patricia__18,_21_: assign_('Patricia',_np.int64(18))
#  + assign_('Patricia',_np.int64(21)) <= 1
#
# RestrSimult_Patricia__19,_22_: assign_('Patricia',_np.int64(19))
#  + assign_('Patricia',_np.int64(22)) <= 1
#
# RestrSimult_Patricia__24,_27_: assign_('Patricia',_np.int64(24))
#  + assign_('Patricia',_np.int64(27)) <= 1
#
# RestrSimult_Patricia__25,_28_: assign_('Patricia',_np.int64(25))
#  + assign_('Patricia',_np.int64(28)) <= 1
#
# RestrSimult_Patricia__30,_33_: assign_('Patricia',_np.int64(30))
#  + assign_('Patricia',_np.int64(33)) <= 1
#
# RestrSimult_Patricia__31,_34_: assign_('Patricia',_np.int64(31))
#  + assign_('Patricia',_np.int64(34)) <= 1
#
# RestrSimult_Patrick__1,_4,_6_: assign_('Patrick',_np.int64(1))
#  + assign_('Patrick',_np.int64(4)) + assign_('Patrick',_np.int64(6)) <= 1
#
# RestrSimult_Patrick__2,_5,_7_: assign_('Patrick',_np.int64(2))
#  + assign_('Patrick',_np.int64(5)) + assign_('Patrick',_np.int64(7)) <= 1
#
# RestrSimult_Patrick__9,_12,_14_: assign_('Patrick',_np.int64(12))
#  + assign_('Patrick',_np.int64(14)) + assign_('Patrick',_np.int64(9)) <= 1
#
# RestrSimult_Patrick__10,_13,_15_: assign_('Patrick',_np.int64(10))
#  + assign_('Patrick',_np.int64(13)) + assign_('Patrick',_np.int64(15)) <= 1
#
# RestrSimult_Patrick__11,_16_: assign_('Patrick',_np.int64(11))
#  + assign_('Patrick',_np.int64(16)) <= 1
#
# RestrSimult_Patrick__18,_21_: assign_('Patrick',_np.int64(18))
#  + assign_('Patrick',_np.int64(21)) <= 1
#
# RestrSimult_Patrick__19,_22_: assign_('Patrick',_np.int64(19))
#  + assign_('Patrick',_np.int64(22)) <= 1
#
# RestrSimult_Patrick__24,_27_: assign_('Patrick',_np.int64(24))
#  + assign_('Patrick',_np.int64(27)) <= 1
#
# RestrSimult_Patrick__25,_28_: assign_('Patrick',_np.int64(25))
#  + assign_('Patrick',_np.int64(28)) <= 1
#
# RestrSimult_Patrick__30,_33_: assign_('Patrick',_np.int64(30))
#  + assign_('Patrick',_np.int64(33)) <= 1
#
# RestrSimult_Patrick__31,_34_: assign_('Patrick',_np.int64(31))
#  + assign_('Patrick',_np.int64(34)) <= 1
#
# RestrSimult_Roberta__1,_4,_6_: assign_('Roberta',_np.int64(1))
#  + assign_('Roberta',_np.int64(4)) + assign_('Roberta',_np.int64(6)) <= 1
#
# RestrSimult_Roberta__2,_5,_7_: assign_('Roberta',_np.int64(2))
#  + assign_('Roberta',_np.int64(5)) + assign_('Roberta',_np.int64(7)) <= 1
#
# RestrSimult_Roberta__9,_12,_14_: assign_('Roberta',_np.int64(12))
#  + assign_('Roberta',_np.int64(14)) + assign_('Roberta',_np.int64(9)) <= 1
#
# RestrSimult_Roberta__10,_13,_15_: assign_('Roberta',_np.int64(10))
#  + assign_('Roberta',_np.int64(13)) + assign_('Roberta',_np.int64(15)) <= 1
#
# RestrSimult_Roberta__11,_16_: assign_('Roberta',_np.int64(11))
#  + assign_('Roberta',_np.int64(16)) <= 1
#
# RestrSimult_Roberta__18,_21_: assign_('Roberta',_np.int64(18))
#  + assign_('Roberta',_np.int64(21)) <= 1
#
# RestrSimult_Roberta__19,_22_: assign_('Roberta',_np.int64(19))
#  + assign_('Roberta',_np.int64(22)) <= 1
#
# RestrSimult_Roberta__24,_27_: assign_('Roberta',_np.int64(24))
#  + assign_('Roberta',_np.int64(27)) <= 1
#
# RestrSimult_Roberta__25,_28_: assign_('Roberta',_np.int64(25))
#  + assign_('Roberta',_np.int64(28)) <= 1
#
# RestrSimult_Roberta__30,_33_: assign_('Roberta',_np.int64(30))
#  + assign_('Roberta',_np.int64(33)) <= 1
#
# RestrSimult_Roberta__31,_34_: assign_('Roberta',_np.int64(31))
#  + assign_('Roberta',_np.int64(34)) <= 1
#
# RestrSimult_Suzanne__1,_4,_6_: assign_('Suzanne',_np.int64(1))
#  + assign_('Suzanne',_np.int64(4)) + assign_('Suzanne',_np.int64(6)) <= 1
#
# RestrSimult_Suzanne__2,_5,_7_: assign_('Suzanne',_np.int64(2))
#  + assign_('Suzanne',_np.int64(5)) + assign_('Suzanne',_np.int64(7)) <= 1
#
# RestrSimult_Suzanne__9,_12,_14_: assign_('Suzanne',_np.int64(12))
#  + assign_('Suzanne',_np.int64(14)) + assign_('Suzanne',_np.int64(9)) <= 1
#
# RestrSimult_Suzanne__10,_13,_15_: assign_('Suzanne',_np.int64(10))
#  + assign_('Suzanne',_np.int64(13)) + assign_('Suzanne',_np.int64(15)) <= 1
#
# RestrSimult_Suzanne__11,_16_: assign_('Suzanne',_np.int64(11))
#  + assign_('Suzanne',_np.int64(16)) <= 1
#
# RestrSimult_Suzanne__18,_21_: assign_('Suzanne',_np.int64(18))
#  + assign_('Suzanne',_np.int64(21)) <= 1
#
# RestrSimult_Suzanne__19,_22_: assign_('Suzanne',_np.int64(19))
#  + assign_('Suzanne',_np.int64(22)) <= 1
#
# RestrSimult_Suzanne__24,_27_: assign_('Suzanne',_np.int64(24))
#  + assign_('Suzanne',_np.int64(27)) <= 1
#
# RestrSimult_Suzanne__25,_28_: assign_('Suzanne',_np.int64(25))
#  + assign_('Suzanne',_np.int64(28)) <= 1
#
# RestrSimult_Suzanne__30,_33_: assign_('Suzanne',_np.int64(30))
#  + assign_('Suzanne',_np.int64(33)) <= 1
#
# RestrSimult_Suzanne__31,_34_: assign_('Suzanne',_np.int64(31))
#  + assign_('Suzanne',_np.int64(34)) <= 1
#
# RestrSimult_Vickie__1,_4,_6_: assign_('Vickie',_np.int64(1))
#  + assign_('Vickie',_np.int64(4)) + assign_('Vickie',_np.int64(6)) <= 1
#
# RestrSimult_Vickie__2,_5,_7_: assign_('Vickie',_np.int64(2))
#  + assign_('Vickie',_np.int64(5)) + assign_('Vickie',_np.int64(7)) <= 1
#
# RestrSimult_Vickie__9,_12,_14_: assign_('Vickie',_np.int64(12))
#  + assign_('Vickie',_np.int64(14)) + assign_('Vickie',_np.int64(9)) <= 1
#
# RestrSimult_Vickie__10,_13,_15_: assign_('Vickie',_np.int64(10))
#  + assign_('Vickie',_np.int64(13)) + assign_('Vickie',_np.int64(15)) <= 1
#
# RestrSimult_Vickie__11,_16_: assign_('Vickie',_np.int64(11))
#  + assign_('Vickie',_np.int64(16)) <= 1
#
# RestrSimult_Vickie__18,_21_: assign_('Vickie',_np.int64(18))
#  + assign_('Vickie',_np.int64(21)) <= 1
#
# RestrSimult_Vickie__19,_22_: assign_('Vickie',_np.int64(19))
#  + assign_('Vickie',_np.int64(22)) <= 1
#
# RestrSimult_Vickie__24,_27_: assign_('Vickie',_np.int64(24))
#  + assign_('Vickie',_np.int64(27)) <= 1
#
# RestrSimult_Vickie__25,_28_: assign_('Vickie',_np.int64(25))
#  + assign_('Vickie',_np.int64(28)) <= 1
#
# RestrSimult_Vickie__30,_33_: assign_('Vickie',_np.int64(30))
#  + assign_('Vickie',_np.int64(33)) <= 1
#
# RestrSimult_Vickie__31,_34_: assign_('Vickie',_np.int64(31))
#  + assign_('Vickie',_np.int64(34)) <= 1
#
# RestrSimult_Wendie__1,_4,_6_: assign_('Wendie',_np.int64(1))
#  + assign_('Wendie',_np.int64(4)) + assign_('Wendie',_np.int64(6)) <= 1
#
# RestrSimult_Wendie__2,_5,_7_: assign_('Wendie',_np.int64(2))
#  + assign_('Wendie',_np.int64(5)) + assign_('Wendie',_np.int64(7)) <= 1
#
# RestrSimult_Wendie__9,_12,_14_: assign_('Wendie',_np.int64(12))
#  + assign_('Wendie',_np.int64(14)) + assign_('Wendie',_np.int64(9)) <= 1
#
# RestrSimult_Wendie__10,_13,_15_: assign_('Wendie',_np.int64(10))
#  + assign_('Wendie',_np.int64(13)) + assign_('Wendie',_np.int64(15)) <= 1
#
# RestrSimult_Wendie__11,_16_: assign_('Wendie',_np.int64(11))
#  + assign_('Wendie',_np.int64(16)) <= 1
#
# RestrSimult_Wendie__18,_21_: assign_('Wendie',_np.int64(18))
#  + assign_('Wendie',_np.int64(21)) <= 1
#
# RestrSimult_Wendie__19,_22_: assign_('Wendie',_np.int64(19))
#  + assign_('Wendie',_np.int64(22)) <= 1
#
# RestrSimult_Wendie__24,_27_: assign_('Wendie',_np.int64(24))
#  + assign_('Wendie',_np.int64(27)) <= 1
#
# RestrSimult_Wendie__25,_28_: assign_('Wendie',_np.int64(25))
#  + assign_('Wendie',_np.int64(28)) <= 1
#
# RestrSimult_Wendie__30,_33_: assign_('Wendie',_np.int64(30))
#  + assign_('Wendie',_np.int64(33)) <= 1
#
# RestrSimult_Wendie__31,_34_: assign_('Wendie',_np.int64(31))
#  + assign_('Wendie',_np.int64(34)) <= 1
#
# RestrSimult_Zoe__1,_4,_6_: assign_('Zoe',_np.int64(1))
#  + assign_('Zoe',_np.int64(4)) + assign_('Zoe',_np.int64(6)) <= 1
#
# RestrSimult_Zoe__2,_5,_7_: assign_('Zoe',_np.int64(2))
#  + assign_('Zoe',_np.int64(5)) + assign_('Zoe',_np.int64(7)) <= 1
#
# RestrSimult_Zoe__9,_12,_14_: assign_('Zoe',_np.int64(12))
#  + assign_('Zoe',_np.int64(14)) + assign_('Zoe',_np.int64(9)) <= 1
#
# RestrSimult_Zoe__10,_13,_15_: assign_('Zoe',_np.int64(10))
#  + assign_('Zoe',_np.int64(13)) + assign_('Zoe',_np.int64(15)) <= 1
#
# RestrSimult_Zoe__11,_16_: assign_('Zoe',_np.int64(11))
#  + assign_('Zoe',_np.int64(16)) <= 1
#
# RestrSimult_Zoe__18,_21_: assign_('Zoe',_np.int64(18))
#  + assign_('Zoe',_np.int64(21)) <= 1
#
# RestrSimult_Zoe__19,_22_: assign_('Zoe',_np.int64(19))
#  + assign_('Zoe',_np.int64(22)) <= 1
#
# RestrSimult_Zoe__24,_27_: assign_('Zoe',_np.int64(24))
#  + assign_('Zoe',_np.int64(27)) <= 1
#
# RestrSimult_Zoe__25,_28_: assign_('Zoe',_np.int64(25))
#  + assign_('Zoe',_np.int64(28)) <= 1
#
# RestrSimult_Zoe__30,_33_: assign_('Zoe',_np.int64(30))
#  + assign_('Zoe',_np.int64(33)) <= 1
#
# RestrSimult_Zoe__31,_34_: assign_('Zoe',_np.int64(31))
#  + assign_('Zoe',_np.int64(34)) <= 1
#
# Worktime_Anne: 6 assign_('Anne',_np.int64(0)) + 4 assign_('Anne',_np.int64(1))
#  + 6 assign_('Anne',_np.int64(10)) + 8 assign_('Anne',_np.int64(11))
#  + 4 assign_('Anne',_np.int64(12)) + 6 assign_('Anne',_np.int64(13))
#  + 4 assign_('Anne',_np.int64(14)) + 6 assign_('Anne',_np.int64(15))
#  + 8 assign_('Anne',_np.int64(16)) + 6 assign_('Anne',_np.int64(17))
#  + 4 assign_('Anne',_np.int64(18)) + 6 assign_('Anne',_np.int64(19))
#  + 6 assign_('Anne',_np.int64(2)) + 8 assign_('Anne',_np.int64(20))
#  + 4 assign_('Anne',_np.int64(21)) + 6 assign_('Anne',_np.int64(22))
#  + 6 assign_('Anne',_np.int64(23)) + 4 assign_('Anne',_np.int64(24))
#  + 6 assign_('Anne',_np.int64(25)) + 8 assign_('Anne',_np.int64(26))
#  + 4 assign_('Anne',_np.int64(27)) + 6 assign_('Anne',_np.int64(28))
#  + 6 assign_('Anne',_np.int64(29)) + 8 assign_('Anne',_np.int64(3))
#  + 4 assign_('Anne',_np.int64(30)) + 6 assign_('Anne',_np.int64(31))
#  + 8 assign_('Anne',_np.int64(32)) + 4 assign_('Anne',_np.int64(33))
#  + 6 assign_('Anne',_np.int64(34)) + 10 assign_('Anne',_np.int64(35))
#  + 8 assign_('Anne',_np.int64(36)) + 6 assign_('Anne',_np.int64(37))
#  + 10 assign_('Anne',_np.int64(38)) + 8 assign_('Anne',_np.int64(39))
#  + 4 assign_('Anne',_np.int64(4)) + 6 assign_('Anne',_np.int64(40))
#  + 2 assign_('Anne',_np.int64(41)) + 6 assign_('Anne',_np.int64(5))
#  + 4 assign_('Anne',_np.int64(6)) + 6 assign_('Anne',_np.int64(7))
#  + 6 assign_('Anne',_np.int64(8)) + 4 assign_('Anne',_np.int64(9)) <= 40
#
# Worktime_Bethanie: 6 assign_('Bethanie',_np.int64(0))
#  + 4 assign_('Bethanie',_np.int64(1)) + 6 assign_('Bethanie',_np.int64(10))
#  + 8 assign_('Bethanie',_np.int64(11)) + 4 assign_('Bethanie',_np.int64(12))
#  + 6 assign_('Bethanie',_np.int64(13)) + 4 assign_('Bethanie',_np.int64(14))
#  + 6 assign_('Bethanie',_np.int64(15)) + 8 assign_('Bethanie',_np.int64(16))
#  + 6 assign_('Bethanie',_np.int64(17)) + 4 assign_('Bethanie',_np.int64(18))
#  + 6 assign_('Bethanie',_np.int64(19)) + 6 assign_('Bethanie',_np.int64(2))
#  + 8 assign_('Bethanie',_np.int64(20)) + 4 assign_('Bethanie',_np.int64(21))
#  + 6 assign_('Bethanie',_np.int64(22)) + 6 assign_('Bethanie',_np.int64(23))
#  + 4 assign_('Bethanie',_np.int64(24)) + 6 assign_('Bethanie',_np.int64(25))
#  + 8 assign_('Bethanie',_np.int64(26)) + 4 assign_('Bethanie',_np.int64(27))
#  + 6 assign_('Bethanie',_np.int64(28)) + 6 assign_('Bethanie',_np.int64(29))
#  + 8 assign_('Bethanie',_np.int64(3)) + 4 assign_('Bethanie',_np.int64(30))
#  + 6 assign_('Bethanie',_np.int64(31)) + 8 assign_('Bethanie',_np.int64(32))
#  + 4 assign_('Bethanie',_np.int64(33)) + 6 assign_('Bethanie',_np.int64(34))
#  + 10 assign_('Bethanie',_np.int64(35)) + 8 assign_('Bethanie',_np.int64(36))
#  + 6 assign_('Bethanie',_np.int64(37)) + 10 assign_('Bethanie',_np.int64(38))
#  + 8 assign_('Bethanie',_np.int64(39)) + 4 assign_('Bethanie',_np.int64(4))
#  + 6 assign_('Bethanie',_np.int64(40)) + 2 assign_('Bethanie',_np.int64(41))
#  + 6 assign_('Bethanie',_np.int64(5)) + 4 assign_('Bethanie',_np.int64(6))
#  + 6 assign_('Bethanie',_np.int64(7)) + 6 assign_('Bethanie',_np.int64(8))
#  + 4 assign_('Bethanie',_np.int64(9)) <= 40
#
# Worktime_Betsy: 6 assign_('Betsy',_np.int64(0))
#  + 4 assign_('Betsy',_np.int64(1)) + 6 assign_('Betsy',_np.int64(10))
#  + 8 assign_('Betsy',_np.int64(11)) + 4 assign_('Betsy',_np.int64(12))
#  + 6 assign_('Betsy',_np.int64(13)) + 4 assign_('Betsy',_np.int64(14))
#  + 6 assign_('Betsy',_np.int64(15)) + 8 assign_('Betsy',_np.int64(16))
#  + 6 assign_('Betsy',_np.int64(17)) + 4 assign_('Betsy',_np.int64(18))
#  + 6 assign_('Betsy',_np.int64(19)) + 6 assign_('Betsy',_np.int64(2))
#  + 8 assign_('Betsy',_np.int64(20)) + 4 assign_('Betsy',_np.int64(21))
#  + 6 assign_('Betsy',_np.int64(22)) + 6 assign_('Betsy',_np.int64(23))
#  + 4 assign_('Betsy',_np.int64(24)) + 6 assign_('Betsy',_np.int64(25))
#  + 8 assign_('Betsy',_np.int64(26)) + 4 assign_('Betsy',_np.int64(27))
#  + 6 assign_('Betsy',_np.int64(28)) + 6 assign_('Betsy',_np.int64(29))
#  + 8 assign_('Betsy',_np.int64(3)) + 4 assign_('Betsy',_np.int64(30))
#  + 6 assign_('Betsy',_np.int64(31)) + 8 assign_('Betsy',_np.int64(32))
# ...
# 0 <= assign_('Nicole',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Nicole',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Patricia',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Patrick',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Roberta',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Suzanne',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Vickie',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Wendie',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(9)) <= 1 Integer

# %%
prob.objective.value()
# Out:
# np.float64(29508.0)

# %%
# Preparação dos resultados para visualização
resultados = []
for nurse in all_nurses:
    for shift in all_shifts:
        if value(assigned[(nurse, shift)]) == 1:  # Se a enfermeira foi alocada ao turno
            custo_turno = df_shifts['duration'][shift] * df_nurses.loc[nurse, 'pay_rate']
            resultados.append([nurse, shift, df_shifts['duration'][shift], df_nurses.loc[nurse, 'pay_rate'], custo_turno])

# Cria DataFrame para exibir os resultados
df_resultados = pd.DataFrame(resultados, columns=['Enfermeira', 'Turno', 'Duração (h)', 'Taxa por Hora', 'Custo Turno'])
df_resultados.loc['Total'] = ['', '', '', '', value(prob.objective)]

# %%
import sqlite3

# Cria uma conexão com o banco de dados em memória
conn = sqlite3.connect(":memory:")

# Carrega o DataFrame como uma tabela SQL
df_resultados.to_sql("resultados", conn, index=False, if_exists="replace")

# Exemplo de consulta: selecionar enfermeiras com custo total maior que 100
query = """
    SELECT sum([Duração (h)]) as a
    FROM resultados
    GROUP BY Enfermeira
    Having a > 40
    """
# Executa a consulta e carrega o resultado em um novo DataFrame
resultado_sql = pd.read_sql_query(query, conn)

# Fecha a conexão
conn.close()

print(resultado_sql)
# Out:
# Empty DataFrame
# Columns: [a]
# Index: []

# %%
df_resultados.to_excel("resultado_com_restricao_de_12h.xlsx", index=False)

print("Resultados exportados para 'resultado_alocacao_enfermeiras.xlsx'")
# Out:
# Resultados exportados para 'resultado_alocacao_enfermeiras.xlsx'
