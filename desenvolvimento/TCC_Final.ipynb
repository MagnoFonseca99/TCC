# %% [markdown]
# ### **Otimização Linear: Algoritmo Branch and Bound aplicado a problemas de alocação de Equipes de Enfermagem**
# Projeto de TCC Referente ao curso de Engenharia Biomédica (ICT - UNIFESP)
#
# Autor: Magno Gonçalves Fonseca
# contato: mgfonseca1999@gmail.com
#
# Este notebook demonstra a modelagem e solução de um problema de alocação de equipes de enfermagem usando otimização linear.
# O objetivo é minimizar os custos operacionais ao mesmo tempo que respeitamos restrições como carga horária e cobertura mínima de profissionais.

# %% [markdown]
# Para saber se o funcionário $ e $ estará escalado no turno $ t $, definimos variáveis binárias que representem esse estado, onde:
#
# $$
# x_{e,t} =
# \begin{cases}
# 1, & \text{se o enfermeiro } e \text{ está no turno } t, \\
# 0, & \text{caso contrário}.
# \end{cases}
# \quad \forall e, t
# $$
#
# Para cada enfermeiro $ e $ e conjunto de turnos simultâneos $ T_s $, impôs-se a seguinte restrição:
#
# $$ \sum_{t \in T_s} x_{e,t} \leq 1. $$
#
# Cada enfermeiro tem uma carga horária máxima semanal de 40 horas, definida como:
#
# $$ \sum_{t} x_{e,t} \cdot D_t \leq 40, \quad \forall e $$
#
# onde $ D_t $ representa a duração do turno $ t $ . Cada turno deve respeitar a quantidade mínima ($ P_{\text{min}} $) e máxima ($ P_{\text{max}} $) de enfermeiros alocados:
#
# $$ P_{\text{min},t} \leq \sum_{e} x_{e,t} \leq P_{\text{max},t}, \quad \forall t. $$
#
# Trabalhar em dois turnos consecutivos é permitido, desde que a soma da duração dos turnos não ultrapasse 10 horas:
#
# $$ x_{e, t_x} + x_{e, t_y} \leq 1, \quad \text{se }(D_{t_x} + D_{t_y}) > 10. $$
#
# $$ \forall \text{ par } (t_x, t_y) \text{ consecutivos}. $$
#
# **Descanso diário:** deve-se garantir que entre turnos não consecutivos (separados por longos intervalos), exista um intervalo mínimo de descanso diário, como 12 horas:
#
# $$ x_{e, t_a} + x_{e, t_b} \leq 1, \quad \text{se } \text{descanso}(t_a, t_b) < 12. $$
#
# O objetivo do modelo foi minimizar o custo total da operação hospitalar. O custo para cada enfermeiro é calculado como o produto da duração dos turnos pelos seus salários por hora:
#
# $$ \text{Custo}_e = \sum_{t} x_{e,t} \cdot D_t \cdot S_e $$
#
# onde $ S_e $ é o salário por hora do enfermeiro $ e $ . O custo total foi, então:
#
# $$ \text{Custo Total} = \sum_{e} \text{Custo}_e. $$

# %% [markdown]
# ##### Passo 1 - Importar depedências

# %%
import pip
REQUIRED_MINIMUM_PANDAS_VERSION = '0.17.1'
try:
    import pandas as pd
    assert pd.__version__ >= REQUIRED_MINIMUM_PANDAS_VERSION
except:
    raise Exception("Version %s or above of Pandas is required to run this notebook" % REQUIRED_MINIMUM_PANDAS_VERSION)

# %%
CSS = """
body {
    margin: 0;
    font-family: Helvetica;
}
table.dataframe {
    border-collapse: collapse;
    border: none;
}
table.dataframe tr {
    border: none;
}
table.dataframe td, table.dataframe th {
    margin: 0;
    border: 1px solid white;
    padding-left: 0.25em;
    padding-right: 0.25em;
}
table.dataframe th:not(:empty) {
    background-color: #fec;
    text-align: left;
    font-weight: normal;
}
table.dataframe tr:nth-child(2) th:empty {
    border-left: none;
    border-right: 1px dashed #888;
}
table.dataframe td {
    border: 2px solid #ccf;
    background-color: #f4f4ff;
}
    table.dataframe thead th:first-child {
        display: none;
    }
    table.dataframe tbody th {
        display: none;
    }
"""

# %%
from IPython.core.display import HTML
HTML('<style>{}</style>'.format(CSS))

from IPython.display import display

# %%
try:
    from StringIO import StringIO
except ImportError:
    from io import StringIO

# %%
# This notebook requires pandas to work
import pandas as pd
from pandas import DataFrame

# Make sure that xlrd package, which is a pandas optional dependency, is installed
# This package is required for Excel I/O
try:
    import xlrd
except:
    if hasattr(sys, 'real_prefix'):
        #we are in a virtual env.
        # !pip install xlrd 
    else:
        # !pip install --user xlrd

# %% [markdown]
# ##### Passo 2 - Carregar os dados do problema para o DataFrame

# %%
# Dados do exemplo original
# data_url = "https://github.com/IBMDecisionOptimization/docplex-examples/blob/master/examples/mp/jupyter/nurses_data.xls?raw=true"


# Dados locais, com personalizações de volumes
file_path = "nurses_data.xls"

# Ler o arquivo Excel local
nurse_xls_file = pd.ExcelFile(file_path)

df_skills = nurse_xls_file.parse('Skills')
df_depts = nurse_xls_file.parse('Departments')
#df_shifts = nurse_xls_file.parse('Shifts_larger')
df_shifts = nurse_xls_file.parse('Shifts')
# Rename df_shifts index
df_shifts.index.name = 'shiftId'

# Index is column 0: name
#df_nurses = nurse_xls_file.parse('Nurses_larger', header=0, index_col=0)
df_nurses = nurse_xls_file.parse('Nurses', header=0, index_col=0)
df_nurse_skills = nurse_xls_file.parse('NurseSkills')
df_vacations = nurse_xls_file.parse('NurseVacations')
df_associations = nurse_xls_file.parse('NurseAssociations')
df_incompatibilities = nurse_xls_file.parse('NurseIncompatibilities')

# Display the nurses dataframe
print("#nurses = {}".format(len(df_nurses)))
print("#shifts = {}".format(len(df_shifts)))
print("#vacations = {}".format(len(df_vacations)))
# Out:
# #nurses = 65
# #shifts = 84
# #vacations = 59

# %%
# maximum work time (in hours)
max_work_time = 40

# %% [markdown]
# ### Passo 3: Preparar os dados
#
# Precisamos pré-computar dados adicionais para os turnos.
# Para cada turno, precisamos do horário de início e de término expressos em horas, contando a partir do início da semana: segunda-feira às 8h é convertido para 8, terça-feira às 8h é convertido para 24 + 8 = 32, e assim por diante.
#
# ####        Sub-passo 1
# Começamos adicionando uma coluna extra chamada `dow` (dia da semana), que converte a string "dia" em um inteiro de 0 a 6 (segunda-feira é 0, domingo é 6).

# %%
days = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]
day_of_weeks = dict(zip(days, range(7)))

# utility to convert a day string e.g. "Monday" to an integer in 0..6
def day_to_day_of_week(day):
    return day_of_weeks[day.strip().lower()]

# for each day name, we normalize it by stripping whitespace and converting it to lowercase
# " Monday" -> "monday"
df_shifts["dow"] = df_shifts.day.apply(day_to_day_of_week)
df_shifts
# Out:
#           department     day  start_time  end_time  min_req  max_req  dow
# shiftId
# 0          Emergency  Monday           2         8        3        5    0
# 1          Emergency  Monday           8        12        4        7    0
# 2          Emergency  Monday          12        18        2        5    0
# 3          Emergency  Monday          18         2        3        7    0
# 4        Orthopedics  Monday           2         8        3        5    0
# ...              ...     ...         ...       ...      ...      ...  ...
# 79       Orthopedics  Sunday           2        12        5        7    6
# 80       Orthopedics  Sunday          12        20        7        9    6
# 81       Orthopedics  Sunday          20         2        8       12    6
# 82        Geriatrics  Sunday           8        10        2        5    6
# 83        Geriatrics  Sunday          12        20        2        5    6
#
# [84 rows x 7 columns]

# %% [markdown]
# #### Sub-passo #2: Calcular o horário de início absoluto de cada turno.
#
# Calcular o horário de início na semana é simples: basta adicionar `24 * dow` à coluna `start_time`. O resultado é armazenado em uma nova coluna chamada `wstart`.

# %%
df_shifts["wstart"] = df_shifts.start_time + 24 * df_shifts.dow

# %% [markdown]
# #### Sub-passo #3: Calcular o horário de término absoluto de cada turno.
#
# Calcular o horário de término absoluto é um pouco mais complicado, pois alguns turnos se estendem até a meia-noite. Por exemplo, o Turno #3 começa na segunda-feira às 18:00 e termina na terça-feira às 2:00. O horário de término absoluto do Turno #3 é 26, não 2.
# A regra geral para calcular o horário de término absoluto é:
#
# `abs_end_time = end_time + 24 * dow + (start_time >= end_time ? 24 : 0)`
#
# Novamente, usamos *pandas* para adicionar uma nova coluna calculada chamada `wend`. Isso é feito usando o método `apply` do *pandas* com uma função anônima `lambda` aplicada às linhas. O parâmetro `raw=True` impede a criação de uma *Series* do *pandas* para cada linha, o que melhora significativamente o desempenho em conjuntos de dados grandes.

# %%
# an auxiliary function to calculate absolute end time of a shift
def calculate_absolute_endtime(start, end, dow):
    return 24*dow + end + (24 if start>=end else 0)

# store the results in a new column
df_shifts["wend"] = df_shifts.apply(lambda row: calculate_absolute_endtime(
        row.start_time, row.end_time, row.dow), axis=1)

# %% [markdown]
# #### Sub-passo #4: Calcular a duração de cada turno.
#
# Calcular a duração de cada turno agora é uma diferença direta entre colunas. O resultado é armazenado na coluna `duration`.

# %%
df_shifts["duration"] = df_shifts.wend - df_shifts.wstart

# %% [markdown]
# #### Sub-passo #5: Calcular a demanda mínima para cada turno.
#
# A demanda mínima é o produto da duração (em horas) pelo número mínimo de enfermeiros requeridos. Assim, em termos de horas de enfermeiro, essa demanda é armazenada em outra nova coluna chamada `min_demand`.
#
# Por fim, exibimos o *DataFrame* de turnos atualizado com todas as colunas calculadas.

# %%
# also compute minimum demand in nurse-hours
df_shifts["min_demand"] = df_shifts.min_req * df_shifts.duration
# finally check the modified shifts dataframe
df_shifts
# Out:
#           department     day  start_time  end_time  min_req  max_req  dow  \
# shiftId
# 0          Emergency  Monday           2         8        3        5    0
# 1          Emergency  Monday           8        12        4        7    0
# 2          Emergency  Monday          12        18        2        5    0
# 3          Emergency  Monday          18         2        3        7    0
# 4        Orthopedics  Monday           2         8        3        5    0
# ...              ...     ...         ...       ...      ...      ...  ...
# 79       Orthopedics  Sunday           2        12        5        7    6
# 80       Orthopedics  Sunday          12        20        7        9    6
# 81       Orthopedics  Sunday          20         2        8       12    6
# 82        Geriatrics  Sunday           8        10        2        5    6
# 83        Geriatrics  Sunday          12        20        2        5    6
#
#          wstart  wend  duration  min_demand
# shiftId
# 0             2     8         6          18
# 1             8    12         4          16
# 2            12    18         6          12
# 3            18    26         8          24
# 4             2     8         6          18
# ...         ...   ...       ...         ...
# 79          146   156        10          50
# 80          156   164         8          56
# 81          164   170         6          48
# 82          152   154         2           4
# 83          156   164         8          16
#
# [84 rows x 11 columns]

# %% [markdown]
# ### Passo 4: Configurar o modelo

# %% [markdown]
# Declarar as variáveis e decisão binarias associadas a alocação dos turnos:
# $$
# x_{e,t} =
# \begin{cases}
# 1, & \text{se o enfermeiro } e \text{ está no turno } t, \\
# 0, & \text{caso contrário}.
# \end{cases}
# \quad \forall e, t
# $$

# %%
from pulp import LpProblem, LpVariable, lpSum, LpStatus, LpStatusOptimal, value, PULP_CBC_CMD, GLPK, CPLEX
import pulp

# Criando o problema de otimização
prob = pulp.LpProblem("nurses", pulp.LpMinimize)

# Definindo as coleções de enfermeiros e turnos
all_nurses = df_nurses.index.values  # Lista de enfermeiros
all_shifts = df_shifts.index.values  # Lista de turnos

# Definindo as variáveis binárias de atribuição
assigned = pulp.LpVariable.dicts(
    "assign", 
    [(nurse, shift) for nurse in all_nurses for shift in all_shifts], 
    cat='Binary'
)

# %% [markdown]
# Encontrar o conjunto de turnos simultâneos $ T_s $, para atribuir a primeira restrição:
# $$ \sum_{t \in T_s} x_{e,t} \leq 1. $$

# %%
import pandasql as psql
import sqlite3

df = pd.DataFrame(df_shifts)

# Conectar ao banco de dados SQLite na memória
conn = sqlite3.connect(':memory:')

# Carregar o DataFrame em uma tabela SQL temporária
df.to_sql('shifts', conn, index=False, if_exists='replace')

# Consulta SQL para encontrar turnos que ocorrem no mesmo horário
query = """
SELECT group_concat(shiftId) as turnos_simultaneos
FROM df
GROUP BY wstart 
HAVING COUNT(*) > 1
"""

# Executar a consulta no DataFrame
turnos_simultaneos = psql.sqldf(query, locals())

# Exibir o resultado
print(turnos_simultaneos)
# Out:
#    turnos_simultaneos
# 0                 0,4
# 1      1,5,8,10,12,14
# 2      2,6,9,11,13,15
# 3                 3,7
# 4               16,20
# 5   17,21,24,26,28,31
# 6   18,22,25,27,29,32
# 7         19,23,30,33
# 8               34,38
# 9         35,39,42,44
# 10        36,40,43,45
# 11              37,41
# 12              46,50
# 13        47,51,54,56
# 14        48,52,55,57
# 15              49,53
# 16              58,62
# 17        59,63,66,68
# 18        60,64,67,69
# 19              61,65
# 20              70,73
# 21              71,74
# 22              72,75
# 23              76,79
# 24           77,80,83
# 25              78,81

# %%
for nurse in all_nurses:
    #Adicionar a restrição para cada enfermeiro e grupo de turnos simultâneos
    for _, row in turnos_simultaneos.iterrows():
        # Pegar os turnos simultâneos e transformá-los em uma lista de inteiros
        simultaneous_shifts = [int(shift_id) for shift_id in row['turnos_simultaneos'].split(',')]
        # Criar a restrição: a soma das variáveis de decisão desses turnos deve ser <= 1 para cada enfermeiro
        prob += lpSum([assigned[(nurse, shift)] for shift in simultaneous_shifts]) <= 1, f"RestrSimult_{nurse}_{simultaneous_shifts}"

# %% [markdown]
# Adicionar a retrição de quantidade maxima trabalhada na semana:
# $$ \sum_{t} x_{e,t} \cdot D_t \leq 40, \quad \forall e $$

# %%
for nurse in all_nurses:
    #Adicionar a restrição de 40 horas trabalhadas na semana
    prob += lpSum([assigned[(nurse, shift)]*df_shifts['duration'][shift] for shift in all_shifts]) <= 40, f"Worktime_{nurse}"

# %% [markdown]
# Adicionar a restrição responsável por demonstrar a quantidade mínima e maxima de funcionários para cada turno:
# $$ P_{\text{min},t} \leq \sum_{e} x_{e,t} \leq P_{\text{max},t}, \quad \forall t. $$

# %%
for shift in all_shifts:
    #Adicionar a restrição de quantidade mínima e maxima
    prob += lpSum([assigned[(nurse, shift)] for nurse in all_nurses]) >= df_shifts['min_req'][shift], f"Min_Req_{shift}"
    prob += lpSum([assigned[(nurse, shift)] for nurse in all_nurses]) <= df_shifts['max_req'][shift], f"Max_Req_{shift}"

# %% [markdown]
# Adicionar as retrições de turnos consecutivos e descanso minimo
#
# $$ x_{e, t_x} + x_{e, t_y} \leq 1, \quad \text{se }(D_{t_x} + D_{t_y}) > 10. $$
# $$ \forall \text{ par } (t_x, t_y) \text{ consecutivos}. $$
# $$ x_{e, t_a} + x_{e, t_b} \leq 1, \quad \text{se } \text{descanso}(t_a, t_b) < 12. $$

# %%
from itertools import combinations
# Lista de pares de turnos no mesmo dia para restrição
max_consecutive_pairs = []
min_rest_pairs = []

for shift1, shift2 in combinations(all_shifts, 2):
    day1 = df_shifts.loc[shift1, 'day']
    day2 = df_shifts.loc[shift2, 'day']
    start_time1 = df_shifts.loc[shift1, 'start_time']
    end_time1 = df_shifts.loc[shift1, 'end_time']
    start_time2 = df_shifts.loc[shift2, 'start_time']
    end_time2 = df_shifts.loc[shift2, 'end_time']

    # Verificar se os turnos são no mesmo dia
    if day1 == day2:
        # Turnos consecutivos (shift2 começa logo após shift1 terminar)
        if start_time2 >= end_time1:
            work_hours = end_time1 - start_time1 + (end_time2 - start_time2)
            if work_hours > 10:
                max_consecutive_pairs.append((shift1, shift2))
        # Turnos não consecutivos (verificar descanso mínimo diário)
        rest_time = start_time2 - end_time1
        if rest_time > 0 and rest_time < 12:  # Menos de 12h de descanso
            min_rest_pairs.append((shift1, shift2))

# %%
# Adicionar restrição para trabalho consecutivo máximo de 10h
for nurse in all_nurses:
    for shift1, shift2 in max_consecutive_pairs:
        prob += (
            assigned[(nurse, shift1)] + assigned[(nurse, shift2)]
        ) <= 1, f"MaxConsecutive_{nurse}_{shift1}_{shift2}"

# %%
# Adicionar restrição para descanso mínimo diário de 12h
for nurse in all_nurses:
    for shift1, shift2 in min_rest_pairs:
        prob += (
            assigned[(nurse, shift1)] + assigned[(nurse, shift2)]
        ) <= 1, f"MinRest_{nurse}_{shift1}_{shift2}"

# %% [markdown]
# Adicionando função objetivo relacionada ao custo da operação:
# $$ \text{Custo}_e = \sum_{t} x_{e,t} \cdot D_t \cdot S_e $$
#
# onde $ S_e $ é o salário por hora do enfermeiro $ e $ . portanto, a função objetivo é demonstrada como:
#
# $$ \text{Minimize   } \sum_{e} \text{Custo}_e. $$

# %%
CustoTotal = 0
for nurse in all_nurses:
    CustoEnfermeira = 0
    for shift in all_shifts:
        CustoEnfermeira += assigned[(nurse, shift)] * df_shifts['duration'][shift] * df_nurses.loc[nurse, 'pay_rate']
    CustoTotal += CustoEnfermeira

prob += CustoTotal, f"CustoTotal"

# %% [markdown]
# Mostrar o problema completo

# %%
print(prob)
# Out:
# nurses:
# MINIMIZE
# 138*assign_('Alice',_np.int64(0)) + 92*assign_('Alice',_np.int64(1)) + 92*assign_('Alice',_np.int64(10)) + 138*assign_('Alice',_np.int64(11)) + 92*assign_('Alice',_np.int64(12)) + 138*assign_('Alice',_np.int64(13)) + 92*assign_('Alice',_np.int64(14)) + 138*assign_('Alice',_np.int64(15)) + 138*assign_('Alice',_np.int64(16)) + 92*assign_('Alice',_np.int64(17)) + 138*assign_('Alice',_np.int64(18)) + 184*assign_('Alice',_np.int64(19)) + 138*assign_('Alice',_np.int64(2)) + 138*assign_('Alice',_np.int64(20)) + 92*assign_('Alice',_np.int64(21)) + 138*assign_('Alice',_np.int64(22)) + 184*assign_('Alice',_np.int64(23)) + 92*assign_('Alice',_np.int64(24)) + 138*assign_('Alice',_np.int64(25)) + 92*assign_('Alice',_np.int64(26)) + 138*assign_('Alice',_np.int64(27)) + 92*assign_('Alice',_np.int64(28)) + 138*assign_('Alice',_np.int64(29)) + 184*assign_('Alice',_np.int64(3)) + 184*assign_('Alice',_np.int64(30)) + 92*assign_('Alice',_np.int64(31)) + 138*assign_('Alice',_np.int64(32)) + 184*assign_('Alice',_np.int64(33)) + 138*assign_('Alice',_np.int64(34)) + 92*assign_('Alice',_np.int64(35)) + 138*assign_('Alice',_np.int64(36)) + 184*assign_('Alice',_np.int64(37)) + 138*assign_('Alice',_np.int64(38)) + 92*assign_('Alice',_np.int64(39)) + 138*assign_('Alice',_np.int64(4)) + 138*assign_('Alice',_np.int64(40)) + 184*assign_('Alice',_np.int64(41)) + 92*assign_('Alice',_np.int64(42)) + 138*assign_('Alice',_np.int64(43)) + 92*assign_('Alice',_np.int64(44)) + 138*assign_('Alice',_np.int64(45)) + 138*assign_('Alice',_np.int64(46)) + 92*assign_('Alice',_np.int64(47)) + 138*assign_('Alice',_np.int64(48)) + 184*assign_('Alice',_np.int64(49)) + 92*assign_('Alice',_np.int64(5)) + 138*assign_('Alice',_np.int64(50)) + 92*assign_('Alice',_np.int64(51)) + 138*assign_('Alice',_np.int64(52)) + 184*assign_('Alice',_np.int64(53)) + 92*assign_('Alice',_np.int64(54)) + 138*assign_('Alice',_np.int64(55)) + 92*assign_('Alice',_np.int64(56)) + 138*assign_('Alice',_np.int64(57)) + 138*assign_('Alice',_np.int64(58)) + 92*assign_('Alice',_np.int64(59)) + 138*assign_('Alice',_np.int64(6)) + 138*assign_('Alice',_np.int64(60)) + 184*assign_('Alice',_np.int64(61)) + 138*assign_('Alice',_np.int64(62)) + 92*assign_('Alice',_np.int64(63)) + 138*assign_('Alice',_np.int64(64)) + 184*assign_('Alice',_np.int64(65)) + 92*assign_('Alice',_np.int64(66)) + 138*assign_('Alice',_np.int64(67)) + 92*assign_('Alice',_np.int64(68)) + 138*assign_('Alice',_np.int64(69)) + 184*assign_('Alice',_np.int64(7)) + 230*assign_('Alice',_np.int64(70)) + 184*assign_('Alice',_np.int64(71)) + 138*assign_('Alice',_np.int64(72)) + 230*assign_('Alice',_np.int64(73)) + 184*assign_('Alice',_np.int64(74)) + 138*assign_('Alice',_np.int64(75)) + 230*assign_('Alice',_np.int64(76)) + 184*assign_('Alice',_np.int64(77)) + 138*assign_('Alice',_np.int64(78)) + 230*assign_('Alice',_np.int64(79)) + 92*assign_('Alice',_np.int64(8)) + 184*assign_('Alice',_np.int64(80)) + 138*assign_('Alice',_np.int64(81)) + 46*assign_('Alice',_np.int64(82)) + 184*assign_('Alice',_np.int64(83)) + 138*assign_('Alice',_np.int64(9)) + 150*assign_('Anne',_np.int64(0)) + 100*assign_('Anne',_np.int64(1)) + 100*assign_('Anne',_np.int64(10)) + 150*assign_('Anne',_np.int64(11)) + 100*assign_('Anne',_np.int64(12)) + 150*assign_('Anne',_np.int64(13)) + 100*assign_('Anne',_np.int64(14)) + 150*assign_('Anne',_np.int64(15)) + 150*assign_('Anne',_np.int64(16)) + 100*assign_('Anne',_np.int64(17)) + 150*assign_('Anne',_np.int64(18)) + 200*assign_('Anne',_np.int64(19)) + 150*assign_('Anne',_np.int64(2)) + 150*assign_('Anne',_np.int64(20)) + 100*assign_('Anne',_np.int64(21)) + 150*assign_('Anne',_np.int64(22)) + 200*assign_('Anne',_np.int64(23)) + 100*assign_('Anne',_np.int64(24)) + 150*assign_('Anne',_np.int64(25)) + 100*assign_('Anne',_np.int64(26)) + 150*assign_('Anne',_np.int64(27)) + 100*assign_('Anne',_np.int64(28)) + 150*assign_('Anne',_np.int64(29)) + 200*assign_('Anne',_np.int64(3)) + 200*assign_('Anne',_np.int64(30)) + 100*assign_('Anne',_np.int64(31 ...
# SUBJECT TO
# RestrSimult_Anne__0,_4_: assign_('Anne',_np.int64(0))
#  + assign_('Anne',_np.int64(4)) <= 1
#
# RestrSimult_Anne__1,_5,_8,_10,_12,_14_: assign_('Anne',_np.int64(1))
#  + assign_('Anne',_np.int64(10)) + assign_('Anne',_np.int64(12))
#  + assign_('Anne',_np.int64(14)) + assign_('Anne',_np.int64(5))
#  + assign_('Anne',_np.int64(8)) <= 1
#
# RestrSimult_Anne__2,_6,_9,_11,_13,_15_: assign_('Anne',_np.int64(11))
#  + assign_('Anne',_np.int64(13)) + assign_('Anne',_np.int64(15))
#  + assign_('Anne',_np.int64(2)) + assign_('Anne',_np.int64(6))
#  + assign_('Anne',_np.int64(9)) <= 1
#
# RestrSimult_Anne__3,_7_: assign_('Anne',_np.int64(3))
#  + assign_('Anne',_np.int64(7)) <= 1
#
# RestrSimult_Anne__16,_20_: assign_('Anne',_np.int64(16))
#  + assign_('Anne',_np.int64(20)) <= 1
#
# RestrSimult_Anne__17,_21,_24,_26,_28,_31_: assign_('Anne',_np.int64(17))
#  + assign_('Anne',_np.int64(21)) + assign_('Anne',_np.int64(24))
#  + assign_('Anne',_np.int64(26)) + assign_('Anne',_np.int64(28))
#  + assign_('Anne',_np.int64(31)) <= 1
#
# RestrSimult_Anne__18,_22,_25,_27,_29,_32_: assign_('Anne',_np.int64(18))
#  + assign_('Anne',_np.int64(22)) + assign_('Anne',_np.int64(25))
#  + assign_('Anne',_np.int64(27)) + assign_('Anne',_np.int64(29))
#  + assign_('Anne',_np.int64(32)) <= 1
#
# RestrSimult_Anne__19,_23,_30,_33_: assign_('Anne',_np.int64(19))
#  + assign_('Anne',_np.int64(23)) + assign_('Anne',_np.int64(30))
#  + assign_('Anne',_np.int64(33)) <= 1
#
# RestrSimult_Anne__34,_38_: assign_('Anne',_np.int64(34))
#  + assign_('Anne',_np.int64(38)) <= 1
#
# RestrSimult_Anne__35,_39,_42,_44_: assign_('Anne',_np.int64(35))
#  + assign_('Anne',_np.int64(39)) + assign_('Anne',_np.int64(42))
#  + assign_('Anne',_np.int64(44)) <= 1
#
# RestrSimult_Anne__36,_40,_43,_45_: assign_('Anne',_np.int64(36))
#  + assign_('Anne',_np.int64(40)) + assign_('Anne',_np.int64(43))
#  + assign_('Anne',_np.int64(45)) <= 1
#
# RestrSimult_Anne__37,_41_: assign_('Anne',_np.int64(37))
#  + assign_('Anne',_np.int64(41)) <= 1
#
# RestrSimult_Anne__46,_50_: assign_('Anne',_np.int64(46))
#  + assign_('Anne',_np.int64(50)) <= 1
#
# RestrSimult_Anne__47,_51,_54,_56_: assign_('Anne',_np.int64(47))
#  + assign_('Anne',_np.int64(51)) + assign_('Anne',_np.int64(54))
#  + assign_('Anne',_np.int64(56)) <= 1
#
# RestrSimult_Anne__48,_52,_55,_57_: assign_('Anne',_np.int64(48))
#  + assign_('Anne',_np.int64(52)) + assign_('Anne',_np.int64(55))
#  + assign_('Anne',_np.int64(57)) <= 1
#
# RestrSimult_Anne__49,_53_: assign_('Anne',_np.int64(49))
#  + assign_('Anne',_np.int64(53)) <= 1
#
# RestrSimult_Anne__58,_62_: assign_('Anne',_np.int64(58))
#  + assign_('Anne',_np.int64(62)) <= 1
#
# RestrSimult_Anne__59,_63,_66,_68_: assign_('Anne',_np.int64(59))
#  + assign_('Anne',_np.int64(63)) + assign_('Anne',_np.int64(66))
#  + assign_('Anne',_np.int64(68)) <= 1
#
# RestrSimult_Anne__60,_64,_67,_69_: assign_('Anne',_np.int64(60))
#  + assign_('Anne',_np.int64(64)) + assign_('Anne',_np.int64(67))
#  + assign_('Anne',_np.int64(69)) <= 1
#
# RestrSimult_Anne__61,_65_: assign_('Anne',_np.int64(61))
#  + assign_('Anne',_np.int64(65)) <= 1
#
# RestrSimult_Anne__70,_73_: assign_('Anne',_np.int64(70))
#  + assign_('Anne',_np.int64(73)) <= 1
#
# RestrSimult_Anne__71,_74_: assign_('Anne',_np.int64(71))
#  + assign_('Anne',_np.int64(74)) <= 1
#
# RestrSimult_Anne__72,_75_: assign_('Anne',_np.int64(72))
#  + assign_('Anne',_np.int64(75)) <= 1
#
# RestrSimult_Anne__76,_79_: assign_('Anne',_np.int64(76))
#  + assign_('Anne',_np.int64(79)) <= 1
#
# RestrSimult_Anne__77,_80,_83_: assign_('Anne',_np.int64(77))
#  + assign_('Anne',_np.int64(80)) + assign_('Anne',_np.int64(83)) <= 1
#
# RestrSimult_Anne__78,_81_: assign_('Anne',_np.int64(78))
#  + assign_('Anne',_np.int64(81)) <= 1
#
# RestrSimult_Bethanie__0,_4_: assign_('Bethanie',_np.int64(0))
#  + assign_('Bethanie',_np.int64(4)) <= 1
#
# RestrSimult_Bethanie__1,_5,_8,_10,_12,_14_: assign_('Bethanie',_np.int64(1))
#  + assign_('Bethanie',_np.int64(10)) + assign_('Bethanie',_np.int64(12))
#  + assign_('Bethanie',_np.int64(14)) + assign_('Bethanie',_np.int64(5))
#  + assign_('Bethanie',_np.int64(8)) <= 1
#
# RestrSimult_Bethanie__2,_6,_9,_11,_13,_15_: assign_('Bethanie',_np.int64(11))
#  + assign_('Bethanie',_np.int64(13)) + assign_('Bethanie',_np.int64(15))
#  + assign_('Bethanie',_np.int64(2)) + assign_('Bethanie',_np.int64(6))
#  + assign_('Bethanie',_np.int64(9)) <= 1
#
# RestrSimult_Bethanie__3,_7_: assign_('Bethanie',_np.int64(3))
#  + assign_('Bethanie',_np.int64(7)) <= 1
#
# RestrSimult_Bethanie__16,_20_: assign_('Bethanie',_np.int64(16))
#  + assign_('Bethanie',_np.int64(20)) <= 1
#
# RestrSimult_Bethanie__17,_21,_24,_26,_28,_31_:
#  assign_('Bethanie',_np.int64(17)) + assign_('Bethanie',_np.int64(21))
#  + assign_('Bethanie',_np.int64(24)) + assign_('Bethanie',_np.int64(26))
#  + assign_('Bethanie',_np.int64(28)) + assign_('Bethanie',_np.int64(31)) <= 1
#
# RestrSimult_Bethanie__18,_22,_25,_27,_29,_32_:
#  assign_('Bethanie',_np.int64(18)) + assign_('Bethanie',_np.int64(22))
#  + assign_('Bethanie',_np.int64(25)) + assign_('Bethanie',_np.int64(27))
#  + assign_('Bethanie',_np.int64(29)) + assign_('Bethanie',_np.int64(32)) <= 1
#
# RestrSimult_Bethanie__19,_23,_30,_33_: assign_('Bethanie',_np.int64(19))
#  + assign_('Bethanie',_np.int64(23)) + assign_('Bethanie',_np.int64(30))
#  + assign_('Bethanie',_np.int64(33)) <= 1
#
# RestrSimult_Bethanie__34,_38_: assign_('Bethanie',_np.int64(34))
#  + assign_('Bethanie',_np.int64(38)) <= 1
#
# RestrSimult_Bethanie__35,_39,_42,_44_: assign_('Bethanie',_np.int64(35))
#  + assign_('Bethanie',_np.int64(39)) + assign_('Bethanie',_np.int64(42))
#  + assign_('Bethanie',_np.int64(44)) <= 1
#
# RestrSimult_Bethanie__36,_40,_43,_45_: assign_('Bethanie',_np.int64(36))
#  + assign_('Bethanie',_np.int64(40)) + assign_('Bethanie',_np.int64(43))
#  + assign_('Bethanie',_np.int64(45)) <= 1
#
# RestrSimult_Bethanie__37,_41_: assign_('Bethanie',_np.int64(37))
#  + assign_('Bethanie',_np.int64(41)) <= 1
#
# RestrSimult_Bethanie__46,_50_: assign_('Bethanie',_np.int64(46))
#  + assign_('Bethanie',_np.int64(50)) <= 1
#
# RestrSimult_Bethanie__47,_51,_54,_56_: assign_('Bethanie',_np.int64(47))
#  + assign_('Bethanie',_np.int64(51)) + assign_('Bethanie',_np.int64(54))
#  + assign_('Bethanie',_np.int64(56)) <= 1
#
# RestrSimult_Bethanie__48,_52,_55,_57_: assign_('Bethanie',_np.int64(48))
#  + assign_('Bethanie',_np.int64(52)) + assign_('Bethanie',_np.int64(55))
#  + assign_('Bethanie',_np.int64(57)) <= 1
#
# RestrSimult_Bethanie__49,_53_: assign_('Bethanie',_np.int64(49))
#  + assign_('Bethanie',_np.int64(53)) <= 1
#
# RestrSimult_Bethanie__58,_62_: assign_('Bethanie',_np.int64(58))
#  + assign_('Bethanie',_np.int64(62)) <= 1
#
# RestrSimult_Bethanie__59,_63,_66,_68_: assign_('Bethanie',_np.int64(59))
#  + assign_('Bethanie',_np.int64(63)) + assign_('Bethanie',_np.int64(66))
#  + assign_('Bethanie',_np.int64(68)) <= 1
#
# RestrSimult_Bethanie__60,_64,_67,_69_: assign_('Bethanie',_np.int64(60))
#  + assign_('Bethanie',_np.int64(64)) + assign_('Bethanie',_np.int64(67))
#  + assign_('Bethanie',_np.int64(69)) <= 1
#
# RestrSimult_Bethanie__61,_65_: assign_('Bethanie',_np.int64(61))
#  + assign_('Bethanie',_np.int64(65)) <= 1
#
# RestrSimult_Bethanie__70,_73_: assign_('Bethanie',_np.int64(70))
#  + assign_('Bethanie',_np.int64(73)) <= 1
#
# RestrSimult_Bethanie__71,_74_: assign_('Bethanie',_np.int64(71))
#  + assign_('Bethanie',_np.int64(74)) <= 1
#
# RestrSimult_Bethanie__72,_75_: assign_('Bethanie',_np.int64(72))
#  + assign_('Bethanie',_np.int64(75)) <= 1
#
# RestrSimult_Bethanie__76,_79_: assign_('Bethanie',_np.int64(76))
#  + assign_('Bethanie',_np.int64(79)) <= 1
#
# RestrSimult_Bethanie__77,_80,_83_: assign_('Bethanie',_np.int64(77))
#  + assign_('Bethanie',_np.int64(80)) + assign_('Bethanie',_np.int64(83)) <= 1
#
# RestrSimult_Bethanie__78,_81_: assign_('Bethanie',_np.int64(78))
#  + assign_('Bethanie',_np.int64(81)) <= 1
#
# RestrSimult_Betsy__0,_4_: assign_('Betsy',_np.int64(0))
#  + assign_('Betsy',_np.int64(4)) <= 1
#
# RestrSimult_Betsy__1,_5,_8,_10,_12,_14_: assign_('Betsy',_np.int64(1))
#  + assign_('Betsy',_np.int64(10)) + assign_('Betsy',_np.int64(12))
#  + assign_('Betsy',_np.int64(14)) + assign_('Betsy',_np.int64(5))
#  + assign_('Betsy',_np.int64(8)) <= 1
#
# RestrSimult_Betsy__2,_6,_9,_11,_13,_15_: assign_('Betsy',_np.int64(11))
#  + assign_('Betsy',_np.int64(13)) + assign_('Betsy',_np.int64(15))
#  + assign_('Betsy',_np.int64(2)) + assign_('Betsy',_np.int64(6))
#  + assign_('Betsy',_np.int64(9)) <= 1
#
# RestrSimult_Betsy__3,_7_: assign_('Betsy',_np.int64(3))
#  + assign_('Betsy',_np.int64(7)) <= 1
#
# RestrSimult_Betsy__16,_20_: assign_('Betsy',_np.int64(16))
#  + assign_('Betsy',_np.int64(20)) <= 1
#
# RestrSimult_Betsy__17,_21,_24,_26,_28,_31_: assign_('Betsy',_np.int64(17))
#  + assign_('Betsy',_np.int64(21)) + assign_('Betsy',_np.int64(24))
#  + assign_('Betsy',_np.int64(26)) + assign_('Betsy',_np.int64(28))
#  + assign_('Betsy',_np.int64(31)) <= 1
#
# RestrSimult_Betsy__18,_22,_25,_27,_29,_32_: assign_('Betsy',_np.int64(18))
#  + assign_('Betsy',_np.int64(22)) + assign_('Betsy',_np.int64(25))
#  + assign_('Betsy',_np.int64(27)) + assign_('Betsy',_np.int64(29))
#  + assign_('Betsy',_np.int64(32)) <= 1
#
# RestrSimult_Betsy__19,_23,_30,_33_: assign_('Betsy',_np.int64(19))
#  + assign_('Betsy',_np.int64(23)) + assign_('Betsy',_np.int64(30))
#  + assign_('Betsy',_np.int64(33)) <= 1
#
# RestrSimult_Betsy__34,_38_: assign_('Betsy',_np.int64(34))
#  + assign_('Betsy',_np.int64(38)) <= 1
#
# RestrSimult_Betsy__35,_39,_42,_44_: assign_('Betsy',_np.int64(35))
#  + assign_('Betsy',_np.int64(39)) + assign_('Betsy',_np.int64(42))
#  + assign_('Betsy',_np.int64(44)) <= 1
#
# RestrSimult_Betsy__36,_40,_43,_45_: assign_('Betsy',_np.int64(36))
#  + assign_('Betsy',_np.int64(40)) + assign_('Betsy',_np.int64(43))
#  + assign_('Betsy',_np.int64(45)) <= 1
#
# RestrSimult_Betsy__37,_41_: assign_('Betsy',_np.int64(37))
#  + assign_('Betsy',_np.int64(41)) <= 1
#
# RestrSimult_Betsy__46,_50_: assign_('Betsy',_np.int64(46))
#  + assign_('Betsy',_np.int64(50)) <= 1
#
# RestrSimult_Betsy__47,_51,_54,_56_: assign_('Betsy',_np.int64(47))
#  + assign_('Betsy',_np.int64(51)) + assign_('Betsy',_np.int64(54))
#  + assign_('Betsy',_np.int64(56)) <= 1
#
# RestrSimult_Betsy__48,_52,_55,_57_: assign_('Betsy',_np.int64(48))
#  + assign_('Betsy',_np.int64(52)) + assign_('Betsy',_np.int64(55))
#  + assign_('Betsy',_np.int64(57)) <= 1
#
# RestrSimult_Betsy__49,_53_: assign_('Betsy',_np.int64(49))
#  + assign_('Betsy',_np.int64(53)) <= 1
#
# RestrSimult_Betsy__58,_62_: assign_('Betsy',_np.int64(58))
#  + assign_('Betsy',_np.int64(62)) <= 1
#
# RestrSimult_Betsy__59,_63,_66,_68_: assign_('Betsy',_np.int64(59))
#  + assign_('Betsy',_np.int64(63)) + assign_('Betsy',_np.int64(66))
#  + assign_('Betsy',_np.int64(68)) <= 1
#
# RestrSimult_Betsy__60,_64,_67,_69_: assign_('Betsy',_np.int64(60))
#  + assign_('Betsy',_np.int64(64)) + assign_('Betsy',_np.int64(67))
#  + assign_('Betsy',_np.int64(69)) <= 1
#
# RestrSimult_Betsy__61,_65_: assign_('Betsy',_np.int64(61))
#  + assign_('Betsy',_np.int64(65)) <= 1
#
# RestrSimult_Betsy__70,_73_: assign_('Betsy',_np.int64(70))
#  + assign_('Betsy',_np.int64(73)) <= 1
#
# RestrSimult_Betsy__71,_74_: assign_('Betsy',_np.int64(71))
#  + assign_('Betsy',_np.int64(74)) <= 1
#
# RestrSimult_Betsy__72,_75_: assign_('Betsy',_np.int64(72))
#  + assign_('Betsy',_np.int64(75)) <= 1
#
# RestrSimult_Betsy__76,_79_: assign_('Betsy',_np.int64(76))
#  + assign_('Betsy',_np.int64(79)) <= 1
#
# RestrSimult_Betsy__77,_80,_83_: assign_('Betsy',_np.int64(77))
#  + assign_('Betsy',_np.int64(80)) + assign_('Betsy',_np.int64(83)) <= 1
#
# RestrSimult_Betsy__78,_81_: assign_('Betsy',_np.int64(78))
#  + assign_('Betsy',_np.int64(81)) <= 1
#
# RestrSimult_Cathy__0,_4_: assign_('Cathy',_np.int64(0))
#  + assign_('Cathy',_np.int64(4)) <= 1
#
# RestrSimult_Cathy__1,_5,_8,_10,_12,_14_: assign_('Cathy',_np.int64(1))
#  + assign_('Cathy',_np.int64(10)) + assign_('Cathy',_np.int64(12))
#  + assign_('Cathy',_np.int64(14)) + assign_('Cathy',_np.int64(5))
#  + assign_('Cathy',_np.int64(8)) <= 1
#
# RestrSimult_Cathy__2,_6,_9,_11,_13,_15_: assign_('Cathy',_np.int64(11))
#  + assign_('Cathy',_np.int64(13)) + assign_('Cathy',_np.int64(15))
#  + assign_('Cathy',_np.int64(2)) + assign_('Cathy',_np.int64(6))
#  + assign_('Cathy',_np.int64(9)) <= 1
#
# RestrSimult_Cathy__3,_7_: assign_('Cathy',_np.int64(3))
#  + assign_('Cathy',_np.int64(7)) <= 1
#
# RestrSimult_Cathy__16,_20_: assign_('Cathy',_np.int64(16))
#  + assign_('Cathy',_np.int64(20)) <= 1
#
# RestrSimult_Cathy__17,_21,_24,_26,_28,_31_: assign_('Cathy',_np.int64(17))
#  + assign_('Cathy',_np.int64(21)) + assign_('Cathy',_np.int64(24))
#  + assign_('Cathy',_np.int64(26)) + assign_('Cathy',_np.int64(28))
#  + assign_('Cathy',_np.int64(31)) <= 1
#
# RestrSimult_Cathy__18,_22,_25,_27,_29,_32_: assign_('Cathy',_np.int64(18))
#  + assign_('Cathy',_np.int64(22)) + assign_('Cathy',_np.int64(25))
#  + assign_('Cathy',_np.int64(27)) + assign_('Cathy',_np.int64(29))
#  + assign_('Cathy',_np.int64(32)) <= 1
#
# RestrSimult_Cathy__19,_23,_30,_33_: assign_('Cathy',_np.int64(19))
#  + assign_('Cathy',_np.int64(23)) + assign_('Cathy',_np.int64(30))
#  + assign_('Cathy',_np.int64(33)) <= 1
#
# RestrSimult_Cathy__34,_38_: assign_('Cathy',_np.int64(34))
#  + assign_('Cathy',_np.int64(38)) <= 1
#
# RestrSimult_Cathy__35,_39,_42,_44_: assign_('Cathy',_np.int64(35))
#  + assign_('Cathy',_np.int64(39)) + assign_('Cathy',_np.int64(42))
#  + assign_('Cathy',_np.int64(44)) <= 1
#
# RestrSimult_Cathy__36,_40,_43,_45_: assign_('Cathy',_np.int64(36))
#  + assign_('Cathy',_np.int64(40)) + assign_('Cathy',_np.int64(43))
#  + assign_('Cathy',_np.int64(45)) <= 1
#
# RestrSimult_Cathy__37,_41_: assign_('Cathy',_np.int64(37))
#  + assign_('Cathy',_np.int64(41)) <= 1
#
# RestrSimult_Cathy__46,_50_: assign_('Cathy',_np.int64(46))
#  + assign_('Cathy',_np.int64(50)) <= 1
#
# RestrSimult_Cathy__47,_51,_54,_56_: assign_('Cathy',_np.int64(47))
#  + assign_('Cathy',_np.int64(51)) + assign_('Cathy',_np.int64(54))
#  + assign_('Cathy',_np.int64(56)) <= 1
#
# RestrSimult_Cathy__48,_52,_55,_57_: assign_('Cathy',_np.int64(48))
#  + assign_('Cathy',_np.int64(52)) + assign_('Cathy',_np.int64(55))
#  + assign_('Cathy',_np.int64(57)) <= 1
#
# RestrSimult_Cathy__49,_53_: assign_('Cathy',_np.int64(49))
#  + assign_('Cathy',_np.int64(53)) <= 1
#
# RestrSimult_Cathy__58,_62_: assign_('Cathy',_np.int64(58))
#  + assign_('Cathy',_np.int64(62)) <= 1
#
# RestrSimult_Cathy__59,_63,_66,_68_: assign_('Cathy',_np.int64(59))
#  + assign_('Cathy',_np.int64(63)) + assign_('Cathy',_np.int64(66))
#  + assign_('Cathy',_np.int64(68)) <= 1
#
# RestrSimult_Cathy__60,_64,_67,_69_: assign_('Cathy',_np.int64(60))
#  + assign_('Cathy',_np.int64(64)) + assign_('Cathy',_np.int64(67))
#  + assign_('Cathy',_np.int64(69)) <= 1
#
# RestrSimult_Cathy__61,_65_: assign_('Cathy',_np.int64(61))
#  + assign_('Cathy',_np.int64(65)) <= 1
#
# RestrSimult_Cathy__70,_73_: assign_('Cathy',_np.int64(70))
#  + assign_('Cathy',_np.int64(73)) <= 1
#
# RestrSimult_Cathy__71,_74_: assign_('Cathy',_np.int64(71))
#  + assign_('Cathy',_np.int64(74)) <= 1
#
# RestrSimult_Cathy__72,_75_: assign_('Cathy',_np.int64(72))
#  + assign_('Cathy',_np.int64(75)) <= 1
#
# RestrSimult_Cathy__76,_79_: assign_('Cathy',_np.int64(76))
#  + assign_('Cathy',_np.int64(79)) <= 1
#
# RestrSimult_Cathy__77,_80,_83_: assign_('Cathy',_np.int64(77))
#  + assign_('Cathy',_np.int64(80)) + assign_('Cathy',_np.int64(83)) <= 1
#
# RestrSimult_Cathy__78,_81_: assign_('Cathy',_np.int64(78))
#  + assign_('Cathy',_np.int64(81)) <= 1
#
# RestrSimult_Cecilia__0,_4_: assign_('Cecilia',_np.int64(0))
#  + assign_('Cecilia',_np.int64(4)) <= 1
#
# RestrSimult_Cecilia__1,_5,_8,_10,_12,_14_: assign_('Cecilia',_np.int64(1))
#  + assign_('Cecilia',_np.int64(10)) + assign_('Cecilia',_np.int64(12))
#  + assign_('Cecilia',_np.int64(14)) + assign_('Cecilia',_np.int64(5))
#  + assign_('Cecilia',_np.int64(8)) <= 1
#
# RestrSimult_Cecilia__2,_6,_9,_11,_13,_15_: assign_('Cecilia',_np.int64(11))
#  + assign_('Cecilia',_np.int64(13)) + assign_('Cecilia',_np.int64(15))
#  + assign_('Cecilia',_np.int64(2)) + assign_('Cecilia',_np.int64(6))
#  + assign_('Cecilia',_np.int64(9)) <= 1
#
# RestrSimult_Cecilia__3,_7_: assign_('Cecilia',_np.int64(3))
#  + assign_('Cecilia',_np.int64(7)) <= 1
#
# RestrSimult_Cecilia__16,_20_: assign_('Cecilia',_np.int64(16))
#  + assign_('Cecilia',_np.int64(20)) <= 1
#
# RestrSimult_Cecilia__17,_21,_24,_26,_28,_31_: assign_('Cecilia',_np.int64(17))
#  + assign_('Cecilia',_np.int64(21)) + assign_('Cecilia',_np.int64(24))
#  + assign_('Cecilia',_np.int64(26)) + assign_('Cecilia',_np.int64(28))
#  + assign_('Cecilia',_np.int64(31)) <= 1
#
# RestrSimult_Cecilia__18,_22,_25,_27,_29,_32_: assign_('Cecilia',_np.int64(18))
#  + assign_('Cecilia',_np.int64(22)) + assign_('Cecilia',_np.int64(25))
#  + assign_('Cecilia',_np.int64(27)) + assign_('Cecilia',_np.int64(29))
#  + assign_('Cecilia',_np.int64(32)) <= 1
#
# RestrSimult_Cecilia__19,_23,_30,_33_: assign_('Cecilia',_np.int64(19))
#  + assign_('Cecilia',_np.int64(23)) + assign_('Cecilia',_np.int64(30))
#  + assign_('Cecilia',_np.int64(33)) <= 1
#
# RestrSimult_Cecilia__34,_38_: assign_('Cecilia',_np.int64(34))
#  + assign_('Cecilia',_np.int64(38)) <= 1
#
# RestrSimult_Cecilia__35,_39,_42,_44_: assign_('Cecilia',_np.int64(35))
#  + assign_('Cecilia',_np.int64(39)) + assign_('Cecilia',_np.int64(42))
#  + assign_('Cecilia',_np.int64(44)) <= 1
#
# RestrSimult_Cecilia__36,_40,_43,_45_: assign_('Cecilia',_np.int64(36))
#  + assign_('Cecilia',_np.int64(40)) + assign_('Cecilia',_np.int64(43))
#  + assign_('Cecilia',_np.int64(45)) <= 1
#
# RestrSimult_Cecilia__37,_41_: assign_('Cecilia',_np.int64(37))
#  + assign_('Cecilia',_np.int64(41)) <= 1
#
# RestrSimult_Cecilia__46,_50_: assign_('Cecilia',_np.int64(46))
#  + assign_('Cecilia',_np.int64(50)) <= 1
#
# RestrSimult_Cecilia__47,_51,_54,_56_: assign_('Cecilia',_np.int64(47))
#  + assign_('Cecilia',_np.int64(51)) + assign_('Cecilia',_np.int64(54))
#  + assign_('Cecilia',_np.int64(56)) <= 1
#
# RestrSimult_Cecilia__48,_52,_55,_57_: assign_('Cecilia',_np.int64(48))
#  + assign_('Cecilia',_np.int64(52)) + assign_('Cecilia',_np.int64(55))
#  + assign_('Cecilia',_np.int64(57)) <= 1
#
# RestrSimult_Cecilia__49,_53_: assign_('Cecilia',_np.int64(49))
#  + assign_('Cecilia',_np.int64(53)) <= 1
#
# RestrSimult_Cecilia__58,_62_: assign_('Cecilia',_np.int64(58))
#  + assign_('Cecilia',_np.int64(62)) <= 1
#
# RestrSimult_Cecilia__59,_63,_66,_68_: assign_('Cecilia',_np.int64(59))
#  + assign_('Cecilia',_np.int64(63)) + assign_('Cecilia',_np.int64(66))
#  + assign_('Cecilia',_np.int64(68)) <= 1
#
# RestrSimult_Cecilia__60,_64,_67,_69_: assign_('Cecilia',_np.int64(60))
#  + assign_('Cecilia',_np.int64(64)) + assign_('Cecilia',_np.int64(67))
#  + assign_('Cecilia',_np.int64(69)) <= 1
#
# RestrSimult_Cecilia__61,_65_: assign_('Cecilia',_np.int64(61))
#  + assign_('Cecilia',_np.int64(65)) <= 1
#
# RestrSimult_Cecilia__70,_73_: assign_('Cecilia',_np.int64(70))
#  + assign_('Cecilia',_np.int64(73)) <= 1
#
# RestrSimult_Cecilia__71,_74_: assign_('Cecilia',_np.int64(71))
#  + assign_('Cecilia',_np.int64(74)) <= 1
#
# RestrSimult_Cecilia__72,_75_: assign_('Cecilia',_np.int64(72))
#  + assign_('Cecilia',_np.int64(75)) <= 1
#
# RestrSimult_Cecilia__76,_79_: assign_('Cecilia',_np.int64(76))
#  + assign_('Cecilia',_np.int64(79)) <= 1
#
# RestrSimult_Cecilia__77,_80,_83_: assign_('Cecilia',_np.int64(77))
#  + assign_('Cecilia',_np.int64(80)) + assign_('Cecilia',_np.int64(83)) <= 1
#
# RestrSimult_Cecilia__78,_81_: assign_('Cecilia',_np.int64(78))
#  + assign_('Cecilia',_np.int64(81)) <= 1
#
# RestrSimult_Chris__0,_4_: assign_('Chris',_np.int64(0))
#  + assign_('Chris',_np.int64(4)) <= 1
#
# RestrSimult_Chris__1,_5,_8,_10,_12,_14_: assign_('Chris',_np.int64(1))
#  + assign_('Chris',_np.int64(10)) + assign_('Chris',_np.int64(12))
#  + assign_('Chris',_np.int64(14)) + assign_('Chris',_np.int64(5))
#  + assign_('Chris',_np.int64(8)) <= 1
#
# RestrSimult_Chris__2,_6,_9,_11,_13,_15_: assign_('Chris',_np.int64(11))
#  + assign_('Chris',_np.int64(13)) + assign_('Chris',_np.int64(15))
#  + assign_('Chris',_np.int64(2)) + assign_('Chris',_np.int64(6))
#  + assign_('Chris',_np.int64(9)) <= 1
#
# RestrSimult_Chris__3,_7_: assign_('Chris',_np.int64(3))
#  + assign_('Chris',_np.int64(7)) <= 1
#
# RestrSimult_Chris__16,_20_: assign_('Chris',_np.int64(16))
#  + assign_('Chris',_np.int64(20)) <= 1
#
# RestrSimult_Chris__17,_21,_24,_26,_28,_31_: assign_('Chris',_np.int64(17))
#  + assign_('Chris',_np.int64(21)) + assign_('Chris',_np.int64(24))
#  + assign_('Chris',_np.int64(26)) + assign_('Chris',_np.int64(28))
#  + assign_('Chris',_np.int64(31)) <= 1
#
# RestrSimult_Chris__18,_22,_25,_27,_29,_32_: assign_('Chris',_np.int64(18))
#  + assign_('Chris',_np.int64(22)) + assign_('Chris',_np.int64(25))
#  + assign_('Chris',_np.int64(27)) + assign_('Chris',_np.int64(29))
#  + assign_('Chris',_np.int64(32)) <= 1
#
# RestrSimult_Chris__19,_23,_30,_33_: assign_('Chris',_np.int64(19))
#  + assign_('Chris',_np.int64(23)) + assign_('Chris',_np.int64(30))
#  + assign_('Chris',_np.int64(33)) <= 1
#
# RestrSimult_Chris__34,_38_: assign_('Chris',_np.int64(34))
#  + assign_('Chris',_np.int64(38)) <= 1
#
# RestrSimult_Chris__35,_39,_42,_44_: assign_('Chris',_np.int64(35))
#  + assign_('Chris',_np.int64(39)) + assign_('Chris',_np.int64(42))
#  + assign_('Chris',_np.int64(44)) <= 1
#
# RestrSimult_Chris__36,_40,_43,_45_: assign_('Chris',_np.int64(36))
#  + assign_('Chris',_np.int64(40)) + assign_('Chris',_np.int64(43))
#  + assign_('Chris',_np.int64(45)) <= 1
#
# RestrSimult_Chris__37,_41_: assign_('Chris',_np.int64(37))
#  + assign_('Chris',_np.int64(41)) <= 1
#
# RestrSimult_Chris__46,_50_: assign_('Chris',_np.int64(46))
#  + assign_('Chris',_np.int64(50)) <= 1
#
# RestrSimult_Chris__47,_51,_54,_56_: assign_('Chris',_np.int64(47))
#  + assign_('Chris',_np.int64(51)) + assign_('Chris',_np.int64(54))
#  + assign_('Chris',_np.int64(56)) <= 1
#
# RestrSimult_Chris__48,_52,_55,_57_: assign_('Chris',_np.int64(48))
#  + assign_('Chris',_np.int64(52)) + assign_('Chris',_np.int64(55))
#  + assign_('Chris',_np.int64(57)) <= 1
#
# RestrSimult_Chris__49,_53_: assign_('Chris',_np.int64(49))
#  + assign_('Chris',_np.int64(53)) <= 1
#
# RestrSimult_Chris__58,_62_: assign_('Chris',_np.int64(58))
#  + assign_('Chris',_np.int64(62)) <= 1
#
# RestrSimult_Chris__59,_63,_66,_68_: assign_('Chris',_np.int64(59))
#  + assign_('Chris',_np.int64(63)) + assign_('Chris',_np.int64(66))
#  + assign_('Chris',_np.int64(68)) <= 1
#
# RestrSimult_Chris__60,_64,_67,_69_: assign_('Chris',_np.int64(60))
#  + assign_('Chris',_np.int64(64)) + assign_('Chris',_np.int64(67))
#  + assign_('Chris',_np.int64(69)) <= 1
#
# RestrSimult_Chris__61,_65_: assign_('Chris',_np.int64(61))
#  + assign_('Chris',_np.int64(65)) <= 1
#
# RestrSimult_Chris__70,_73_: assign_('Chris',_np.int64(70))
#  + assign_('Chris',_np.int64(73)) <= 1
#
# RestrSimult_Chris__71,_74_: assign_('Chris',_np.int64(71))
#  + assign_('Chris',_np.int64(74)) <= 1
#
# RestrSimult_Chris__72,_75_: assign_('Chris',_np.int64(72))
#  + assign_('Chris',_np.int64(75)) <= 1
#
# RestrSimult_Chris__76,_79_: assign_('Chris',_np.int64(76))
#  + assign_('Chris',_np.int64(79)) <= 1
#
# RestrSimult_Chris__77,_80,_83_: assign_('Chris',_np.int64(77))
#  + assign_('Chris',_np.int64(80)) + assign_('Chris',_np.int64(83)) <= 1
#
# RestrSimult_Chris__78,_81_: assign_('Chris',_np.int64(78))
#  + assign_('Chris',_np.int64(81)) <= 1
#
# RestrSimult_Cindy__0,_4_: assign_('Cindy',_np.int64(0))
#  + assign_('Cindy',_np.int64(4)) <= 1
#
# RestrSimult_Cindy__1,_5,_8,_10,_12,_14_: assign_('Cindy',_np.int64(1))
#  + assign_('Cindy',_np.int64(10)) + assign_('Cindy',_np.int64(12))
#  + assign_('Cindy',_np.int64(14)) + assign_('Cindy',_np.int64(5))
#  + assign_('Cindy',_np.int64(8)) <= 1
#
# RestrSimult_Cindy__2,_6,_9,_11,_13,_15_: assign_('Cindy',_np.int64(11))
#  + assign_('Cindy',_np.int64(13)) + assign_('Cindy',_np.int64(15))
#  + assign_('Cindy',_np.int64(2)) + assign_('Cindy',_np.int64(6))
#  + assign_('Cindy',_np.int64(9)) <= 1
#
# RestrSimult_Cindy__3,_7_: assign_('Cindy',_np.int64(3))
#  + assign_('Cindy',_np.int64(7)) <= 1
#
# RestrSimult_Cindy__16,_20_: assign_('Cindy',_np.int64(16))
#  + assign_('Cindy',_np.int64(20)) <= 1
#
# RestrSimult_Cindy__17,_21,_24,_26,_28,_31_: assign_('Cindy',_np.int64(17))
#  + assign_('Cindy',_np.int64(21)) + assign_('Cindy',_np.int64(24))
#  + assign_('Cindy',_np.int64(26)) + assign_('Cindy',_np.int64(28))
#  + assign_('Cindy',_np.int64(31)) <= 1
#
# RestrSimult_Cindy__18,_22,_25,_27,_29,_32_: assign_('Cindy',_np.int64(18))
#  + assign_('Cindy',_np.int64(22)) + assign_('Cindy',_np.int64(25))
#  + assign_('Cindy',_np.int64(27)) + assign_('Cindy',_np.int64(29))
#  + assign_('Cindy',_np.int64(32)) <= 1
#
# RestrSimult_Cindy__19,_23,_30,_33_: assign_('Cindy',_np.int64(19))
#  + assign_('Cindy',_np.int64(23)) + assign_('Cindy',_np.int64(30))
#  + assign_('Cindy',_np.int64(33)) <= 1
#
# RestrSimult_Cindy__34,_38_: assign_('Cindy',_np.int64(34))
#  + assign_('Cindy',_np.int64(38)) <= 1
#
# RestrSimult_Cindy__35,_39,_42,_44_: assign_('Cindy',_np.int64(35))
#  + assign_('Cindy',_np.int64(39)) + assign_('Cindy',_np.int64(42))
#  + assign_('Cindy',_np.int64(44)) <= 1
#
# RestrSimult_Cindy__36,_40,_43,_45_: assign_('Cindy',_np.int64(36))
#  + assign_('Cindy',_np.int64(40)) + assign_('Cindy',_np.int64(43))
#  + assign_('Cindy',_np.int64(45)) <= 1
#
# RestrSimult_Cindy__37,_41_: assign_('Cindy',_np.int64(37))
#  + assign_('Cindy',_np.int64(41)) <= 1
#
# RestrSimult_Cindy__46,_50_: assign_('Cindy',_np.int64(46))
#  + assign_('Cindy',_np.int64(50)) <= 1
#
# RestrSimult_Cindy__47,_51,_54,_56_: assign_('Cindy',_np.int64(47))
#  + assign_('Cindy',_np.int64(51)) + assign_('Cindy',_np.int64(54))
#  + assign_('Cindy',_np.int64(56)) <= 1
#
# RestrSimult_Cindy__48,_52,_55,_57_: assign_('Cindy',_np.int64(48))
#  + assign_('Cindy',_np.int64(52)) + assign_('Cindy',_np.int64(55))
#  + assign_('Cindy',_np.int64(57)) <= 1
#
# RestrSimult_Cindy__49,_53_: assign_('Cindy',_np.int64(49))
#  + assign_('Cindy',_np.int64(53)) <= 1
#
# RestrSimult_Cindy__58,_62_: assign_('Cindy',_np.int64(58))
#  + assign_('Cindy',_np.int64(62)) <= 1
#
# RestrSimult_Cindy__59,_63,_66,_68_: assign_('Cindy',_np.int64(59))
#  + assign_('Cindy',_np.int64(63)) + assign_('Cindy',_np.int64(66))
#  + assign_('Cindy',_np.int64(68)) <= 1
#
# RestrSimult_Cindy__60,_64,_67,_69_: assign_('Cindy',_np.int64(60))
#  + assign_('Cindy',_np.int64(64)) + assign_('Cindy',_np.int64(67))
#  + assign_('Cindy',_np.int64(69)) <= 1
#
# RestrSimult_Cindy__61,_65_: assign_('Cindy',_np.int64(61))
#  + assign_('Cindy',_np.int64(65)) <= 1
#
# RestrSimult_Cindy__70,_73_: assign_('Cindy',_np.int64(70))
#  + assign_('Cindy',_np.int64(73)) <= 1
#
# RestrSimult_Cindy__71,_74_: assign_('Cindy',_np.int64(71))
#  + assign_('Cindy',_np.int64(74)) <= 1
#
# RestrSimult_Cindy__72,_75_: assign_('Cindy',_np.int64(72))
#  + assign_('Cindy',_np.int64(75)) <= 1
#
# RestrSimult_Cindy__76,_79_: assign_('Cindy',_np.int64(76))
#  + assign_('Cindy',_np.int64(79)) <= 1
#
# RestrSimult_Cindy__77,_80,_83_: assign_('Cindy',_np.int64(77))
#  + assign_('Cindy',_np.int64(80)) + assign_('Cindy',_np.int64(83)) <= 1
#
# RestrSimult_Cindy__78,_81_: assign_('Cindy',_np.int64(78))
#  + assign_('Cindy',_np.int64(81)) <= 1
#
# RestrSimult_David__0,_4_: assign_('David',_np.int64(0))
#  + assign_('David',_np.int64(4)) <= 1
#
# RestrSimult_David__1,_5,_8,_10,_12,_14_: assign_('David',_np.int64(1))
#  + assign_('David',_np.int64(10)) + assign_('David',_np.int64(12))
#  + assign_('David',_np.int64(14)) + assign_('David',_np.int64(5))
#  + assign_('David',_np.int64(8)) <= 1
#
# RestrSimult_David__2,_6,_9,_11,_13,_15_: assign_('David',_np.int64(11))
#  + assign_('David',_np.int64(13)) + assign_('David',_np.int64(15))
#  + assign_('David',_np.int64(2)) + assign_('David',_np.int64(6))
#  + assign_('David',_np.int64(9)) <= 1
#
# RestrSimult_David__3,_7_: assign_('David',_np.int64(3))
#  + assign_('David',_np.int64(7)) <= 1
#
# RestrSimult_David__16,_20_: assign_('David',_np.int64(16))
#  + assign_('David',_np.int64(20)) <= 1
#
# RestrSimult_David__17,_21,_24,_26,_28,_31_: assign_('David',_np.int64(17))
#  + assign_('David',_np.int64(21)) + assign_('David',_np.int64(24))
#  + assign_('David',_np.int64(26)) + assign_('David',_np.int64(28))
#  + assign_('David',_np.int64(31)) <= 1
#
# RestrSimult_David__18,_22,_25,_27,_29,_32_: assign_('David',_np.int64(18))
#  + assign_('David',_np.int64(22)) + assign_('David',_np.int64(25))
#  + assign_('David',_np.int64(27)) + assign_('David',_np.int64(29))
#  + assign_('David',_np.int64(32)) <= 1
#
# RestrSimult_David__19,_23,_30,_33_: assign_('David',_np.int64(19))
#  + assign_('David',_np.int64(23)) + assign_('David',_np.int64(30))
#  + assign_('David',_np.int64(33)) <= 1
#
# RestrSimult_David__34,_38_: assign_('David',_np.int64(34))
#  + assign_('David',_np.int64(38)) <= 1
#
# RestrSimult_David__35,_39,_42,_44_: assign_('David',_np.int64(35))
#  + assign_('David',_np.int64(39)) + assign_('David',_np.int64(42))
#  + assign_('David',_np.int64(44)) <= 1
#
# RestrSimult_David__36,_40,_43,_45_: assign_('David',_np.int64(36))
#  + assign_('David',_np.int64(40)) + assign_('David',_np.int64(43))
#  + assign_('David',_np.int64(45)) <= 1
#
# RestrSimult_David__37,_41_: assign_('David',_np.int64(37))
#  + assign_('David',_np.int64(41)) <= 1
#
# RestrSimult_David__46,_50_: assign_('David',_np.int64(46))
#  + assign_('David',_np.int64(50)) <= 1
#
# RestrSimult_David__47,_51,_54,_56_: assign_('David',_np.int64(47))
#  + assign_('David',_np.int64(51)) + assign_('David',_np.int64(54))
#  + assign_('David',_np.int64(56)) <= 1
#
# RestrSimult_David__48,_52,_55,_57_: assign_('David',_np.int64(48))
#  + assign_('David',_np.int64(52)) + assign_('David',_np.int64(55))
#  + assign_('David',_np.int64(57)) <= 1
#
# RestrSimult_David__49,_53_: assign_('David',_np.int64(49))
#  + assign_('David',_np.int64(53)) <= 1
#
# RestrSimult_David__58,_62_: assign_('David',_np.int64(58))
#  + assign_('David',_np.int64(62)) <= 1
#
# RestrSimult_David__59,_63,_66,_68_: assign_('David',_np.int64(59))
#  + assign_('David',_np.int64(63)) + assign_('David',_np.int64(66))
#  + assign_('David',_np.int64(68)) <= 1
#
# RestrSimult_David__60,_64,_67,_69_: assign_('David',_np.int64(60))
#  + assign_('David',_np.int64(64)) + assign_('David',_np.int64(67))
#  + assign_('David',_np.int64(69)) <= 1
#
# RestrSimult_David__61,_65_: assign_('David',_np.int64(61))
#  + assign_('David',_np.int64(65)) <= 1
#
# RestrSimult_David__70,_73_: assign_('David',_np.int64(70))
#  + assign_('David',_np.int64(73)) <= 1
#
# RestrSimult_David__71,_74_: assign_('David',_np.int64(71))
#  + assign_('David',_np.int64(74)) <= 1
#
# RestrSimult_David__72,_75_: assign_('David',_np.int64(72))
#  + assign_('David',_np.int64(75)) <= 1
#
# RestrSimult_David__76,_79_: assign_('David',_np.int64(76))
#  + assign_('David',_np.int64(79)) <= 1
#
# RestrSimult_David__77,_80,_83_: assign_('David',_np.int64(77))
#  + assign_('David',_np.int64(80)) + assign_('David',_np.int64(83)) <= 1
#
# RestrSimult_David__78,_81_: assign_('David',_np.int64(78))
#  + assign_('David',_np.int64(81)) <= 1
#
# RestrSimult_Debbie__0,_4_: assign_('Debbie',_np.int64(0))
#  + assign_('Debbie',_np.int64(4)) <= 1
#
# RestrSimult_Debbie__1,_5,_8,_10,_12,_14_: assign_('Debbie',_np.int64(1))
#  + assign_('Debbie',_np.int64(10)) + assign_('Debbie',_np.int64(12))
#  + assign_('Debbie',_np.int64(14)) + assign_('Debbie',_np.int64(5))
#  + assign_('Debbie',_np.int64(8)) <= 1
#
# RestrSimult_Debbie__2,_6,_9,_11,_13,_15_: assign_('Debbie',_np.int64(11))
#  + assign_('Debbie',_np.int64(13)) + assign_('Debbie',_np.int64(15))
#  + assign_('Debbie',_np.int64(2)) + assign_('Debbie',_np.int64(6))
#  + assign_('Debbie',_np.int64(9)) <= 1
#
# RestrSimult_Debbie__3,_7_: assign_('Debbie',_np.int64(3))
#  + assign_('Debbie',_np.int64(7)) <= 1
#
# RestrSimult_Debbie__16,_20_: assign_('Debbie',_np.int64(16))
#  + assign_('Debbie',_np.int64(20)) <= 1
#
# RestrSimult_Debbie__17,_21,_24,_26,_28,_31_: assign_('Debbie',_np.int64(17))
#  + assign_('Debbie',_np.int64(21)) + assign_('Debbie',_np.int64(24))
#  + assign_('Debbie',_np.int64(26)) + assign_('Debbie',_np.int64(28))
#  + assign_('Debbie',_np.int64(31)) <= 1
#
# RestrSimult_Debbie__18,_22,_25,_27,_29,_32_: assign_('Debbie',_np.int64(18))
#  + assign_('Debbie',_np.int64(22)) + assign_('Debbie',_np.int64(25))
#  + assign_('Debbie',_np.int64(27)) + assign_('Debbie',_np.int64(29))
#  + assign_('Debbie',_np.int64(32)) <= 1
#
# RestrSimult_Debbie__19,_23,_30,_33_: assign_('Debbie',_np.int64(19))
#  + assign_('Debbie',_np.int64(23)) + assign_('Debbie',_np.int64(30))
#  + assign_('Debbie',_np.int64(33)) <= 1
#
# RestrSimult_Debbie__34,_38_: assign_('Debbie',_np.int64(34))
#  + assign_('Debbie',_np.int64(38)) <= 1
#
# RestrSimult_Debbie__35,_39,_42,_44_: assign_('Debbie',_np.int64(35))
#  + assign_('Debbie',_np.int64(39)) + assign_('Debbie',_np.int64(42))
#  + assign_('Debbie',_np.int64(44)) <= 1
#
# RestrSimult_Debbie__36,_40,_43,_45_: assign_('Debbie',_np.int64(36))
#  + assign_('Debbie',_np.int64(40)) + assign_('Debbie',_np.int64(43))
#  + assign_('Debbie',_np.int64(45)) <= 1
#
# RestrSimult_Debbie__37,_41_: assign_('Debbie',_np.int64(37))
#  + assign_('Debbie',_np.int64(41)) <= 1
#
# RestrSimult_Debbie__46,_50_: assign_('Debbie',_np.int64(46))
#  + assign_('Debbie',_np.int64(50)) <= 1
#
# RestrSimult_Debbie__47,_51,_54,_56_: assign_('Debbie',_np.int64(47))
#  + assign_('Debbie',_np.int64(51)) + assign_('Debbie',_np.int64(54))
#  + assign_('Debbie',_np.int64(56)) <= 1
#
# RestrSimult_Debbie__48,_52,_55,_57_: assign_('Debbie',_np.int64(48))
#  + assign_('Debbie',_np.int64(52)) + assign_('Debbie',_np.int64(55))
#  + assign_('Debbie',_np.int64(57)) <= 1
#
# RestrSimult_Debbie__49,_53_: assign_('Debbie',_np.int64(49))
#  + assign_('Debbie',_np.int64(53)) <= 1
#
# RestrSimult_Debbie__58,_62_: assign_('Debbie',_np.int64(58))
#  + assign_('Debbie',_np.int64(62)) <= 1
#
# RestrSimult_Debbie__59,_63,_66,_68_: assign_('Debbie',_np.int64(59))
#  + assign_('Debbie',_np.int64(63)) + assign_('Debbie',_np.int64(66))
#  + assign_('Debbie',_np.int64(68)) <= 1
#
# RestrSimult_Debbie__60,_64,_67,_69_: assign_('Debbie',_np.int64(60))
#  + assign_('Debbie',_np.int64(64)) + assign_('Debbie',_np.int64(67))
#  + assign_('Debbie',_np.int64(69)) <= 1
#
# RestrSimult_Debbie__61,_65_: assign_('Debbie',_np.int64(61))
#  + assign_('Debbie',_np.int64(65)) <= 1
#
# RestrSimult_Debbie__70,_73_: assign_('Debbie',_np.int64(70))
#  + assign_('Debbie',_np.int64(73)) <= 1
#
# RestrSimult_Debbie__71,_74_: assign_('Debbie',_np.int64(71))
#  + assign_('Debbie',_np.int64(74)) <= 1
#
# RestrSimult_Debbie__72,_75_: assign_('Debbie',_np.int64(72))
#  + assign_('Debbie',_np.int64(75)) <= 1
#
# RestrSimult_Debbie__76,_79_: assign_('Debbie',_np.int64(76))
#  + assign_('Debbie',_np.int64(79)) <= 1
#
# RestrSimult_Debbie__77,_80,_83_: assign_('Debbie',_np.int64(77))
#  + assign_('Debbie',_np.int64(80)) + assign_('Debbie',_np.int64(83)) <= 1
#
# RestrSimult_Debbie__78,_81_: assign_('Debbie',_np.int64(78))
#  + assign_('Debbie',_np.int64(81)) <= 1
#
# RestrSimult_Dee__0,_4_: assign_('Dee',_np.int64(0))
#  + assign_('Dee',_np.int64(4)) <= 1
#
# RestrSimult_Dee__1,_5,_8,_10,_12,_14_: assign_('Dee',_np.int64(1))
#  + assign_('Dee',_np.int64(10)) + assign_('Dee',_np.int64(12))
#  + assign_('Dee',_np.int64(14)) + assign_('Dee',_np.int64(5))
#  + assign_('Dee',_np.int64(8)) <= 1
#
# RestrSimult_Dee__2,_6,_9,_11,_13,_15_: assign_('Dee',_np.int64(11))
#  + assign_('Dee',_np.int64(13)) + assign_('Dee',_np.int64(15))
#  + assign_('Dee',_np.int64(2)) + assign_('Dee',_np.int64(6))
#  + assign_('Dee',_np.int64(9)) <= 1
#
# RestrSimult_Dee__3,_7_: assign_('Dee',_np.int64(3))
#  + assign_('Dee',_np.int64(7)) <= 1
#
# RestrSimult_Dee__16,_20_: assign_('Dee',_np.int64(16))
#  + assign_('Dee',_np.int64(20)) <= 1
#
# RestrSimult_Dee__17,_21,_24,_26,_28,_31_: assign_('Dee',_np.int64(17))
#  + assign_('Dee',_np.int64(21)) + assign_('Dee',_np.int64(24))
#  + assign_('Dee',_np.int64(26)) + assign_('Dee',_np.int64(28))
#  + assign_('Dee',_np.int64(31)) <= 1
#
# RestrSimult_Dee__18,_22,_25,_27,_29,_32_: assign_('Dee',_np.int64(18))
#  + assign_('Dee',_np.int64(22)) + assign_('Dee',_np.int64(25))
#  + assign_('Dee',_np.int64(27)) + assign_('Dee',_np.int64(29))
#  + assign_('Dee',_np.int64(32)) <= 1
#
# RestrSimult_Dee__19,_23,_30,_33_: assign_('Dee',_np.int64(19))
#  + assign_('Dee',_np.int64(23)) + assign_('Dee',_np.int64(30))
#  + assign_('Dee',_np.int64(33)) <= 1
#
# RestrSimult_Dee__34,_38_: assign_('Dee',_np.int64(34))
#  + assign_('Dee',_np.int64(38)) <= 1
#
# RestrSimult_Dee__35,_39,_42,_44_: assign_('Dee',_np.int64(35))
#  + assign_('Dee',_np.int64(39)) + assign_('Dee',_np.int64(42))
#  + assign_('Dee',_np.int64(44)) <= 1
#
# RestrSimult_Dee__36,_40,_43,_45_: assign_('Dee',_np.int64(36))
#  + assign_('Dee',_np.int64(40)) + assign_('Dee',_np.int64(43))
#  + assign_('Dee',_np.int64(45)) <= 1
#
# RestrSimult_Dee__37,_41_: assign_('Dee',_np.int64(37))
#  + assign_('Dee',_np.int64(41)) <= 1
#
# RestrSimult_Dee__46,_50_: assign_('Dee',_np.int64(46))
#  + assign_('Dee',_np.int64(50)) <= 1
#
# RestrSimult_Dee__47,_51,_54,_56_: assign_('Dee',_np.int64(47))
#  + assign_('Dee',_np.int64(51)) + assign_('Dee',_np.int64(54))
#  + assign_('Dee',_np.int64(56)) <= 1
#
# RestrSimult_Dee__48,_52,_55,_57_: assign_('Dee',_np.int64(48))
#  + assign_('Dee',_np.int64(52)) + assign_('Dee',_np.int64(55))
#  + assign_('Dee',_np.int64(57)) <= 1
#
# RestrSimult_Dee__49,_53_: assign_('Dee',_np.int64(49))
#  + assign_('Dee',_np.int64(53)) <= 1
#
# RestrSimult_Dee__58,_62_: assign_('Dee',_np.int64(58))
#  + assign_('Dee',_np.int64(62)) <= 1
#
# RestrSimult_Dee__59,_63,_66,_68_: assign_('Dee',_np.int64(59))
#  + assign_('Dee',_np.int64(63)) + assign_('Dee',_np.int64(66))
#  + assign_('Dee',_np.int64(68)) <= 1
#
# RestrSimult_Dee__60,_64,_67,_69_: assign_('Dee',_np.int64(60))
#  + assign_('Dee',_np.int64(64)) + assign_('Dee',_np.int64(67))
#  + assign_('Dee',_np.int64(69)) <= 1
#
# RestrSimult_Dee__61,_65_: assign_('Dee',_np.int64(61))
#  + assign_('Dee',_np.int64(65)) <= 1
#
# RestrSimult_Dee__70,_73_: assign_('Dee',_np.int64(70))
#  + assign_('Dee',_np.int64(73)) <= 1
#
# RestrSimult_Dee__71,_74_: assign_('Dee',_np.int64(71))
#  + assign_('Dee',_np.int64(74)) <= 1
#
# RestrSimult_Dee__72,_75_: assign_('Dee',_np.int64(72))
#  + assign_('Dee',_np.int64(75)) <= 1
#
# RestrSimult_Dee__76,_79_: assign_('Dee',_np.int64(76))
#  + assign_('Dee',_np.int64(79)) <= 1
#
# RestrSimult_Dee__77,_80,_83_: assign_('Dee',_np.int64(77))
#  + assign_('Dee',_np.int64(80)) + assign_('Dee',_np.int64(83)) <= 1
#
# RestrSimult_Dee__78,_81_: assign_('Dee',_np.int64(78))
#  + assign_('Dee',_np.int64(81)) <= 1
#
# RestrSimult_Gloria__0,_4_: assign_('Gloria',_np.int64(0))
#  + assign_('Gloria',_np.int64(4)) <= 1
#
# RestrSimult_Gloria__1,_5,_8,_10,_12,_14_: assign_('Gloria',_np.int64(1))
#  + assign_('Gloria',_np.int64(10)) + assign_('Gloria',_np.int64(12))
#  + assign_('Gloria',_np.int64(14)) + assign_('Gloria',_np.int64(5))
#  + assign_('Gloria',_np.int64(8)) <= 1
#
# RestrSimult_Gloria__2,_6,_9,_11,_13,_15_: assign_('Gloria',_np.int64(11))
#  + assign_('Gloria',_np.int64(13)) + assign_('Gloria',_np.int64(15))
#  + assign_('Gloria',_np.int64(2)) + assign_('Gloria',_np.int64(6))
#  + assign_('Gloria',_np.int64(9)) <= 1
#
# RestrSimult_Gloria__3,_7_: assign_('Gloria',_np.int64(3))
#  + assign_('Gloria',_np.int64(7)) <= 1
#
# RestrSimult_Gloria__16,_20_: assign_('Gloria',_np.int64(16))
#  + assign_('Gloria',_np.int64(20)) <= 1
#
# RestrSimult_Gloria__17,_21,_24,_26,_28,_31_: assign_('Gloria',_np.int64(17))
#  + assign_('Gloria',_np.int64(21)) + assign_('Gloria',_np.int64(24))
#  + assign_('Gloria',_np.int64(26)) + assign_('Gloria',_np.int64(28))
#  + assign_('Gloria',_np.int64(31)) <= 1
#
# RestrSimult_Gloria__18,_22,_25,_27,_29,_32_: assign_('Gloria',_np.int64(18))
#  + assign_('Gloria',_np.int64(22)) + assign_('Gloria',_np.int64(25))
#  + assign_('Gloria',_np.int64(27)) + assign_('Gloria',_np.int64(29))
#  + assign_('Gloria',_np.int64(32)) <= 1
#
# RestrSimult_Gloria__19,_23,_30,_33_: assign_('Gloria',_np.int64(19))
#  + assign_('Gloria',_np.int64(23)) + assign_('Gloria',_np.int64(30))
#  + assign_('Gloria',_np.int64(33)) <= 1
#
# RestrSimult_Gloria__34,_38_: assign_('Gloria',_np.int64(34))
#  + assign_('Gloria',_np.int64(38)) <= 1
#
# RestrSimult_Gloria__35,_39,_42,_44_: assign_('Gloria',_np.int64(35))
#  + assign_('Gloria',_np.int64(39)) + assign_('Gloria',_np.int64(42))
#  + assign_('Gloria',_np.int64(44)) <= 1
#
# RestrSimult_Gloria__36,_40,_43,_45_: assign_('Gloria',_np.int64(36))
#  + assign_('Gloria',_np.int64(40)) + assign_('Gloria',_np.int64(43))
#  + assign_('Gloria',_np.int64(45)) <= 1
#
# RestrSimult_Gloria__37,_41_: assign_('Gloria',_np.int64(37))
#  + assign_('Gloria',_np.int64(41)) <= 1
#
# RestrSimult_Gloria__46,_50_: assign_('Gloria',_np.int64(46))
#  + assign_('Gloria',_np.int64(50)) <= 1
#
# RestrSimult_Gloria__47,_51,_54,_56_: assign_('Gloria',_np.int64(47))
#  + assign_('Gloria',_np.int64(51)) + assign_('Gloria',_np.int64(54))
#  + assign_('Gloria',_np.int64(56)) <= 1
#
# RestrSimult_Gloria__48,_52,_55,_57_: assign_('Gloria',_np.int64(48))
#  + assign_('Gloria',_np.int64(52)) + assign_('Gloria',_np.int64(55))
#  + assign_('Gloria',_np.int64(57)) <= 1
#
# RestrSimult_Gloria__49,_53_: assign_('Gloria',_np.int64(49))
#  + assign_('Gloria',_np.int64(53)) <= 1
#
# RestrSimult_Gloria__58,_62_: assign_('Gloria',_np.int64(58))
#  + assign_('Gloria',_np.int64(62)) <= 1
#
# RestrSimult_Gloria__59,_63,_66,_68_: assign_('Gloria',_np.int64(59))
#  + assign_('Gloria',_np.int64(63)) + assign_('Gloria',_np.int64(66))
#  + assign_('Gloria',_np.int64(68)) <= 1
#
# RestrSimult_Gloria__60,_64,_67,_69_: assign_('Gloria',_np.int64(60))
#  + assign_('Gloria',_np.int64(64)) + assign_('Gloria',_np.int64(67))
#  + assign_('Gloria',_np.int64(69)) <= 1
#
# RestrSimult_Gloria__61,_65_: assign_('Gloria',_np.int64(61))
#  + assign_('Gloria',_np.int64(65)) <= 1
#
# RestrSimult_Gloria__70,_73_: assign_('Gloria',_np.int64(70))
#  + assign_('Gloria',_np.int64(73)) <= 1
#
# RestrSimult_Gloria__71,_74_: assign_('Gloria',_np.int64(71))
#  + assign_('Gloria',_np.int64(74)) <= 1
#
# RestrSimult_Gloria__72,_75_: assign_('Gloria',_np.int64(72))
#  + assign_('Gloria',_np.int64(75)) <= 1
#
# RestrSimult_Gloria__76,_79_: assign_('Gloria',_np.int64(76))
#  + assign_('Gloria',_np.int64(79)) <= 1
#
# RestrSimult_Gloria__77,_80,_83_: assign_('Gloria',_np.int64(77))
#  + assign_('Gloria',_np.int64(80)) + assign_('Gloria',_np.int64(83)) <= 1
#
# RestrSimult_Gloria__78,_81_: assign_('Gloria',_np.int64(78))
#  + assign_('Gloria',_np.int64(81)) <= 1
#
# RestrSimult_Isabelle__0,_4_: assign_('Isabelle',_np.int64(0))
#  + assign_('Isabelle',_np.int64(4)) <= 1
#
# RestrSimult_Isabelle__1,_5,_8,_10,_12,_14_: assign_('Isabelle',_np.int64(1))
#  + assign_('Isabelle',_np.int64(10)) + assign_('Isabelle',_np.int64(12))
#  + assign_('Isabelle',_np.int64(14)) + assign_('Isabelle',_np.int64(5))
#  + assign_('Isabelle',_np.int64(8)) <= 1
#
# RestrSimult_Isabelle__2,_6,_9,_11,_13,_15_: assign_('Isabelle',_np.int64(11))
#  + assign_('Isabelle',_np.int64(13)) + assign_('Isabelle',_np.int64(15))
#  + assign_('Isabelle',_np.int64(2)) + assign_('Isabelle',_np.int64(6))
#  + assign_('Isabelle',_np.int64(9)) <= 1
#
# RestrSimult_Isabelle__3,_7_: assign_('Isabelle',_np.int64(3))
#  + assign_('Isabelle',_np.int64(7)) <= 1
#
# RestrSimult_Isabelle__16,_20_: assign_('Isabelle',_np.int64(16))
#  + assign_('Isabelle',_np.int64(20)) <= 1
#
# RestrSimult_Isabelle__17,_21,_24,_26,_28,_31_:
#  assign_('Isabelle',_np.int64(17)) + assign_('Isabelle',_np.int64(21))
#  + assign_('Isabelle',_np.int64(24)) + assign_('Isabelle',_np.int64(26))
#  + assign_('Isabelle',_np.int64(28)) + assign_('Isabelle',_np.int64(31)) <= 1
#
# RestrSimult_Isabelle__18,_22,_25,_27,_29,_32_:
#  assign_('Isabelle',_np.int64(18)) + assign_('Isabelle',_np.int64(22))
#  + assign_('Isabelle',_np.int64(25)) + assign_('Isabelle',_np.int64(27))
#  + assign_('Isabelle',_np.int64(29)) + assign_('Isabelle',_np.int64(32)) <= 1
#
# RestrSimult_Isabelle__19,_23,_30,_33_: assign_('Isabelle',_np.int64(19))
#  + assign_('Isabelle',_np.int64(23)) + assign_('Isabelle',_np.int64(30))
#  + assign_('Isabelle',_np.int64(33)) <= 1
#
# RestrSimult_Isabelle__34,_38_: assign_('Isabelle',_np.int64(34))
#  + assign_('Isabelle',_np.int64(38)) <= 1
#
# RestrSimult_Isabelle__35,_39,_42,_44_: assign_('Isabelle',_np.int64(35))
#  + assign_('Isabelle',_np.int64(39)) + assign_('Isabelle',_np.int64(42))
#  + assign_('Isabelle',_np.int64(44)) <= 1
#
# RestrSimult_Isabelle__36,_40,_43,_45_: assign_('Isabelle',_np.int64(36))
#  + assign_('Isabelle',_np.int64(40)) + assign_('Isabelle',_np.int64(43))
#  + assign_('Isabelle',_np.int64(45)) <= 1
#
# RestrSimult_Isabelle__37,_41_: assign_('Isabelle',_np.int64(37))
#  + assign_('Isabelle',_np.int64(41)) <= 1
#
# RestrSimult_Isabelle__46,_50_: assign_('Isabelle',_np.int64(46))
#  + assign_('Isabelle',_np.int64(50)) <= 1
#
# RestrSimult_Isabelle__47,_51,_54,_56_: assign_('Isabelle',_np.int64(47))
#  + assign_('Isabelle',_np.int64(51)) + assign_('Isabelle',_np.int64(54))
#  + assign_('Isabelle',_np.int64(56)) <= 1
#
# RestrSimult_Isabelle__48,_52,_55,_57_: assign_('Isabelle',_np.int64(48))
#  + assign_('Isabelle',_np.int64(52)) + assign_('Isabelle',_np.int64(55))
#  + assign_('Isabelle',_np.int64(57)) <= 1
#
# ...
# 0 <= assign_('Willow',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(42)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(43)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(44)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(45)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(46)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(47)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(48)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(49)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(50)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(51)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(52)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(53)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(54)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(55)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(56)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(57)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(58)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(59)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(60)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(61)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(62)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(63)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(64)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(65)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(66)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(67)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(68)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(69)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(70)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(71)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(72)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(73)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(74)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(75)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(76)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(77)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(78)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(79)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(80)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(81)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(82)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(83)) <= 1 Integer
# 0 <= assign_('Willow',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(42)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(43)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(44)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(45)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(46)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(47)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(48)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(49)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(50)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(51)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(52)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(53)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(54)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(55)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(56)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(57)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(58)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(59)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(60)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(61)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(62)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(63)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(64)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(65)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(66)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(67)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(68)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(69)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(70)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(71)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(72)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(73)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(74)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(75)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(76)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(77)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(78)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(79)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(80)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(81)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(82)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(83)) <= 1 Integer
# 0 <= assign_('Yvonne',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(42)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(43)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(44)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(45)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(46)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(47)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(48)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(49)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(50)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(51)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(52)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(53)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(54)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(55)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(56)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(57)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(58)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(59)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(60)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(61)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(62)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(63)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(64)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(65)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(66)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(67)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(68)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(69)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(70)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(71)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(72)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(73)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(74)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(75)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(76)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(77)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(78)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(79)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(80)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(81)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(82)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(83)) <= 1 Integer
# 0 <= assign_('Zara',_np.int64(9)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(0)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(1)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(10)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(11)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(12)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(13)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(14)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(15)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(16)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(17)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(18)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(19)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(2)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(20)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(21)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(22)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(23)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(24)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(25)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(26)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(27)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(28)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(29)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(3)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(30)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(31)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(32)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(33)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(34)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(35)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(36)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(37)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(38)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(39)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(4)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(40)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(41)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(42)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(43)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(44)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(45)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(46)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(47)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(48)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(49)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(5)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(50)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(51)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(52)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(53)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(54)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(55)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(56)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(57)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(58)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(59)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(6)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(60)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(61)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(62)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(63)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(64)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(65)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(66)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(67)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(68)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(69)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(7)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(70)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(71)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(72)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(73)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(74)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(75)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(76)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(77)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(78)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(79)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(8)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(80)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(81)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(82)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(83)) <= 1 Integer
# 0 <= assign_('Zoe',_np.int64(9)) <= 1 Integer

# %% [markdown]
# Enviar modelagem ao solucionador:

# %%
import time;

resultado = []

inicio = time.time()
prob.solve()
fim = time.time()
tempo_execucao = fim - inicio
resultado_objetivo = prob.objective.value()

resultado.append({
"Solver": "PULP_CBC_CMD",
"Tempo de Execução (s)": tempo_execucao,
"Valor da Função Objetivo": resultado_objetivo,
"Status": prob.status
})
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/magnofonseca/.local/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/083db551f0e0482fa7b2c6de603f6880-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /tmp/083db551f0e0482fa7b2c6de603f6880-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 16228 COLUMNS
# At line 82984 RHS
# At line 99208 BOUNDS
# At line 104669 ENDATA
# Problem MODEL has 16223 rows, 5460 columns and 50375 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 61536 - 0.35 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 11085 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 10712 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8884 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 6739 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4323 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2812 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1603 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1213 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 746 strengthened rows, 0 substitutions
# Cgl0004I processed model has 4759 rows, 5460 columns (5460 integer (5460 of which binary)) and 39914 elements
# Cutoff increment increased from 1e-05 to 1.9999
# Cbc0038I Initial state - 75 integers unsatisfied sum - 27.3
# Cbc0038I Pass   1: (4.54 seconds) suminf.   12.76667 (44) obj. 62226 iterations 475
# Cbc0038I Pass   2: (4.56 seconds) suminf.   11.50000 (40) obj. 62420 iterations 90
# Cbc0038I Pass   3: (4.59 seconds) suminf.    9.16667 (35) obj. 62432 iterations 91
# Cbc0038I Pass   4: (4.61 seconds) suminf.    8.90000 (36) obj. 62394 iterations 44
# Cbc0038I Pass   5: (4.67 seconds) suminf.   10.10000 (35) obj. 62290 iterations 221
# Cbc0038I Pass   6: (4.71 seconds) suminf.    9.90000 (34) obj. 62290 iterations 108
# Cbc0038I Pass   7: (4.73 seconds) suminf.    9.90000 (34) obj. 62290 iterations 49
# Cbc0038I Pass   8: (4.76 seconds) suminf.    9.40000 (34) obj. 62340 iterations 92
# Cbc0038I Pass   9: (4.80 seconds) suminf.    9.40000 (34) obj. 62340 iterations 79
# Cbc0038I Pass  10: (4.82 seconds) suminf.    9.40000 (34) obj. 62340 iterations 1
# Cbc0038I Pass  11: (4.85 seconds) suminf.   11.90000 (39) obj. 62258 iterations 159
# Cbc0038I Pass  12: (4.88 seconds) suminf.   11.30000 (38) obj. 62288 iterations 107
# Cbc0038I Pass  13: (4.91 seconds) suminf.   11.05000 (38) obj. 62336 iterations 43
# Cbc0038I Pass  14: (4.93 seconds) suminf.   11.05000 (38) obj. 62336 iterations 17
# Cbc0038I Pass  15: (4.96 seconds) suminf.   11.20000 (38) obj. 62320 iterations 139
# Cbc0038I Pass  16: (5.01 seconds) suminf.   10.30000 (36) obj. 62408 iterations 154
# Cbc0038I Pass  17: (5.03 seconds) suminf.    9.90000 (35) obj. 62400 iterations 28
# Cbc0038I Pass  18: (5.06 seconds) suminf.    9.90000 (35) obj. 62400 iterations 20
# Cbc0038I Pass  19: (5.10 seconds) suminf.    9.50000 (35) obj. 62310 iterations 153
# Cbc0038I Pass  20: (5.12 seconds) suminf.    9.50000 (35) obj. 62310 iterations 92
# Cbc0038I Pass  21: (5.16 seconds) suminf.    9.55000 (34) obj. 62490 iterations 153
# Cbc0038I Pass  22: (5.19 seconds) suminf.    9.00000 (33) obj. 62364 iterations 74
# Cbc0038I Pass  23: (5.23 seconds) suminf.    9.70000 (35) obj. 62276 iterations 152
# Cbc0038I Pass  24: (5.26 seconds) suminf.    9.70000 (35) obj. 62314 iterations 48
# Cbc0038I Pass  25: (5.29 seconds) suminf.    9.20000 (34) obj. 62236 iterations 95
# Cbc0038I Pass  26: (5.31 seconds) suminf.    9.20000 (34) obj. 62276 iterations 42
# Cbc0038I Pass  27: (5.36 seconds) suminf.   10.65000 (36) obj. 62308 iterations 190
# Cbc0038I Pass  28: (5.39 seconds) suminf.   10.00000 (35) obj. 62282 iterations 108
# Cbc0038I Pass  29: (5.44 seconds) suminf.   10.20000 (35) obj. 62252 iterations 157
# Cbc0038I Pass  30: (5.46 seconds) suminf.    9.70000 (35) obj. 62276 iterations 97
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 5297 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (5.54 seconds)
# Cbc0038I Full problem 4760 rows 5460 columns, reduced to 4027 rows 5460 columns - too large
# Cbc0038I After 5.94 seconds - Feasibility pump exiting - took 1.50 seconds
# Cbc0031I 21 added rows had average density of 432.38095
# Cbc0013I At root node, 21 cuts changed objective from 61536 to 61536 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.337 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 256 row cuts average 943.2 elements, 0 column cuts (0 active)  in 0.859 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.061 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 263.0 elements, 0 column cuts (0 active)  in 0.082 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.013 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 126 row cuts average 163.7 elements, 0 column cuts (0 active)  in 0.258 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 102 row cuts average 83.6 elements, 0 column cuts (0 active)  in 1.176 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 61536 (11.34 seconds)
# Cbc0010I After 100 nodes, 63 on tree, 1e+50 best solution, best possible 61536 (24.32 seconds)
# Cbc0010I After 200 nodes, 119 on tree, 1e+50 best solution, best possible 61536 (26.35 seconds)
# Cbc0010I After 300 nodes, 169 on tree, 1e+50 best solution, best possible 61536 (28.23 seconds)
# Cbc0010I After 400 nodes, 217 on tree, 1e+50 best solution, best possible 61536 (30.27 seconds)
# Cbc0010I After 500 nodes, 269 on tree, 1e+50 best solution, best possible 61536 (32.38 seconds)
# Cbc0010I After 600 nodes, 321 on tree, 1e+50 best solution, best possible 61536 (34.71 seconds)
# Cbc0010I After 700 nodes, 375 on tree, 1e+50 best solution, best possible 61536 (36.75 seconds)
# Cbc0010I After 800 nodes, 435 on tree, 1e+50 best solution, best possible 61536 (38.90 seconds)
# Cbc0004I Integer solution of 61536 found after 23221 iterations and 814 nodes (39.24 seconds)
# Cbc0001I Search completed - best objective 61536, took 23221 iterations and 814 nodes (39.28 seconds)
# Cbc0032I Strong branching done 1880 times (23524 iterations), fathomed 0 nodes and fixed 0 variables
# Cbc0035I Maximum depth 170, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 61536 to 61536
# Probing was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.337 seconds)
# Gomory was tried 10 times and created 256 cuts of which 0 were active after adding rounds of cuts (0.859 seconds)
# Knapsack was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.061 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# MixedIntegerRounding2 was tried 10 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.082 seconds)
# FlowCover was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.013 seconds)
# TwoMirCuts was tried 10 times and created 126 cuts of which 0 were active after adding rounds of cuts (0.258 seconds)
# ZeroHalf was tried 10 times and created 102 cuts of which 0 were active after adding rounds of cuts (1.176 seconds)
#
# Result - Optimal solution found
#
# Objective value:                61536.00000000
# Enumerated nodes:               814
# Total iterations:               23221
# Time (CPU seconds):             37.51
# Time (Wallclock seconds):       39.55
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       37.67   (Wallclock seconds):       39.81

# %%
prob.objective.value()
# Out:
# np.float64(61536.0)

# %%
# Preparação dos resultados para visualização
resultados = []
for nurse in all_nurses:
    for shift in all_shifts:
        if value(assigned[(nurse, shift)]) == 1:  # Se a enfermeira foi alocada ao turno
            custo_turno = df_shifts['duration'][shift] * df_nurses.loc[nurse, 'pay_rate']
            resultados.append([nurse, shift, df_shifts['duration'][shift], df_nurses.loc[nurse, 'pay_rate'], custo_turno])

# Cria DataFrame para exibir os resultados
df_resultados = pd.DataFrame(resultados, columns=['Enfermeira', 'Turno', 'Duração (h)', 'Taxa por Hora', 'Custo Turno'])
df_resultados.loc['Total'] = ['', '', '', '', value(prob.objective)]

# %% [markdown]
# Manter o resultado em um SqLite, afim de realizar consultas e filtros para a análise dos resultados

# %%
# import sqlite3
# 
# # Cria uma conexão com o banco de dados em memória
# conn = sqlite3.connect(":memory:")
# 
# # Carrega o DataFrame como uma tabela SQL
# df_resultados.to_sql("resultados", conn, index=False, if_exists="replace")
# 
# # 1. Carga horária máxima semanal de 40 horas
# query_carga_horaria = """
# SELECT Enfermeira, SUM([Duração (h)]) AS total_horas
# FROM resultados
# GROUP BY Enfermeira
# HAVING total_horas > 40
# """
# resultado_carga_horaria = pd.read_sql_query(query_carga_horaria, conn)
# 
# # 2. Trabalho consecutivo máximo de 10 horas
# query_consecutivo = """
# SELECT a.Enfermeira, a.Turno as Turno1, a.[Hora Início], a.[Hora Fim],
#        b.Turno as Turno2, b.[Hora Início], b.[Hora Fim],
#        (a.[Duração (h)] + b.[Duração (h)]) as Total_Horas_Trabalho
# FROM resultados a
# JOIN resultados b 
#   ON a.Enfermeira = b.Enfermeira 
#  AND a.[Dia da Semana] = b.[Dia da Semana]
#  AND a.[Hora Fim] <= b.[Hora Início]
# WHERE Total_Horas_Trabalho > 10
# """
# resultado_consecutivo = pd.read_sql_query(query_consecutivo, conn)
# 
# # 3. Descanso mínimo diário de 12 horas
# query_descanso_minimo = """
# SELECT a.Enfermeira, a.Turno as Turno1, a.[Hora Fim], 
#        b.Turno as Turno2, b.[Hora Início], 
#        (b.[Hora Início] - a.[Hora Fim]) as Descanso_Horas
# FROM resultados a
# JOIN resultados b
#   ON a.Enfermeira = b.Enfermeira
#  AND a.[Dia da Semana] = b.[Dia da Semana]
#  AND a.[Hora Fim] <= b.[Hora Início]
# WHERE Descanso_Horas < 12
# """
# resultado_descanso = pd.read_sql_query(query_descanso_minimo, conn)
# 
# # 4. Mínimo e máximo de enfermeiros por turno
# query_min_max_enfermeiros = """
# SELECT Turno, COUNT(Enfermeira) as Total_Enfermeiras,
#        Min_Req, Max_Req
# FROM resultados
# GROUP BY Turno
# HAVING Total_Enfermeiras < Min_Req OR Total_Enfermeiras > Max_Req
# """
# resultado_min_max = pd.read_sql_query(query_min_max_enfermeiros, conn)
# 
# # Exibir resultados
# print("Violação de carga horária máxima semanal:")
# print(resultado_carga_horaria)
# 
# print("\nViolação de trabalho consecutivo máximo de 10 horas:")
# print(resultado_consecutivo)
# 
# print("\nViolação de descanso mínimo diário de 12 horas:")
# print(resultado_descanso)
# 
# print("\nViolação de mínimo e máximo de enfermeiros por turno:")
# print(resultado_min_max)
# # Fecha a conexão
# conn.close()

# %% [markdown]
# Exportar resultado para uma planilha

# %%
df_resultados.to_excel("resultado_32_42.xlsx", index=False)

print("Resultados exportados para 'resultado_alocacao_enfermeiras.xlsx'")
# Out:
# Resultados exportados para 'resultado_alocacao_enfermeiras.xlsx'
